# %% [markdown]
# <a href="https://colab.research.google.com/github/EleonoraBartolomucci/Fairness/blob/master/Faceplusplus/ElaboraFotoRandom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install clarifai
# Out:
# Collecting clarifai
#   Downloading https://files.pythonhosted.org/packages/7a/1b/b7718c29f54ba7545551724461a8c2891304b7e68e5f415c30b49499f5e1/clarifai-2.6.2.tar.gz (125kB)
#      |████████████████████████████████| 133kB 2.8MB/s
# Requirement already satisfied: future<2,>=0.15 in /usr/local/lib/python3.6/dist-packages (from clarifai) (0.16.0)
# Requirement already satisfied: requests<3,>=2.13 in /usr/local/lib/python3.6/dist-packages (from clarifai) (2.21.0)
# Collecting configparser<4,>=3.5
#   Downloading https://files.pythonhosted.org/packages/ab/1a/ec151e5e703ac80041eaccef923611bbcec2b667c20383655a06962732e9/configparser-3.8.1-py2.py3-none-any.whl
# Requirement already satisfied: jsonschema<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from clarifai) (2.6.0)
# Requirement already satisfied: grpcio<2,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from clarifai) (1.28.1)
# Requirement already satisfied: protobuf<4,>=3.6 in /usr/local/lib/python3.6/dist-packages (from clarifai) (3.10.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from clarifai) (1.51.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.13->clarifai) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.13->clarifai) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.13->clarifai) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.13->clarifai) (2020.4.5.1)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from grpcio<2,>=1.13.0->clarifai) (1.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf<4,>=3.6->clarifai) (46.1.3)
# Building wheels for collected packages: clarifai
#   Building wheel for clarifai (setup.py) ... done
#   Created wheel for clarifai: filename=clarifai-2.6.2-cp36-none-any.whl size=188403 sha256=abc3d79017e89e9cd54ea19e3c2e520fd5b770a371c35cd00a6ed6da8d16dafd
#   Stored in directory: /root/.cache/pip/wheels/17/2c/3b/d89ffd4572633f70872165cedf61813ac8047461ed5e1e3768
# Successfully built clarifai
# Installing collected packages: configparser, clarifai
# Successfully installed clarifai-2.6.2 configparser-3.8.1

# %%
#Da cambiare:
#nome del csv e cartella da cui prendo le foto (foto ordinate come "ultima modifica e freccetta in giù")

import json
import csv
from pydrive.auth import GoogleAuth 
from pydrive.drive import GoogleDrive

# apro e parso il file .json
def convert(response,file):

  with open('utenti.txt', 'w') as outfile:
    json.dump(response, outfile) 
        
  # apro e parso il file .json
  data = open('utenti.txt').read()
  data_parsed = json.loads(data)

  #creo e apro un file .csv per scrivere
  file_parsed = open('TupeloHoney_10%Random_UsersData.csv', 'a')
    
  #creo il writer
  writer = csv.writer(file_parsed)

  #ciclo per estrarre dal file json i valori di id, età, genere ed etnia
  for person in data_parsed['user']:
     writer.writerow([person['id'],
                      person['age'],
                      person['gender'],
                      person['ethnicity']])
     
  
  #salvo e chiudo il file .csv
  file_parsed.close()

  file.SetContentFile('TupeloHoney_10%Random_UsersData.csv') #The contents of the file
  file.Upload()

# %%
from clarifai.rest import ClarifaiApp
import time

def detect_clarifai(id, url_photo, data):
  app = ClarifaiApp(api_key='6651c2b2e8d64d3291238ef15277c18c')
  model = app.models.get(model_id="c0c0ac362b03416da06ab3fa36fb58e3")
  response = model.predict_by_url(url = '%s' % url_photo)
  
  if response['outputs'][0]['data'] != {}:
    x = 0
    while (x < len(response['outputs'][0]['data']['regions'])):
      age = response['outputs'][0]['data']['regions'][x]['data']['concepts'][0]['name']
      gender = response['outputs'][0]['data']['regions'][x]['data']['concepts'][20]['name']
      ethnicity = response['outputs'][0]['data']['regions'][x]['data']['concepts'][22]['name']

      data['user'].append({
          'id' : '%s' % id,
          'age' : '%s' % age,
          'gender' : '%s' % gender,
          'ethnicity' : '%s' % ethnicity,
      })
      x = x + 1
  else:
    return

# %%
#Da cambiare:
#id_csv_clarifai = link condivisibile del csv (clarifai) già fatto e il nome
#file_list = cartella da dove prendi le foto

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
from google.colab import auth
from clarifai.rest import ApiError
import json
import pandas as pd

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# DOWNLOAD my_users.csv FROM DRIVE
id_csv_clarifai = '1lZM22vKH4DRjxgG0PIbuos4MbaF86MqU'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': id_csv_clarifai})
download.GetContentFile('TupeloHoney_10%Random_UsersData.csv')

#leggo il csv
csv_clarifai = pd.read_csv('TupeloHoney_10%Random_UsersData.csv')

#Auto-iterate through all files that matches this query
file_list = drive.ListFile({'q': "'1Y4kVSFpVyLUA6uIAE9pAN12U82KNRZ6-' in parents and trashed=false"}).GetList()    #cartella da cui prendo le foto

data = {}
data['user'] = []
for file1 in file_list:
  id = file1['title'][0:22] 
  df1 = csv_clarifai[csv_clarifai['id'].str.contains(id)]
  print(df1)
  if df1.empty :
    detect_clarifai(id, file1['thumbnailLink'], data)

convert(data, download)
# Out:
#                        id  age     gender ethnicity
# 0  JtZmqYQo5jXndoLQ5LBDyA   39  masculine     white
# 1  JtZmqYQo5jXndoLQ5LBDyA   39  masculine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                        id  age     gender ethnicity
# 2  Bco1WVVLtMz67Yi-ilJwsA   39  masculine     asian
#                        id  age     gender ethnicity
# 3  mDbJamFxd0nDtGZi8oHxGg   39  masculine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                        id  age     gender ethnicity
# 4  GhKuk7uU3EiXlzMamQkJ0w   55  masculine     white
#                        id  age    gender ethnicity
# 5  eb5Ew5SXH_fWdcKPThBehg   24  feminine     white
#                        id  age     gender ethnicity
# 6  wCZdIFKTDw0AoYe_kuIoYA   45   feminine     white
# 7  wCZdIFKTDw0AoYe_kuIoYA   28  masculine     white
#                        id  age    gender ethnicity
# 8  yL4whR1Qb63FptG9IVRdVQ   44  feminine     white
#                         id  age    gender ethnicity
# 9   gHLb7eLfQ1Nn2_8ZWf62zg   37  feminine     white
# 10  gHLb7eLfQ1Nn2_8ZWf62zg   39  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age     gender                  ethnicity
# 11  EUkB_ST79MoK6OZAsfppLA   39  masculine  black or african american
#                         id  age     gender ethnicity
# 12  ttaHXwmnmgbopc_zAuzDgg   64   feminine     white
# 13  ttaHXwmnmgbopc_zAuzDgg   46  masculine     white
# 14  ttaHXwmnmgbopc_zAuzDgg   39   feminine     asian
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender                  ethnicity
# 15  8UgV0f04hMaFM4ocW-sZnQ   39  feminine  black or african american
#                         id  age    gender                            ethnicity
# 16  kKTcYPz47sCDH1_ylnE4ZQ   27  feminine  hispanic, latino, or spanish origin
#                         id  age    gender ethnicity
# 17  Uqvur1oqemguILRg-Xmwrg   29  feminine     asian
#                         id  age    gender ethnicity
# 18  Fyls91s9apwY-gkLXt6C9A   38  feminine     white
#                         id  age    gender ethnicity
# 19  3qgQAwIgBtYY2H957xeP-w   24  feminine     white
# 20  3qgQAwIgBtYY2H957xeP-w   36  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age     gender ethnicity
# 21  y2T3FPC5BQgZ_C9IvhoTtg   39  masculine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender ethnicity
# 22  d4ozNIXwNvigQxdw98dwxA   24  feminine     white
#                         id  age     gender ethnicity
# 23  1Qtguu0VWSPal1faEKpsAA   39  masculine     white
#                         id  age    gender ethnicity
# 24  dDOU5Ti90aFL0BmglKR-Ww   56  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age     gender                            ethnicity
# 25  p2IvgM0wdd6FS6ji6868RQ   36  masculine  hispanic, latino, or spanish origin
# 26  p2IvgM0wdd6FS6ji6868RQ   28   feminine                                white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender ethnicity
# 27  _5keMAmic7zzrnM5mVefBw   55  feminine     white
#                         id  age     gender ethnicity
# 28  pxnm3yhL20lFfILrib4v8g   28  masculine     white
#                         id  age    gender                  ethnicity
# 29  kKmHOAMkjnYiKwPTxXSIJQ   39  feminine  black or african american
#                         id  age    gender ethnicity
# 30  hzcqHSJnR1cbS5VGu0c3wA   16  feminine     white
# 31  hzcqHSJnR1cbS5VGu0c3wA   23  feminine     white
#                         id  age    gender ethnicity
# 32  KVTlwVA7NcoKO6QuUZWaiA   39  feminine     white
#                         id  age    gender ethnicity
# 33  qp6mMPejabkk0MdQvZHmOw   28  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender ethnicity
# 34  KOAOhf6u9zTFk32B96eX4A   40  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender ethnicity
# 35  2GArg5AdMTzdr7epY-TBig   39  feminine     white
#                         id  age    gender                  ethnicity
# 36  BkIOqr6F6tNzZjcbx0HAUw   39  feminine  black or african american
#                         id  age    gender ethnicity
# 37  bSXpj3DcGFjRTIlFVQIroA   23  feminine     white
#                         id  age     gender                  ethnicity
# 38  PyRy1msqmdFRYVmTUqHGtg   38  masculine  black or african american
#                         id  age     gender ethnicity
# 39  Il99cw8Bb3LHAutFp94wwA   40  masculine     white
#                         id  age     gender ethnicity
# 40  CvWA-I_vQ51XQjF28nwsZQ   36  masculine     asian
#                         id  age    gender ethnicity
# 41  -ohiiyenkujVu00Quou7-A   55  feminine     white
#                         id  age    gender ethnicity
# 42  9p1u4vQRYQXkoy4ZqiiQoQ   37  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age     gender                            ethnicity
# 43  U8AqHy8hJfD-9X6H68KZsg   24  masculine  hispanic, latino, or spanish origin
#                         id  age     gender ethnicity
# 44  K65tCfivdu-0v6bxZdCBhw   36   feminine     white
# 45  K65tCfivdu-0v6bxZdCBhw   49  masculine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age     gender                            ethnicity
# 46  KKuF91ZnZG4ghxFy0Zsnmg   39   feminine                                asian
# 47  KKuF91ZnZG4ghxFy0Zsnmg   39  masculine  hispanic, latino, or spanish origin
# 48  KKuF91ZnZG4ghxFy0Zsnmg   39  masculine            black or african american
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender                  ethnicity
# 49  tWz7nGOSznFgp_VRFmHiFg   23  feminine  black or african american
# 50  tWz7nGOSznFgp_VRFmHiFg   23  feminine  black or african american
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender ethnicity
# 51  11S60Gx_VoS5toWLjAOPGg   39  feminine     white
# 52  11S60Gx_VoS5toWLjAOPGg   23  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender ethnicity
# 53  oOSTgx4BfGFVheyMzN5dMw   39  feminine     asian
#                         id  age    gender ethnicity
# 54  qvPTw-ArHYI1n1n0cw3S7A   39  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age     gender                            ethnicity
# 55  3KvcAg61IiwDcyVjm63JkQ   39  masculine  hispanic, latino, or spanish origin
#                         id  age    gender ethnicity
# 56  yhEfn_oPNay4shGvBcAoXQ   36  feminine     white
#                         id  age     gender ethnicity
# 57  embCCsFwc6jMUIc0EYfB7Q   45  masculine     white
#                         id  age     gender ethnicity
# 58  6IGAHju0q450GfQMRGBuqw   39  masculine     white
#                         id  age     gender ethnicity
# 59  7KM2S-wfDesQObILU0I3bA   44  masculine     white
#                         id  age     gender ethnicity
# 60  YgRclUfGOFUcoslAXaZFgw   36  masculine     asian
# 61  YgRclUfGOFUcoslAXaZFgw   14   feminine     asian
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender                  ethnicity
# 62  k6um8mmU2ijpTSB-MugERQ   39  feminine  black or african american
#                         id  age    gender ethnicity
# 63  SvotHYsvwEJVRSDQqEq68g   24  feminine     white
#                         id  age    gender ethnicity
# 64  -7_vTTQulgF9MszaHdiJWQ   36  feminine     white
#                         id  age     gender                            ethnicity
# 65  1hKkxL5mMZzmp_hvpvXBkg   39  masculine  hispanic, latino, or spanish origin
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender ethnicity
# 66  mCyQmuKbtg8YRavM2P8KFw   39  feminine     white
# 67  mCyQmuKbtg8YRavM2P8KFw   45  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age     gender ethnicity
# 68  92RulOzPSLf8xfIxgwpXnA   45  masculine     white
# 69  92RulOzPSLf8xfIxgwpXnA   40   feminine     asian
#                         id  age     gender                            ethnicity
# 70  vhXwGy-zBhImLVym62mFqw   28  masculine  hispanic, latino, or spanish origin
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender ethnicity
# 71  3sY-Wj7CKDb9YjQm7LG5Ew   48  feminine     white
# 72  3sY-Wj7CKDb9YjQm7LG5Ew   59  feminine     white
#                         id  age    gender ethnicity
# 73  AUgvqZ_XdzUuAoza21wAYg   23  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age     gender ethnicity
# 74  1zHr8MWy6qDcq7ZUZ4UlHA   55   feminine     asian
# 75  1zHr8MWy6qDcq7ZUZ4UlHA   24  masculine     asian
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age     gender                  ethnicity
# 76  _GF25zBo-3B-ep8P7gxZgw   36  masculine                      asian
# 77  _GF25zBo-3B-ep8P7gxZgw   36   feminine  black or african american
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender ethnicity
# 78  aiJVlwMp6_3_IFmQnrgSTg   55  feminine     white
#                         id  age    gender ethnicity
# 79  cKuY6JCLMcIfm4kCMoLasA   58  feminine     white
#                         id  age    gender                            ethnicity
# 80  nDz9yR9IsPa7YpKeqJXRaQ   40  feminine  hispanic, latino, or spanish origin
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender                  ethnicity
# 81  sgqj8Nvg43iv-l8-MlC01A   39  feminine  black or african american
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age     gender ethnicity
# 82  eE1L8u2_iOV50yhMt9xyhw   27  masculine     white
#                         id  age    gender                  ethnicity
# 83  uJ-3o3dHwkYP3TyRwN4mWg   27  feminine  black or african american
#                         id  age     gender                            ethnicity
# 84  EC2FyPHaSpGOS-tjLXYssw   36  masculine                                white
# 85  EC2FyPHaSpGOS-tjLXYssw   36   feminine  hispanic, latino, or spanish origin
#                         id  age    gender                            ethnicity
# 86  MWuVbyBgP4vD24Rc7UH5xw   39  feminine  hispanic, latino, or spanish origin
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender                            ethnicity
# 87  gm_ZBooThAWMSr957Tlv-g   28  feminine  hispanic, latino, or spanish origin
# 88  gm_ZBooThAWMSr957Tlv-g   48  feminine                                white
#                         id  age     gender ethnicity
# 89  z4Bvefqd1bV7hwAuM7LJbw   39  masculine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age     gender ethnicity
# 90  U8GTYCZFfRJqJnZYJ5DHSA   23   feminine     white
# 91  U8GTYCZFfRJqJnZYJ5DHSA   39  masculine     white
#                         id  age     gender ethnicity
# 92  pEgAQg1y4LK3Lse1-UIFQw   28   feminine     asian
# 93  pEgAQg1y4LK3Lse1-UIFQw   39  masculine     white
# 94  pEgAQg1y4LK3Lse1-UIFQw   45  masculine     white
#                         id  age    gender ethnicity
# 95  gMB0_OdKhCFfSjM_occ76g   39  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender ethnicity
# 96  VLDgOw3mgP5ENzS9D3JAbg   39  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age     gender ethnicity
# 97  mr60nny5y0WlxP-pvMdIxw   39  masculine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender                  ethnicity
# 98  sdLns7062kz3Ur_b8wgeYw   23  feminine  black or african american
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                         id  age    gender ethnicity
# 99  sywiW-8pbt9DzWrYGRzCYQ   33  feminine     asian
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age     gender ethnicity
# 100  WzbiAVIgM4RCuEqNoS1Wcw   39  masculine     asian
#                          id  age    gender ethnicity
# 101  HfmoZIuNSWlN0J9-AgVWRA   36  feminine     white
#                          id  age    gender ethnicity
# 102  Flc77YcnnNCo7Frjk7BYkQ   55  feminine     white
#                          id  age     gender ethnicity
# 103  ZcG8kl7d0laJKrqLyngY9Q   36  masculine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age    gender                            ethnicity
# 104  VQ_qfFcG7nEpnBtqJPNFYQ   39  feminine  hispanic, latino, or spanish origin
# 105  VQ_qfFcG7nEpnBtqJPNFYQ   40  feminine                                white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age    gender ethnicity
# 106  NdiwcuwNX8MoY7sAwhGhig   46  feminine     white
#                          id  age    gender ethnicity
# 107  vKVbmxfzVeX-BlV5lYmT5g   16  feminine     asian
#                          id  age    gender                  ethnicity
# 108  NF3vUYgz6DFd8YPQmzB1WQ   23  feminine  black or african american
#                          id  age     gender ethnicity
# 109  mhOkfqzYPMBG52j0LkviCA   39  masculine     white
# 110  mhOkfqzYPMBG52j0LkviCA   55   feminine     white
#                          id  age     gender ethnicity
# 111  WQ06h-9wQASu3NicYqN5GQ   44  masculine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age     gender ethnicity
# 112  LBtlLzZlaUoTIFqfp5hYGg   39   feminine     white
# 113  LBtlLzZlaUoTIFqfp5hYGg   39  masculine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age    gender ethnicity
# 114  7IKcWcN0mL5MWp1imhfpoA   36  feminine     asian
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  ...                            ethnicity
# 115  sErm5Rn-LDEvoQVZPrM7yA  ...  hispanic, latino, or spanish origin
#
# [1 rows x 4 columns]
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age    gender ethnicity
# 116  EvHtJ5aK7AvUfcCyfgrZhQ   45  feminine     white
#                          id  age     gender                  ethnicity
# 117  VRPhRgGOl7Q1mJ5sbmXBeg    1  masculine                      white
# 118  VRPhRgGOl7Q1mJ5sbmXBeg   39  masculine                      white
# 119  VRPhRgGOl7Q1mJ5sbmXBeg   24  masculine                      white
# 120  VRPhRgGOl7Q1mJ5sbmXBeg   39   feminine  black or african american
#                          id  age     gender ethnicity
# 121  0vwOSOVEcHaIFIvdm5qpUA   36  masculine     asian
#                          id  ...                            ethnicity
# 122  EMyz3ARUB7H5BchEF5sw6w  ...  hispanic, latino, or spanish origin
#
# [1 rows x 4 columns]
#                          id  age    gender ethnicity
# 123  Z5j9Xw_G0c7M2b1-iS67wg   23  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age     gender                  ethnicity
# 124  KYSSaD9XX1aTUahkWK-IYA   39  masculine  black or african american
# 125  KYSSaD9XX1aTUahkWK-IYA   39   feminine                      asian
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age     gender                  ethnicity
# 126  XbEQZZ2y7ES9gAg5ctgY4A   39  masculine  black or african american
#                          id  age     gender ethnicity
# 127  cfun2XRIpELgOlxnWHjkCQ   27  masculine     white
# 128  cfun2XRIpELgOlxnWHjkCQ   45   feminine     white
#                          id  age    gender                  ethnicity
# 129  -9GWez04zko8_hjVQhRx5Q   45  feminine  black or african american
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  ...                            ethnicity
# 130  -JWMd_c7JFGMf02tOdGF_A  ...                                white
# 131  -JWMd_c7JFGMf02tOdGF_A  ...  hispanic, latino, or spanish origin
#
# [2 rows x 4 columns]
#                          id  age     gender ethnicity
# 132  gAORnKkyEJqyCmauTY0yJA   39  masculine     white
#                          id  age     gender ethnicity
# 133  g1YMgvlEcrOPyosKVlR-ng   28  masculine     asian
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age     gender ethnicity
# 134  b9oNk3PFe3uc4zrbF8g0cA    0  masculine     white
#                          id  age    gender                            ethnicity
# 135  hhvkQEAUxO-lSLeJo2nUSA   23  feminine  hispanic, latino, or spanish origin
#                          id  age     gender ethnicity
# 136  Ojhtim0S96aveFKPkTLeDQ   55   feminine     white
# 137  Ojhtim0S96aveFKPkTLeDQ   39  masculine     white
#                          id  age    gender ethnicity
# 138  Fy2-RKxEDjjPG_xQLyER3Q   39  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age     gender                  ethnicity
# 139  UWK3mKjnsVOA6sGim6zfgg   36  masculine  black or african american
#                          id  age     gender ethnicity
# 140  PuWsGFbwKUwnZwSG0Lj05g   39  masculine     white
#                          id  age    gender                  ethnicity
# 141  7yy0SXg9XQv0qK8rtetMWA   38  feminine  black or african american
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age     gender ethnicity
# 142  ofriwKiBqPO8sWlaOksing   39   feminine     white
# 143  ofriwKiBqPO8sWlaOksing   27  masculine     white
#                          id  age     gender ethnicity
# 144  T1fINCHLQ4d-3Ppso_Z0DQ   39  masculine     white
# 145  T1fINCHLQ4d-3Ppso_Z0DQ   40   feminine     white
# 146  T1fINCHLQ4d-3Ppso_Z0DQ   39  masculine     white
# 147  T1fINCHLQ4d-3Ppso_Z0DQ   36  masculine     white
# 148  T1fINCHLQ4d-3Ppso_Z0DQ   39   feminine     white
#                          id  ...                            ethnicity
# 149  Qm3OqdoOpnPsQXMGpMHtEw  ...                                white
# 150  Qm3OqdoOpnPsQXMGpMHtEw  ...  hispanic, latino, or spanish origin
#
# [2 rows x 4 columns]
#                          id  age    gender ethnicity
# 151  oUilYNfXensjapTI_s7cOQ   24  feminine     white
#                          id  age     gender ethnicity
# 152  KD6UvpUgHR4cHf8WLHLjdA   39  masculine     white
# 153  KD6UvpUgHR4cHf8WLHLjdA   39  masculine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age     gender ethnicity
# 154  HFSW-24buTW3_LQ4u_I57g   34  masculine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age    gender ethnicity
# 155  kw4Q3Qfj_8WxjTNExSi1hw   37  feminine     asian
#                          id  age    gender ethnicity
# 156  OP5eVLl7BMmOK0FVBz9rCQ   58  feminine     white
#                          id  age    gender ethnicity
# 157  AfoMST4w8NYNwimi0U7xPA   16  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age    gender ethnicity
# 158  jsOz-dWToun2VsFcFAfGww   28  feminine     white
#                          id  age    gender                  ethnicity
# 159  PF3IPCbcl23nm5HTYEoBoA   38  feminine  black or african american
#                          id  age    gender ethnicity
# 160  W4VhQk3hurVNWgs-0UjJtw   47  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  ...                            ethnicity
# 161  d4O272njR9F1TydrEG8TDw  ...                                white
# 162  d4O272njR9F1TydrEG8TDw  ...  hispanic, latino, or spanish origin
#
# [2 rows x 4 columns]
#                          id  age    gender ethnicity
# 163  ps0Y_WkkywSIQAzTszzGOQ   39  feminine     asian
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age     gender                  ethnicity
# 164  92UYzB-HR4Ei8mOmDzLPhA   39  masculine  black or african american
#                          id  age     gender ethnicity
# 165  qgsa5XPVm9Ckse7rCxupbw   44   feminine     white
# 166  qgsa5XPVm9Ckse7rCxupbw   39  masculine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age     gender ethnicity
# 167  u_wrAXTf-7036O8k6c-2zA   39  masculine     white
#                          id  age     gender                  ethnicity
# 168  tmJ8V-8T47IxuTw5NCBJGg   24  masculine  black or african american
#                          id  age    gender ethnicity
# 169  dcpZ-lXx_dm_tgxEzTJgOQ   45  feminine     white
#                          id  age    gender ethnicity
# 170  Pk4DFKNh9KdbR1pA0UsOgw   39  feminine     white
#                          id  age     gender ethnicity
# 171  cA75LNUExfyFe7MVYbAaKw   39  masculine     white
#                          id  age    gender ethnicity
# 172  U3sKgUOZtyls2DnR66pZtQ   39  feminine     white
#                          id  age     gender ethnicity
# 173  a9hF330chdzNskR07gjJiQ   39   feminine     white
# 174  a9hF330chdzNskR07gjJiQ   39  masculine     white
#                          id  age     gender ethnicity
# 175  OqTWhEhYNU7MRaxB7Ls3Lg   23  masculine     asian
# 176  OqTWhEhYNU7MRaxB7Ls3Lg   46   feminine     white
#                          id  age    gender ethnicity
# 177  bBYRdGO__bQ_VYu3UMe-WA   39  feminine     white
# 178  bBYRdGO__bQ_VYu3UMe-WA   37  feminine     white
#                          id  age     gender ethnicity
# 179  6MQECuBxnrT7FXrzFUV6nA   39  masculine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age     gender                  ethnicity
# 180  dMx-PR1ujNveu6kdQU5Q7w   39  masculine  black or african american
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age     gender ethnicity
# 181  NnL6HUNY9ckb9mSbTGkjOg   39   feminine     asian
# 182  NnL6HUNY9ckb9mSbTGkjOg   39  masculine     white
#                          id  age    gender ethnicity
# 183  KHbnJXr3gx4-JfI5U00YCg   27  feminine     white
#                          id  age    gender ethnicity
# 184  Le0IIH_O2yMpzaNcwA-e-w   46  feminine     white
#                          id  age    gender                            ethnicity
# 185  PQMvWCxlpk8pdLiWMnMRfw   39  feminine  hispanic, latino, or spanish origin
# 186  PQMvWCxlpk8pdLiWMnMRfw   27  feminine                                white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age    gender ethnicity
# 187  2myUUqvMBUPRIIbkDCkYfg   55  feminine     white
#                          id  age    gender                  ethnicity
# 188  jc0O62hRw_dqZtvXPrQ3AA   48  feminine  black or african american
#                          id  age     gender                  ethnicity
# 189  bdJqgpcvSQSzxnpBVz4VCg   39  masculine  black or african american
#                          id  age     gender                  ethnicity
# 190  g4Ou0twfr_0aSoX55Ck4Ng   39  masculine  black or african american
#                          id  age    gender                            ethnicity
# 191  8DtQoqIRVDsfL1RZSG7f9w   27  feminine  hispanic, latino, or spanish origin
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age    gender                            ethnicity
# 192  4U9U4dFEIBE2GhCB0ACwcg   34  feminine  hispanic, latino, or spanish origin
#                          id  age    gender ethnicity
# 193  w6Ehpeh8MLsiIhjskmPMQw   40  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age    gender ethnicity
# 194  QmethzRyAvZXS9m1UNJpdw   45  feminine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age    gender                            ethnicity
# 195  gZ8VNx7wHuaOd24Bx71saQ   39  feminine  hispanic, latino, or spanish origin
#                          id  age     gender ethnicity
# 196  wsC8amclTEocEBjbnujRlA   36  masculine     white
#                          id  age    gender                            ethnicity
# 197  rwEZPeKEHWQcujVWVLdvDw   44  feminine  hispanic, latino, or spanish origin
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
#                          id  age     gender ethnicity
# 198  flz-ymsTSzM9ACOV2JyU8g   37   feminine     white
# 199  flz-ymsTSzM9ACOV2JyU8g   33  masculine     white
# Empty DataFrame
# Columns: [id, age, gender, ethnicity]
# Index: []
