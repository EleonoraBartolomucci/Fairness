# %% [markdown]
# <a href="https://colab.research.google.com/github/EleonoraBartolomucci/Fairness/blob/master/Faceplusplus/HarumiSushiRelevance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#da cambiare:
# folder_id 
import requests
from lxml import html
import shutil
import os
import json

def downloadUser(user_id, counter):

    #Creare la cartella sul Drive dove andranno le foto (in data > face_data > Foto_User > (nomeRistorante)10%(strategia))
    folder_id = '1855GDqRLvhKTyjWrVCpQiv55cSbqfBwv'  # folder ID = HarumiSushi_10%Relevance
    filename = user_id + '.jpg'
    url = 'https://www.yelp.com/user_details?userid=' + user_id

    try:
        # Find user picture from web page
        page_content = requests.get(url)
        tree = html.fromstring(page_content.content)
        if len(tree.xpath('//*[@id="wrap"]/div[2]/div[1]/div/div[2]/div[1]/div/div/div/a/img/@src')) != 0:  # Picture found
            image_url = tree.xpath('//*[@id="wrap"]/div[2]/div[1]/div/div[2]/div[1]/div/div/div/a/img/@src')[0]

            # View all folders and file in your folder
            fileList = drive.ListFile({'q': "'" + folder_id + "' in parents and trashed=false"}).GetList()

            # Create file on Google Drive
            # param id = ID of Fairness/face_data folder in my Google Drive
            drive_file = drive.CreateFile({'title': filename, 'parents': [{'id': folder_id}]})

            # Check if file already exists in Google Drive (prevents duplicates)
            for file in fileList:
                # print('Title: %s, ID: %s' % (file['title'], file['id']))
                if file['title'] == filename:  # The file already exists, then overwrite it
                    fileID = file['id']
                    drive_file = drive.CreateFile({'id': fileID, 'title': filename, 'parents': [{'id': folder_id}]})

            response = requests.get(image_url, stream=True)

            # Create a local copy of user picture
            with open(filename, 'wb') as out_file:
                shutil.copyfileobj(response.raw, out_file)
            del response

            # Upload user picture on Google Drive
            drive_file.SetContentFile(filename)  # path of local file content
            drive_file.Upload()  # Upload the file.
            # print('title: %s, mimeType: %s' % (drive_file['title'], drive_file['mimeType']))

            # Delete local user pictures
            if os.path.exists(filename):
                os.remove(filename)
            else:
                print("The file does not exist")
    except:
        print("Si è verificato un errore alla riga " + str(counter) + " del file user.json")

# %%
#Prime 10% di foto di utenti per ristorante per data e per rilevanza (ordinamento di yelp)

#da cambiare:
#users_restaurant_id, nome del file e quante foto prendere (10% del totale delle recensioni)

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
from google.colab import auth
import json
import csv
import random
import pandas as pd

# Connect to Google Account
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# DOWNLOAD Restaurant.csv FROM DRIVE
# users_restaurant_id = id del file csv del ristorante (si trova in data > Scraping > Reviews_(strategia)) > (nomeRistorante)_(strategia).csv)
users_restaurant_id = '1qz4bzDrzCoiwqNyJOrffYtEOWaFndPBN'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': users_restaurant_id})
download.GetContentFile('Harumi Sushi_relevance_desc.csv')

#leggo il file csv del ristorante
restaurant = pd.read_csv('Harumi Sushi_relevance_desc.csv')

#user_list = lista id utenti che ci sono anche nel dataset
user_list = []
cnt =0
for riga in restaurant['user_id']:
  #10% per ogni ristorante
  if cnt < 140:
    user_list.append(riga)
    print(riga)
    cnt = cnt + 1
  else:
    break

cnt = 0
for user_id in user_list:
  id = '%s' % user_id
  downloadUser(id,cnt)
  cnt = cnt + 1
# Out:
# zLl4HKNyoMeCgrcfFRZ30A
# 19JT5efNEv942W4fhKWDlg
# r66VNjlsuFrPqCsSrE5DEw
# kbfpED-6FURIsNlsAXqc2g
# ED7dq2rT3IWXjSl58CR36w
# qJSO1eF5KB_Fp3D--okr7g
# tCCjNUvPb7fhVSAKn66cMA
# LvKPB1YpLXtg2x6VajPnoQ
# XJNY_hMIYM_DWyh-AgJA3A
# 2Sn7PCx_Q4tnfFU8auqDBw
# P4e8HwEkf0fSGrFEVRFZtQ
# ta1wjlhfRtqYXPSEItJ6BQ
# io3JoPj05TGtuaBCB-u-6Q
# IML_M1sJ0CjKigEzbUT7Xg
# zSQme-TdmYUXpvewGlwlgw
# WR1fZqarWeDgtyVxOgBt_A
# gPHX5p9zqiaks3LNSM0foQ
# qjgljf2MrnHOdWCsgX78FA
# RvF8YlH8N4XrqopprKmHEA
# _pAWShQ3Wv7CaEDtooqfZA
# ycg2iD2LDnY9g6mcw-kjig
# 0ocnjZ70jsb60QtUAX3tXQ
# TsuSXVUYLbXtMXzZyOXgUg
# aVnPe0C5a8InJJXQFFCBMQ
# uLbU7eK_ks7zBB8h1UOHZQ
# OD_pHoIPtSQsC2oPteonwA
# feJ0AcIOjGozeu6BZVhf9A
# EtMyK8NNrlRuONz7jd7F-g
# MZVNPBjd_xoTKd7XS56v-Q
# gNIcGpRuqmXc9_j0x9vXuw
# nybTolOv1XEhrZAFSd1JDg
# ZKIUW2OV8uizW98hn9aKIg
# LS0Cj5IiH28NnSChCLPSQw
# 4PxhS9pBlDzvt6YiUNiU9A
# OPHtdryCpZaooJ_kfJlDxA
# qM6ynUgZjhweJJNYeXrYtA
# A-5uDTPVw6-XmNgUSXQLyQ
# umUFCDiD_0_pSHpUh_03Ow
# koRVMP65qg1E4aIrOCqv0Q
# a85qPvr6L63PF0v9Zs8ZAg
# f8Y4kgQauwv4NhUa0rdvog
# bI0lvh1gm7lcI3nOrQTc7w
# f3s0qvh-yQ__88dYQKALHA
# Nlrs2Hu380rcJjADjM2O3Q
# ROhZJYYxRp8la4FNmFWm1w
# jnCse7jzUIs2R52QYBKOWA
# 8eSWOHE_vmPlORHHH7noMA
# LMj7z3j3ELC-JSgdUGDrBA
# 3kJ5Yuo_CrdctSU-T0nGLQ
# vZFYa63rZtbyiL4bH32CdQ
# Mi6LPDAQIKkzqyxV2Fx7Eg
# T1TI-1x4TJB7V-nJhaP_NA
# VLTm2FcgG9xtPsgi0j55Zg
# iG06cKhzQwJFQdpPcV7TFg
# rIustk_-Li3WR3KZf6rzHg
# ohLH1DFgfqC-I5nEe2z8Nw
# Wt05QanhU00pKkZ_Yz8hbw
# ZnVHNMbe7dSfcymbEDssqw
# m7tf6pvEsHdLS3cIKsvhDw
# 3vcHqFmzSfVAXOIFikK06A
# lWwlPEbkR-yUt057Oc_wjA
# 1zeI8KyMPW--umMxNEP7Ew
# 5FAD2Yq7DLBQ_-ef1iDA-A
# H-qEBVZJ82Sttzi3oE90KQ
# IbuBd7eVXA-u6H_rong8-A
# iuz4lXjzwaxuFWaLqUl6gA
# auGGD6BvchLmZNPjpP7zwQ
# CuGXdlZqU-SlZNAIEkgvHQ
# OGHG4qIEFXfuGYmHEcJU3Q
# Z3i-2gUc7wu8mIFgATDN_Q
# WMMI5Q4Rmm1Rqdu0jOvyhQ
