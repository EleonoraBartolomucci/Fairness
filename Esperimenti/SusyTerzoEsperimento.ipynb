# %% [markdown]
# <a href="https://colab.research.google.com/github/EleonoraBartolomucci/Fairness/blob/master/Esperimenti/SusyTerzoEsperimento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
from google.colab import auth
import json
import pandas as pd
import csv
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# file con i dati di tutti i ristoranti random
sort = 'Random'

relevance = '1n9vdCnppJGdE6M6HdKYlksuTntQYHA7P'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': relevance})
download.GetContentFile('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

# leggo il csv con pandas
res = pd.read_csv('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

# %%
#RACCOLTA DATI

#Percentuali di maschi e femmine sopra e sotto i 40, per ogni ristorante

# converto le stringhe di age in int
res.age = pd.to_numeric(res.age, errors='coerce').fillna(0).astype(np.int64)



totaleNC = len(res[(res['zone'] == 'NC')])
NCamerican = (len(res[(res['zone'] == 'NC') & (res['ethnicity'] == 'white')]) * 100) / totaleNC
NCmexican = (len(res[(res['zone'] == 'NC') & (res['ethnicity'] == 'hispanic, latino, or spanish origin')]) * 100) / totaleNC
NCasian = (len(res[(res['zone'] == 'NC') & (res['ethnicity'] == 'asian')]) * 100) / totaleNC
print(NCamerican)
print(NCmexican)
print(NCasian)

totaleNV = len(res[(res['zone'] == 'NV')])
NVamerican = (len(res[(res['zone'] == 'NV') & (res['ethnicity'] == 'white')]) * 100) / totaleNV
NVmexican = (len(res[(res['zone'] == 'NV') & (res['ethnicity'] == 'hispanic, latino, or spanish origin')]) * 100) / totaleNV
NVasian = (len(res[(res['zone'] == 'NV') & (res['ethnicity'] == 'asian')]) * 100) / totaleNV
print(NVamerican)
print(NVmexican)
print(NVasian)

totaleAZ = len(res[(res['zone'] == 'AZ')])
AZamerican = (len(res[(res['zone'] == 'AZ') & (res['ethnicity'] == 'white')]) * 100) / totaleAZ
AZmexican = (len(res[(res['zone'] == 'AZ') & (res['ethnicity'] == 'hispanic, latino, or spanish origin')]) * 100) / totaleAZ
AZasian = (len(res[(res['zone'] == 'AZ') & (res['ethnicity'] == 'asian')]) * 100) / totaleAZ
print(AZamerican)
print(AZmexican)
print(AZasian)
# Out:
# 34.92511395702192
# 6.924245713045366
# 8.20490557846755
# 22.88534888938748
# 8.974646623289209
# 20.57437738389051
# 33.200335993280135
# 9.785804283914322
# 9.113817723645527

# %%
labels = ['NCamerican', 'NCmexican', 'NCasian']
sizes = [NCamerican, NCmexican, NCasian] 
explode = [0, 0, 0]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.set_title("NC")
fig.tight_layout()

labels = ['NVamerican', 'NVmexican', 'NVasian']
sizes = [NVamerican, NVmexican, NVasian] 
explode = [0, 0, 0]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.set_title("NV")
fig.tight_layout()


labels = ['AZamerican', 'AZmexican', 'AZasian']
sizes = [AZamerican, AZmexican, AZasian] 
explode = [0, 0, 0]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.set_title("AZ")
fig.tight_layout()

# %%
masculineMaxAmerican = (masculineMaxTupelo + masculineMaxCravings + masculineMaxCulinary) / 3
masculineMinAmerican = (masculineMinTupelo + masculineMinCravings + masculineMinCulinary) / 3
femenineMaxAmerican = (femenineMaxTupelo + femenineMaxCravings + femenineMaxCulinary) / 3
femenineMinAmerican = (femenineMinTupelo + femenineMinCravings + femenineMinCulinary) / 3

masculineMaxMexican = (masculineMaxCabo + masculineMaxLindo + masculineMaxBeckyard) / 3
masculineMinMexican = (masculineMinCabo + masculineMinLindo + masculineMinBeckyard) / 3
femenineMaxMexican = (femenineMaxCabo + femenineMaxLindo + femenineMaxBeckyard) / 3
femenineMinMexican = (femenineMinCabo + femenineMinLindo + femenineMinBeckyard) / 3

masculineMaxAmerican = (masculineMaxTupelo + masculineMaxCravings + masculineMaxCulinary) / 3
masculineMinAmerican = (masculineMinTupelo + masculineMinCravings + masculineMinCulinary) / 3
femenineMaxAmerican = (femenineMaxTupelo + femenineMaxCravings + femenineMaxCulinary) / 3
femenineMinAmerican = (femenineMinTupelo + femenineMinCravings + femenineMinCulinary) / 3
