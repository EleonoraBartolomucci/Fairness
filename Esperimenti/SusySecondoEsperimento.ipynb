# %% [markdown]
# <a href="https://colab.research.google.com/github/EleonoraBartolomucci/Fairness/blob/master/Esperimenti/SusySecondoEsperimento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
from google.colab import auth
import json
import pandas as pd
import csv
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# file con i dati di tutti i ristoranti random
sort = 'Random'

relevance = '1n9vdCnppJGdE6M6HdKYlksuTntQYHA7P'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': relevance})
download.GetContentFile('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

# leggo il csv con pandas
res = pd.read_csv('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

# %%
#RACCOLTA DATI

#Percentuali di maschi e femmine sopra e sotto i 40, per ogni ristorante

# converto le stringhe di age in int
res.age = pd.to_numeric(res.age, errors='coerce').fillna(0).astype(np.int64)

totaleTupelo = len(res[(res['restaurant'] == 'TupeloHoney')])
masculineTupeloU30 = (len(res[(res['restaurant'] == 'TupeloHoney') & (res['gender'] == 'masculine') & (res['age'] <= 30)]) * 100) / totaleTupelo
femenineTupeloU30 = (len(res[(res['restaurant'] == 'TupeloHoney') & (res['gender'] == 'feminine') & (res['age'] <= 30)]) * 100) / totaleTupelo
masculineTupeloU50 = (len(res[(res['restaurant'] == 'TupeloHoney') & (res['gender'] == 'masculine') & (res['age'] > 30) & (res['age'] <= 50)]) * 100) / totaleTupelo
femenineTupeloU50 = (len(res[(res['restaurant'] == 'TupeloHoney') & (res['gender'] == 'feminine') & (res['age'] > 30) & (res['age'] <= 50)]) * 100) / totaleTupelo
masculineTupeloOver = (len(res[(res['restaurant'] == 'TupeloHoney') & (res['gender'] == 'feminine') & (res['age'] > 50)]) * 100) / totaleTupelo
femenineTupeloOver = (len(res[(res['restaurant'] == 'TupeloHoney') & (res['gender'] == 'feminine') & (res['age'] > 50)]) * 100) / totaleTupelo
notRecognizedTupelo = (len(res[(res['restaurant'] == 'TupeloHoney') & (res['gender'] == 'Not recognized')]) * 100) / totaleTupelo

totaleCabo = len(res[(res['restaurant'] == 'CaboFishTaco')])
masculineMaxCabo = (len(res[(res['restaurant'] == 'CaboFishTaco') & (res['gender'] == 'masculine') & (res['age'] > 30)]) * 100) / totaleCabo
masculineMinCabo = (len(res[(res['restaurant'] == 'CaboFishTaco') & (res['gender'] == 'masculine') & (res['age'] < 30)]) * 100) / totaleCabo
feminineMaxCabo = (len(res[(res['restaurant'] == 'CaboFishTaco') & (res['gender'] == 'feminine') & (res['age'] > 30)]) * 100) / totaleCabo
feminineMinCabo = (len(res[(res['restaurant'] == 'CaboFishTaco') & (res['gender'] == 'feminine') & (res['age'] < 30)]) * 100) / totaleCabo
notRecognizedCabo = (len(res[(res['restaurant'] == 'CaboFishTaco') & (res['gender'] == 'Not recognized')]) * 100) / totaleCabo

totaleFuto = len(res[(res['restaurant'] == 'FutoButa')])
masculineMaxFuto = (len(res[(res['restaurant'] == 'FutoButa') & (res['gender'] == 'masculine') & (res['age'] > 30)]) * 100) / totaleFuto
masculineMinFuto = (len(res[(res['restaurant'] == 'FutoButa') & (res['gender'] == 'masculine') & (res['age'] < 30)]) * 100) / totaleFuto
feminineMaxFuto = (len(res[(res['restaurant'] == 'FutoButa') & (res['gender'] == 'feminine') & (res['age'] > 30)]) * 100) / totaleFuto
feminineMinFuto = (len(res[(res['restaurant'] == 'FutoButa') & (res['gender'] == 'feminine') & (res['age'] < 30)]) * 100) / totaleFuto
notRecognizedFuto = (len(res[(res['restaurant'] == 'FutoButa') & (res['gender'] == 'Not recognized')]) * 100) / totaleFuto

totaleCravings = len(res[(res['restaurant'] == 'CravingsBuffet')])
masculineMaxCravings = (len(res[(res['restaurant'] == 'CravingsBuffet') & (res['gender'] == 'masculine') & (res['age'] > 30)]) * 100) / totaleCravings
masculineMinCravings = (len(res[(res['restaurant'] == 'CravingsBuffet') & (res['gender'] == 'masculine') & (res['age'] < 30)]) * 100) / totaleCravings
feminineMaxCravings = (len(res[(res['restaurant'] == 'CravingsBuffet') & (res['gender'] == 'feminine') & (res['age'] > 30)]) * 100) / totaleCravings
feminineMinCravings = (len(res[(res['restaurant'] == 'CravingsBuffet') & (res['gender'] == 'feminine') & (res['age'] < 30)]) * 100) / totaleCravings
notRecognizedCravings = (len(res[(res['restaurant'] == 'CravingsBuffet') & (res['gender'] == 'Not recognized')]) * 100) / totaleCravings

totaleLindo = len(res[(res['restaurant'] == 'LindoMichoacan')])
masculineMaxLindo = (len(res[(res['restaurant'] == 'LindoMichoacan') & (res['gender'] == 'masculine') & (res['age'] > 30)]) * 100) / totaleLindo
masculineMinLindo = (len(res[(res['restaurant'] == 'LindoMichoacan') & (res['gender'] == 'masculine') & (res['age'] < 30)]) * 100) / totaleLindo
feminineMaxLindo = (len(res[(res['restaurant'] == 'LindoMichoacan') & (res['gender'] == 'feminine') & (res['age'] > 30)]) * 100) / totaleLindo
feminineMinLindo = (len(res[(res['restaurant'] == 'LindoMichoacan') & (res['gender'] == 'feminine') & (res['age'] < 30)]) * 100) / totaleLindo
notRecognizedLindo = (len(res[(res['restaurant'] == 'LindoMichoacan') & (res['gender'] == 'Not recognized')]) * 100) / totaleLindo

totaleIchiza = len(res[(res['restaurant'] == 'Ichiza')])
masculineMaxIchiza = (len(res[(res['restaurant'] == 'Ichiza') & (res['gender'] == 'masculine') & (res['age'] > 30)]) * 100) / totaleIchiza
masculineMinIchiza = (len(res[(res['restaurant'] == 'Ichiza') & (res['gender'] == 'masculine') & (res['age'] < 30)]) * 100) / totaleIchiza
feminineMaxIchiza = (len(res[(res['restaurant'] == 'Ichiza') & (res['gender'] == 'feminine') & (res['age'] > 30)]) * 100) / totaleIchiza
feminineMinIchiza = (len(res[(res['restaurant'] == 'Ichiza') & (res['gender'] == 'feminine') & (res['age'] < 30)]) * 100) / totaleIchiza
notRecognizedIchiza = (len(res[(res['restaurant'] == 'Ichiza') & (res['gender'] == 'Not recognized')]) * 100) / totaleIchiza

totaleCulinary = len(res[(res['restaurant'] == 'CulinaryDropout')])
masculineMaxCulinary = (len(res[(res['restaurant'] == 'CulinaryDropout') & (res['gender'] == 'masculine') & (res['age'] > 30)]) * 100) / totaleCulinary
masculineMinCulinary = (len(res[(res['restaurant'] == 'CulinaryDropout') & (res['gender'] == 'masculine') & (res['age'] < 30)]) * 100) / totaleCulinary
feminineMaxCulinary = (len(res[(res['restaurant'] == 'CulinaryDropout') & (res['gender'] == 'feminine') & (res['age'] > 30)]) * 100) / totaleCulinary
feminineMinCulinary = (len(res[(res['restaurant'] == 'CulinaryDropout') & (res['gender'] == 'feminine') & (res['age'] < 30)]) * 100) / totaleCulinary
notRecognizedCulinary = (len(res[(res['restaurant'] == 'CulinaryDropout') & (res['gender'] == 'Not recognized')]) * 100) / totaleCulinary

totaleBeckyard = len(res[(res['restaurant'] == 'BeckyardTaco')])
masculineMaxBeckyard = (len(res[(res['restaurant'] == 'BeckyardTaco') & (res['gender'] == 'masculine') & (res['age'] > 30)]) * 100) / totaleBeckyard
masculineMinBeckyard = (len(res[(res['restaurant'] == 'BeckyardTaco') & (res['gender'] == 'masculine') & (res['age'] < 30)]) * 100) / totaleBeckyard
feminineMaxBeckyard = (len(res[(res['restaurant'] == 'BeckyardTaco') & (res['gender'] == 'feminine') & (res['age'] > 30)]) * 100) / totaleBeckyard
feminineMinBeckyard = (len(res[(res['restaurant'] == 'BeckyardTaco') & (res['gender'] == 'feminine') & (res['age'] < 30)]) * 100) / totaleBeckyard
notRecognizedBeckyard = (len(res[(res['restaurant'] == 'BeckyardTaco') & (res['gender'] == 'Not recognized')]) * 100) / totaleBeckyard

totaleHarumi = len(res[(res['restaurant'] == 'HarumiSushi')])
masculineMaxHarumi = (len(res[(res['restaurant'] == 'HarumiSushi') & (res['gender'] == 'masculine') & (res['age'] > 30)]) * 100) / totaleHarumi
masculineMinHarumi = (len(res[(res['restaurant'] == 'HarumiSushi') & (res['gender'] == 'masculine') & (res['age'] < 30)]) * 100) / totaleHarumi
feminineMaxHarumi = (len(res[(res['restaurant'] == 'HarumiSushi') & (res['gender'] == 'feminine') & (res['age'] > 30)]) * 100) / totaleHarumi
feminineMinHarumi = (len(res[(res['restaurant'] == 'HarumiSushi') & (res['gender'] == 'feminine') & (res['age'] < 30)]) * 100) / totaleHarumi
notRecognizedHarumi = (len(res[(res['restaurant'] == 'HarumiSushi') & (res['gender'] == 'Not recognized')]) * 100) / totaleHarumi


print(masculineMaxCulinary)
print(masculineMinCulinary)
print(feminineMaxCulinary)
print(feminineMinCulinary)
print(notRecognizedCulinary)
print('---------------')
print(masculineMaxCravings)
print(masculineMinCravings)
print(feminineMaxCravings)
print(feminineMinCravings)
print(notRecognizedCravings)
# Out:
# 21.359223300970875
# 3.934593765968319
# 23.352069494123658
# 10.679611650485437
# 40.674501788451714
# ---------------
# 17.941952506596305
# 3.496042216358839
# 25.19788918205805
# 10.224274406332453
# 43.13984168865435

# %%
labels = ['masculineTupeloU30', 'femenineTupeloU30', 'masculineTupeloU50', 'femenineTupeloU50', 'masculineTupeloOver','femenineTupeloOver','notRecognizedTupelo']
sizes = [masculineTupeloU25, femenineTupeloU25, masculineTupeloU45, femenineTupeloU45, masculineTupeloU65,femenineTupeloU65,notRecognizedTupelo] 
explode = [0, 0, 0, 0, 0,0,0]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.set_title("Tupelo Honey")
fig.tight_layout()

labels = ['masculineMaxCravings', 'masculineMinCravings', 'feminineMaxCravings', 'feminineMinCravings', 'notRecognizedCravings']
sizes = [masculineMaxCravings, masculineMinCravings, feminineMaxCravings, feminineMinCravings, notRecognizedCravings] 
explode = [0, 0, 0, 0, 0]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.set_title("Cravings Buffet")
fig.tight_layout()

labels = ['masculineMaxCulinary', 'masculineMinCulinary', 'feminineMaxCulinary', 'feminineMinCulinary', 'notRecognizedCulinary']
sizes = [masculineMaxCulinary, masculineMinCulinary, feminineMaxCulinary, feminineMinCulinary, notRecognizedCulinary] 
explode = [0, 0, 0, 0, 0]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.set_title("Culinary Dropout")
fig.tight_layout()

labels = ['masculineMaxCabo', 'masculineMinCabo', 'feminineMaxCabo', 'feminineMinCabo', 'notRecognizedCabo']
sizes = [masculineMaxCabo, masculineMinCabo, feminineMaxCabo, feminineMinCabo, notRecognizedCabo] 
explode = [0, 0, 0, 0, 0]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.set_title("Cabo Fish Taco")
fig.tight_layout()

labels = ['masculineMaxLindo', 'masculineMinLindo', 'feminineMaxLindo', 'feminineMinLindo', 'notRecognizedLindo']
sizes = [masculineMaxLindo, masculineMinLindo, feminineMaxLindo, feminineMinLindo, notRecognizedLindo] 
explode = [0, 0, 0, 0, 0]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.set_title("Lindo Michoacan")
fig.tight_layout()

labels = ['masculineMaxBackyard', 'masculineMinBackyard', 'feminineMaxBackyard', 'feminineMinBackyard', 'notRecognizedBackyard']
sizes = [masculineMaxBeckyard, masculineMinBeckyard, feminineMaxBeckyard, feminineMinBeckyard, notRecognizedBeckyard] 
explode = [0, 0, 0, 0, 0]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.set_title("Backyard Taco")
fig.tight_layout()

labels = ['masculineMaxFuto', 'masculineMinFuto', 'feminineMaxFuto', 'feminineMinFuto', 'notRecognizedFuto']
sizes = [masculineMaxFuto, masculineMinFuto, feminineMaxFuto, feminineMinFuto, notRecognizedFuto] 
explode = [0, 0, 0, 0, 0]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.set_title("Futo Buta")
fig.tight_layout()

labels = ['masculineMaxIchiza', 'masculineMinIchiza', 'feminineMaxIchiza', 'feminineMinIchiza', 'notRecognizedIchiza']
sizes = [masculineMaxIchiza, masculineMinIchiza, feminineMaxIchiza, feminineMinIchiza, notRecognizedIchiza] 
explode = [0, 0, 0, 0, 0]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.set_title("Ichiza")
fig.tight_layout()

labels = ['masculineMaxHarumi', 'masculineMinHarumi', 'feminineMaxHarumi', 'feminineMinHarumi', 'NotRecognizedHarumi']
sizes = [masculineMaxHarumi, masculineMinHarumi, feminineMaxHarumi, feminineMinHarumi, notRecognizedHarumi] 
explode = [0, 0, 0, 0, 0]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.set_title("Harumi Sushi")
fig.tight_layout()

# %%
masculineMaxAmerican = (masculineMaxTupelo + masculineMaxCravings + masculineMaxCulinary) / 3
masculineMinAmerican = (masculineMinTupelo + masculineMinCravings + masculineMinCulinary) / 3
femenineMaxAmerican = (femenineMaxTupelo + femenineMaxCravings + femenineMaxCulinary) / 3
femenineMinAmerican = (femenineMinTupelo + femenineMinCravings + femenineMinCulinary) / 3

masculineMaxMexican = (masculineMaxCabo + masculineMaxLindo + masculineMaxBeckyard) / 3
masculineMinMexican = (masculineMinCabo + masculineMinLindo + masculineMinBeckyard) / 3
femenineMaxMexican = (femenineMaxCabo + femenineMaxLindo + femenineMaxBeckyard) / 3
femenineMinMexican = (femenineMinCabo + femenineMinLindo + femenineMinBeckyard) / 3

masculineMaxAmerican = (masculineMaxTupelo + masculineMaxCravings + masculineMaxCulinary) / 3
masculineMinAmerican = (masculineMinTupelo + masculineMinCravings + masculineMinCulinary) / 3
femenineMaxAmerican = (femenineMaxTupelo + femenineMaxCravings + femenineMaxCulinary) / 3
femenineMinAmerican = (femenineMinTupelo + femenineMinCravings + femenineMinCulinary) / 3
