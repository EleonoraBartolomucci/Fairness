# %% [markdown]
# <a href="https://colab.research.google.com/github/EleonoraBartolomucci/Fairness/blob/master/Esperimenti/SusyPrimoEsperimentoOrizzontale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
from google.colab import auth
import json
import pandas as pd
import csv
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# file con i dati di tutti i ristoranti random
sort = 'Random'

relevance = '1n9vdCnppJGdE6M6HdKYlksuTntQYHA7P'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': relevance})
download.GetContentFile('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

# leggo il csv con pandas
tot = pd.read_csv('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

# %%
#RACCOLTA DATI

res = tot[(tot['ethnicity'] != 'Not recognized')] #assumo che i non riconosciuti siano equamente distribuiti

#Percentuali per etnia per ogni ristorante

totaleTupelo = len(res[(res['restaurant'] == 'TupeloHoney')])
whiteTupelo = ((len(res[(res['restaurant'] == 'TupeloHoney') & (res['ethnicity'] == 'white')])) * 100) / totaleTupelo
blackTupelo = ((len(res[(res['restaurant'] == 'TupeloHoney') & (res['ethnicity'] == 'black or african american')])) * 100) / totaleTupelo
hispanicTupelo = (len(res[(res['restaurant'] == 'TupeloHoney') & (res['ethnicity'] == 'hispanic, latino, or spanish origin')]) * 100) / totaleTupelo
asianTupelo = (len(res[(res['restaurant'] == 'TupeloHoney') & (res['ethnicity'] == 'asian')]) * 100) / totaleTupelo
otherTupelo = (len(res[(res['restaurant'] == 'TupeloHoney') & ((res['ethnicity'] == 'american indian or alaska native') | (res['ethnicity'] == 'middle eastern or north african') 
                                                                    | (res['ethnicity'] == 'native hawaiian or pacific islander'))]) * 100) / totaleTupelo

totaleCabo = len(res[(res['restaurant'] == 'CaboFishTaco')])
whiteCabo = ((len(res[(res['restaurant'] == 'CaboFishTaco') & (res['ethnicity'] == 'white')])) * 100) / totaleCabo
blackCabo = ((len(res[(res['restaurant'] == 'CaboFishTaco') & (res['ethnicity'] == 'black or african american')])) * 100) / totaleCabo
hispanicCabo = (len(res[(res['restaurant'] == 'CaboFishTaco') & (res['ethnicity'] == 'hispanic, latino, or spanish origin')]) * 100) / totaleCabo
asianCabo = (len(res[(res['restaurant'] == 'CaboFishTaco') & (res['ethnicity'] == 'asian')]) * 100) / totaleCabo
otherCabo = (len(res[(res['restaurant'] == 'CaboFishTaco') & ((res['ethnicity'] == 'american indian or alaska native') | (res['ethnicity'] == 'middle eastern or north african') 
                                                                    | (res['ethnicity'] == 'native hawaiian or pacific islander'))]) * 100) / totaleCabo

totaleFuto = len(res[(res['restaurant'] == 'FutoButa')])
whiteFuto = ((len(res[(res['restaurant'] == 'FutoButa') & (res['ethnicity'] == 'white')])) * 100) / totaleFuto
blackFuto = ((len(res[(res['restaurant'] == 'FutoButa') & (res['ethnicity'] == 'black or african american')])) * 100) / totaleFuto
hispanicFuto = (len(res[(res['restaurant'] == 'FutoButa') & (res['ethnicity'] == 'hispanic, latino, or spanish origin')]) * 100) / totaleFuto
asianFuto = (len(res[(res['restaurant'] == 'FutoButa') & (res['ethnicity'] == 'asian')]) * 100) / totaleFuto
otherFuto = (len(res[(res['restaurant'] == 'FutoButa') & ((res['ethnicity'] == 'american indian or alaska native') | (res['ethnicity'] == 'middle eastern or north african') 
                                                                    | (res['ethnicity'] == 'native hawaiian or pacific islander'))]) * 100) / totaleFuto

totaleCravings = len(res[(res['restaurant'] == 'CravingsBuffet')])
whiteCravings = ((len(res[(res['restaurant'] == 'CravingsBuffet') & (res['ethnicity'] == 'white')])) * 100) / totaleCravings
blackCravings = ((len(res[(res['restaurant'] == 'CravingsBuffet') & (res['ethnicity'] == 'black or african american')])) * 100) / totaleCravings
hispanicCravings = (len(res[(res['restaurant'] == 'CravingsBuffet') & (res['ethnicity'] == 'hispanic, latino, or spanish origin')]) * 100) / totaleCravings
asianCravings = (len(res[(res['restaurant'] == 'CravingsBuffet') & (res['ethnicity'] == 'asian')]) * 100) / totaleCravings
otherCravings = (len(res[(res['restaurant'] == 'CravingsBuffet') & ((res['ethnicity'] == 'american indian or alaska native') | (res['ethnicity'] == 'middle eastern or north african') 
                                                                    | (res['ethnicity'] == 'native hawaiian or pacific islander'))]) * 100) / totaleCravings

totaleLindo = len(res[(res['restaurant'] == 'LindoMichoacan')])
whiteLindo = ((len(res[(res['restaurant'] == 'LindoMichoacan') & (res['ethnicity'] == 'white')])) * 100) / totaleLindo
blackLindo = ((len(res[(res['restaurant'] == 'LindoMichoacan') & (res['ethnicity'] == 'black or african american')])) * 100) / totaleLindo
hispanicLindo = (len(res[(res['restaurant'] == 'LindoMichoacan') & (res['ethnicity'] == 'hispanic, latino, or spanish origin')]) * 100) / totaleLindo
asianLindo = (len(res[(res['restaurant'] == 'LindoMichoacan') & (res['ethnicity'] == 'asian')]) * 100) / totaleLindo
otherLindo = (len(res[(res['restaurant'] == 'LindoMichoacan') & ((res['ethnicity'] == 'american indian or alaska native') | (res['ethnicity'] == 'middle eastern or north african') 
                                                                    | (res['ethnicity'] == 'native hawaiian or pacific islander'))]) * 100) / totaleLindo

totaleIchiza = len(res[(res['restaurant'] == 'Ichiza')])
whiteIchiza = ((len(res[(res['restaurant'] == 'Ichiza') & (res['ethnicity'] == 'white')])) * 100) / totaleIchiza
blackIchiza = ((len(res[(res['restaurant'] == 'Ichiza') & (res['ethnicity'] == 'black or african american')])) * 100) / totaleIchiza
hispanicIchiza = (len(res[(res['restaurant'] == 'Ichiza') & (res['ethnicity'] == 'hispanic, latino, or spanish origin')]) * 100) / totaleIchiza
asianIchiza = (len(res[(res['restaurant'] == 'Ichiza') & (res['ethnicity'] == 'asian')]) * 100) / totaleIchiza
otherIchiza = (len(res[(res['restaurant'] == 'Ichiza') & ((res['ethnicity'] == 'american indian or alaska native') | (res['ethnicity'] == 'middle eastern or north african') 
                                                                    | (res['ethnicity'] == 'native hawaiian or pacific islander'))]) * 100) / totaleIchiza

totaleCulinary = len(res[(res['restaurant'] == 'CulinaryDropout')])
whiteCulinary = ((len(res[(res['restaurant'] == 'CulinaryDropout') & (res['ethnicity'] == 'white')])) * 100) / totaleCulinary
blackCulinary = ((len(res[(res['restaurant'] == 'CulinaryDropout') & (res['ethnicity'] == 'black or african american')])) * 100) / totaleCulinary
hispanicCulinary = (len(res[(res['restaurant'] == 'CulinaryDropout') & (res['ethnicity'] == 'hispanic, latino, or spanish origin')]) * 100) / totaleCulinary
asianCulinary = (len(res[(res['restaurant'] == 'CulinaryDropout') & (res['ethnicity'] == 'asian')]) * 100) / totaleCulinary
otherCulinary = (len(res[(res['restaurant'] == 'CulinaryDropout') & ((res['ethnicity'] == 'american indian or alaska native') | (res['ethnicity'] == 'middle eastern or north african') 
                                                                    | (res['ethnicity'] == 'native hawaiian or pacific islander'))]) * 100) / totaleCulinary
totaleBeckyard = len(res[(res['restaurant'] == 'BeckyardTaco')])
whiteBeckyard = ((len(res[(res['restaurant'] == 'BeckyardTaco') & (res['ethnicity'] == 'white')])) * 100) / totaleBeckyard
blackBeckyard = ((len(res[(res['restaurant'] == 'BeckyardTaco') & (res['ethnicity'] == 'black or african american')])) * 100) / totaleBeckyard
hispanicBeckyard = (len(res[(res['restaurant'] == 'BeckyardTaco') & (res['ethnicity'] == 'hispanic, latino, or spanish origin')]) * 100) / totaleBeckyard
asianBeckyard = (len(res[(res['restaurant'] == 'BeckyardTaco') & (res['ethnicity'] == 'asian')]) * 100) / totaleBeckyard
otherBeckyard = (len(res[(res['restaurant'] == 'BeckyardTaco') & ((res['ethnicity'] == 'american indian or alaska native') | (res['ethnicity'] == 'middle eastern or north african') 
                                                                    | (res['ethnicity'] == 'native hawaiian or pacific islander'))]) * 100) / totaleBeckyard

totaleHarumi = len(res[(res['restaurant'] == 'HarumiSushi')])
whiteHarumi = ((len(res[(res['restaurant'] == 'HarumiSushi') & (res['ethnicity'] == 'white')])) * 100) / totaleHarumi
blackHarumi = ((len(res[(res['restaurant'] == 'HarumiSushi') & (res['ethnicity'] == 'black or african american')])) * 100) / totaleHarumi
hispanicHarumi = (len(res[(res['restaurant'] == 'HarumiSushi') & (res['ethnicity'] == 'hispanic, latino, or spanish origin')]) * 100) / totaleHarumi
asianHarumi = (len(res[(res['restaurant'] == 'HarumiSushi') & (res['ethnicity'] == 'asian')]) * 100) / totaleHarumi
otherHarumi = (len(res[(res['restaurant'] == 'HarumiSushi') & ((res['ethnicity'] == 'american indian or alaska native') | (res['ethnicity'] == 'middle eastern or north african') 
                                                                    | (res['ethnicity'] == 'native hawaiian or pacific islander'))]) * 100) / totaleHarumi

# %%
labels = ['Tupelo Honey', 'Cravings Buffet', 'Culinary Dropout', 'Cabo Fish Taco', 'Lindo Michoacan', 'Backyard Taco', 'Futo Buta', 'Ichiza', 'Harumi Sushi']
white = [whiteTupelo, whiteCravings, whiteCulinary, whiteCabo, whiteLindo, whiteBeckyard, whiteFuto, whiteIchiza, whiteHarumi] 
black = [blackTupelo, blackCravings, blackCulinary, blackCabo, blackLindo, blackBeckyard, blackFuto, blackIchiza, blackHarumi] 
hispanic = [hispanicTupelo, hispanicCravings, hispanicCulinary, hispanicCabo, hispanicLindo, hispanicBeckyard, hispanicFuto, hispanicIchiza, hispanicHarumi]  
asian = [asianTupelo, asianCravings, asianCulinary, asianCabo, asianLindo, asianBeckyard, asianFuto, asianIchiza, asianHarumi]  
other = [otherTupelo, otherCravings, otherCulinary, otherCabo, otherLindo, otherBeckyard, otherFuto, otherIchiza, otherHarumi] 





labels = ['Harumi Sushi', 'Ichiza', 'Futo Buta', 'Backyard Taco', 'Lindo Michoacan', 'Cabo Fish Taco', 'Culinary Dropout', 'Cravings Buffet', 'Tupelo Honey']
white = [whiteHarumi, whiteIchiza, whiteFuto, whiteBeckyard, whiteLindo, whiteCabo, whiteCulinary, whiteCravings, whiteTupelo] 
black = [blackHarumi, blackIchiza, blackFuto, blackBeckyard, blackLindo, blackCabo, blackCulinary, blackCravings, blackTupelo] 
hispanic = [hispanicHarumi, hispanicIchiza, hispanicFuto, hispanicBeckyard, hispanicLindo, hispanicCabo, hispanicCulinary, hispanicCravings, hispanicTupelo]  
asian = [asianHarumi, asianIchiza, asianFuto, asianBeckyard, asianLindo, asianCabo, asianCulinary, asianCravings, asianTupelo] 
other = [otherHarumi, otherIchiza, otherFuto, otherBeckyard, otherLindo, otherCabo, otherCulinary, otherCravings, otherTupelo]

# %%
labels = ['Harumi Sushi', 'Ichiza', 'Futo Buta', 'Backyard Taco', 'Lindo Michoacan', 'Cabo Fish Taco', 'Culinary Dropout', 'Cravings Buffet', 'Tupelo Honey']
white = [whiteHarumi, whiteIchiza, whiteFuto, whiteBeckyard, whiteLindo, whiteCabo, whiteCulinary, whiteCravings, whiteTupelo] 
black = [blackHarumi, blackIchiza, blackFuto, blackBeckyard, blackLindo, blackCabo, blackCulinary, blackCravings, blackTupelo] 
hispanic = [hispanicHarumi, hispanicIchiza, hispanicFuto, hispanicBeckyard, hispanicLindo, hispanicCabo, hispanicCulinary, hispanicCravings, hispanicTupelo]  
asian = [asianHarumi, asianIchiza, asianFuto, asianBeckyard, asianLindo, asianCabo, asianCulinary, asianCravings, asianTupelo] 
other = [otherHarumi, otherIchiza, otherFuto, otherBeckyard, otherLindo, otherCabo, otherCulinary, otherCravings, otherTupelo] 

x = np.arange(len(labels))  # the label locations
width = 0.17  # the width of the bars

matplotlib.rcParams['figure.figsize'] = (12,17)

fig, ax = plt.subplots()
rects1 = ax.barh(x - (width*2), other, width, label='Other', color='goldenrod')
rects2 = ax.barh(x - width, asian, width, label='Asian', color='darkturquoise')
rects3 = ax.barh(x, hispanic, width, label='Hispanic, latino, or spanish origin', color='orangered')
rects4 = ax.barh(x + width, black, width, label='Black or african american', color='mediumseagreen')
rects5 = ax.barh(x + (width*2), white, width, label='White', color='darkviolet')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Percentuali', fontsize = 16)
ax.set_title('Percentuali per etnia', fontsize = 20)
ax.set_yticks(y)
ax.set_yticklabels(labels, fontsize = 16)

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        ax.text(rect.get_width() + 0.5 , rect.get_y() + 0.05, \
            str(round((rect.get_width()), 2))+'%', fontsize=11)

autolabel(rects5)
autolabel(rects4)
autolabel(rects3)
autolabel(rects2)
autolabel(rects1)

ax.margins(x=0.15)
#ax.invert_yaxis()
ax.legend(fontsize = 11.2, loc = 'upper right')

fig.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

category_names = ['White', 'Black or african american', 'Hispanic, latino, or spanish origin', 'Asian', 'Other']
results = {
    'Tupelo Honey': [whiteTupelo,  otherTupelo, blackTupelo, hispanicTupelo, asianTupelo],
    'Cravings Buffet': [whiteCravings, blackCravings, hispanicCravings, asianCravings, otherCravings],
    'Culinary Dropout': [whiteCulinary, blackCulinary, hispanicCulinary, asianCulinary, otherCulinary],
    'Cabo Fish Taco': [whiteCabo, blackCabo, hispanicCabo, asianCabo, otherCabo],
    'Lindo Michoacan': [whiteLindo, blackLindo, hispanicLindo, asianLindo, otherLindo],
    'Backyard Taco': [whiteBeckyard, blackBeckyard, hispanicBeckyard, asianBeckyard, otherBeckyard],
    'Futo Buta': [whiteFuto, blackFuto, hispanicFuto, asianFuto, otherFuto],
    'Ichiza': [whiteIchiza, blackIchiza,  hispanicIchiza, asianIchiza, otherIchiza],
    'Harumi Sushi': [whiteHarumi, blackHarumi, hispanicHarumi, asianHarumi, otherHarumi],
}


def survey(results, category_names):
    """
    Parameters
    ----------
    results : dict
        A mapping from question labels to a list of answers per category.
        It is assumed all lists contain the same number of entries and that
        it matches the length of *category_names*.
    category_names : list of str
        The category labels.
    """
    labels = list(results.keys())
    data = np.array(list(results.values()))
    data_cum = data.cumsum(axis=1)
    category_colors = ['mediumorchid',  'gold', 'limegreen', 'darkorange', 'turquoise']

    fig, ax = plt.subplots(figsize=(12, 10))
    ax.invert_yaxis()
    ax.xaxis.set_visible(False)
    #ax.set_xlim(0, np.sum(data, axis=1).max())

    for i, (colname, color) in enumerate(zip(category_names, category_colors)):
        widths = data[:, i]
        starts = data_cum[:, i] - widths
        ax.barh(labels, widths, left=starts, height=0.7,
                label=colname, color=color)
        xcenters = starts + widths / 2

        for y, (x, c) in enumerate(zip(xcenters, widths)):
           ax.text(x, y, str(round(float(c),2)) + '%', ha='center', va='center', fontsize=11)
    ax.legend(ncol=len(category_names), bbox_to_anchor=(0, 1),
              loc='lower left', fontsize='medium')

    return fig, ax


survey(results, category_names)
plt.show()

# %%
#Percentuali medie di japanese, mexican e american per ogni tipologia di ristorante
print('AMERICANI')
americanRistoranteAmerican = (americanTupelo + americanCravings + americanCulinary) / 3
print(americanTupelo)
print(americanCravings)
print(americanCulinary)
print(americanRistoranteAmerican)
print('----------------------------------------')

americanRistoranteMexican = (americanCabo + americanLindo + americanBeckyard) / 3
print(americanCabo)
print(americanLindo)
print(americanBeckyard)
print(americanRistoranteMexican)
print('----------------------------------------')

americanRistoranteJapanese = (americanFuto + americanIchiza + americanHarumi) / 3
print(americanFuto)
print(americanIchiza)
print(americanHarumi)
print(americanRistoranteJapanese)
print('----------------------------------------')

print('MESSICANI')
mexicanRistoranteAmerican = (mexicanTupelo + mexicanCravings + mexicanCulinary) / 3
print(mexicanTupelo)
print(mexicanCravings)
print(mexicanCulinary)
print(mexicanRistoranteAmerican)
print('----------------------------------------')

mexicanRistoranteMexican = (mexicanCabo + mexicanLindo + mexicanBeckyard) / 3
print(mexicanCabo)
print(mexicanLindo)
print(mexicanBeckyard)
print(mexicanRistoranteMexican)
print('----------------------------------------')

mexicanRistoranteJapanese = (mexicanFuto + mexicanIchiza + mexicanHarumi) / 3
print(mexicanFuto)
print(mexicanIchiza)
print(mexicanHarumi)
print(mexicanRistoranteJapanese)
print('----------------------------------------')

print('GIAPPONESI')
japaneseRistoranteAmerican = (japaneseTupelo + japaneseCravings + japaneseCulinary) / 3
print(japaneseTupelo)
print(japaneseCravings)
print(japaneseCulinary)
print(japaneseRistoranteAmerican)
print('----------------------------------------')

japaneseRistoranteMexican = (japaneseCabo + japaneseLindo + japaneseBeckyard) / 3
print(japaneseCabo)
print(japaneseLindo)
print(japaneseBeckyard)
print(japaneseRistoranteMexican)
print('----------------------------------------')

japaneseRistoranteJapanese = (japaneseFuto + japaneseIchiza + japaneseHarumi) / 3
print(japaneseFuto)
print(japaneseIchiza)
print(japaneseHarumi)
print(japaneseRistoranteJapanese)
print('----------------------------------------')
# Out:
# AMERICANI
# 44.83747609942639
# 30.34300791556728
# 41.236586612161474
# 38.80569020905171
# ----------------------------------------
# 51.574803149606296
# 31.25437981779958
# 35.78643578643579
# 39.538539584613886
# ----------------------------------------
# 40.24096385542169
# 17.76750330250991
# 31.782945736434108
# 29.93047096478857
# ----------------------------------------
# MESSICANI
# 5.975143403441683
# 6.926121372031663
# 8.840061318344405
# 7.24710869793925
# ----------------------------------------
# 7.322834645669292
# 12.824106517168886
# 11.904761904761905
# 10.683901022533362
# ----------------------------------------
# 8.112449799196787
# 7.397622192866579
# 9.020436927413671
# 8.176836306492346
# ----------------------------------------
# GIAPPONESI
# 6.21414913957935
# 19.32717678100264
# 8.891159938681655
# 11.477495286421215
# ----------------------------------------
# 6.2204724409448815
# 9.039943938332165
# 5.339105339105339
# 6.866507239460795
# ...

# %%
labels = ['Cucina Giapponese', 'Cucina Messicana','Cucina Americana']
american = [americanRistoranteJapanese, americanRistoranteMexican, americanRistoranteAmerican] 
mexican = [mexicanRistoranteJapanese, mexicanRistoranteMexican, mexicanRistoranteAmerican]
japanese = [japaneseRistoranteJapanese, japaneseRistoranteMexican, japaneseRistoranteAmerican]

y = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

matplotlib.rcParams['figure.figsize'] = (10,6)

fig, ax = plt.subplots()
rects1 = ax.barh(x - width, american, width, label='white or black or african american')
rects2 = ax.barh(x, mexican, width, label='hispanic, latino, or spanish origin')
rects3 = ax.barh(x + width, japanese, width, label='asian')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Percentuali', fontsize = 16)
ax.set_title('Percentuali per etnia e cucina', fontsize = 20)
ax.set_yticks(y)
ax.set_yticklabels(labels, fontsize = 16)

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        ax.text(rect.get_width() + 0.5 , rect.get_y() + 0.05, \
            str(round((rect.get_width()), 2))+'%', fontsize=19)

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

ax.margins(x=0.17)
ax.legend(fontsize = 12, loc = 'upper right')

fig.tight_layout()

plt.show()

# %%
#Percentuali medie di japanese, mexican e american per ogni zona
print('AMERICANI')
americanZonaNC = (americanTupelo + americanCabo + americanFuto) / 3
print(americanTupelo)
print(americanCabo)
print(americanFuto)
print(americanZonaNC)
print('----------------------------------------')

americanZonaNV = (americanCravings + americanLindo + americanIchiza) / 3
print(americanCravings)
print(americanLindo)
print(americanIchiza)
print(americanZonaNV)
print('----------------------------------------')

americanZonaAZ = (americanCulinary + americanBeckyard + americanHarumi) / 3
print(americanCulinary)
print(americanBeckyard)
print(americanHarumi)
print(americanZonaAZ)
print('----------------------------------------')

print('MESSICANI')
mexicanZonaNC = (mexicanTupelo + mexicanCabo + mexicanFuto) / 3
print(mexicanTupelo)
print(mexicanCabo)
print(mexicanFuto)
print(mexicanZonaNC)
print('----------------------------------------')

mexicanZonaNV = (mexicanCravings + mexicanLindo + mexicanIchiza) / 3
print(mexicanCravings)
print(mexicanLindo)
print(mexicanIchiza)
print(mexicanZonaNV)
print('----------------------------------------')

mexicanZonaAZ = (mexicanCulinary + mexicanBeckyard + mexicanHarumi) / 3
print(mexicanCulinary)
print(mexicanBeckyard)
print(mexicanHarumi)
print(mexicanZonaAZ)
print('----------------------------------------')

print('GIAPPONESI')
japaneseZonaNC = (japaneseTupelo + japaneseCabo + japaneseFuto) / 3
print(japaneseTupelo)
print(japaneseCabo)
print(japaneseFuto)
print(japaneseZonaNC)
print('----------------------------------------')

japaneseZonaNV = (japaneseCravings + japaneseLindo + japaneseIchiza) / 3
print(japaneseCravings)
print(japaneseLindo)
print(japaneseIchiza)
print(japaneseZonaNV)
print('----------------------------------------')

japaneseZonaAZ = (japaneseCulinary + japaneseBeckyard + japaneseHarumi) / 3
print(japaneseCulinary)
print(japaneseBeckyard)
print(japaneseHarumi)
print(japaneseZonaAZ)
print('----------------------------------------')
# Out:
# AMERICANI
# 44.83747609942639
# 51.574803149606296
# 40.24096385542169
# 45.55108103481812
# ----------------------------------------
# 30.34300791556728
# 31.25437981779958
# 17.76750330250991
# 26.45496367862559
# ----------------------------------------
# 41.236586612161474
# 35.78643578643579
# 31.782945736434108
# 36.26865604501046
# ----------------------------------------
# MESSICANI
# 5.975143403441683
# 7.322834645669292
# 8.112449799196787
# 7.136809282769254
# ----------------------------------------
# 6.926121372031663
# 12.824106517168886
# 7.397622192866579
# 9.049283360689042
# ----------------------------------------
# 8.840061318344405
# 11.904761904761905
# 9.020436927413671
# 9.92175338350666
# ----------------------------------------
# GIAPPONESI
# 6.21414913957935
# 6.2204724409448815
# 13.57429718875502
# 8.66963958975975
# ----------------------------------------
# 19.32717678100264
# 9.039943938332165
# 32.694848084544255
# 20.35398960129302
# ...

# %%
labels = ['Arizona', 'Nevada','Nord Carolina']
american = [americanZonaAZ, americanZonaNV, americanZonaNC] 
mexican = [mexicanZonaAZ, mexicanZonaNV, mexicanZonaNC]
japanese = [japaneseZonaAZ, japaneseZonaNV, japaneseZonaNC]

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

matplotlib.rcParams['figure.figsize'] = (10,6)

fig, ax = plt.subplots()
rects1 = ax.barh(x - width, american, width, label='white or black or african american')
rects2 = ax.barh(x, mexican, width, label='hispanic, latino, or spanish origin')
rects3 = ax.barh(x + width, japanese, width, label='asian')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Percentuali', fontsize = 16)
ax.set_title('Percentuali per etnia e stato', fontsize = 20)
ax.set_yticks(y)
ax.set_yticklabels(labels, fontsize = 16)

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        ax.text(rect.get_width() + 0.5 , rect.get_y() + 0.05, \
            str(round((rect.get_width()), 2))+'%', fontsize=19)

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

ax.margins(x=0.17)
ax.legend(fontsize = 12, loc = 'upper right')

fig.tight_layout()

plt.show()
