# %% [markdown]
# <a href="https://colab.research.google.com/github/EleonoraBartolomucci/Fairness/blob/master/Esperimenti/MelaTerzoEsperimentoRaggruppamentoPerEtnia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
from google.colab import auth
import json
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

sort = 'Relevance'

relevance = '1nwGbyk8q2S-0BkLcyFVqdK6emTooxHJv'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': relevance})
download.GetContentFile('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

dfr = pd.read_csv('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

sort = 'Date'

date = '1Pb2It9WPid9Irjp6bRVgCF7B3Y5ARBjT'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': date})
download.GetContentFile('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

dfd = pd.read_csv('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

# %%
#elimimo i non riconosciuti
dfr = dfr[(dfr['age'] != 'Not recognized')]
#converto l'eta in numero
dfr['age'] = pd.to_numeric(dfr['age'], errors='coerce').fillna(0).astype(np.int64)
dfr = dfr[(dfr['age']!= 0 )]

#elimimo i non riconosciuti
dfd = dfd[((dfd['age'] != 'Not recognized'))]
#converto l'età in nuemro
dfd['age'] = pd.to_numeric(dfd['age'], errors='coerce').fillna(0).astype(np.int64)
dfr = dfr[(dfr['age']!= 0 )]

# %%
primo_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==1)]) 
primo_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==1)])
primo_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==1)]) 
primo_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==1)]) 

secondo_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==2)]) 
secondo_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==2)]) 
secondo_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==2)]) 
secondo_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==2)]) 

terzo_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==3)]) 
terzo_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==3)]) 
terzo_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==3)]) 
terzo_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==3)]) 

quarto_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==4)]) 
quarto_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==4)]) 
quarto_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==4)]) 
quarto_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==4)]) 

quinto_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==5)]) 
quinto_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==5)]) 
quinto_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==5)]) 
quinto_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==5)]) 

sesto_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==6)]) 
sesto_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==6)]) 
sesto_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==6)]) 
sesto_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==6)]) 

settimo_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==7)]) 
settimo_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==7)]) 
settimo_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==7)]) 
settimo_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==7)]) 

ottavo_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==8)]) 
ottavo_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==8)]) 
ottavo_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==8)]) 
ottavo_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==8)]) 

nono_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==9)]) 
nono_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==9)]) 
nono_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==9)]) 
nono_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==9)]) 

decimo_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==10)]) 
decimo_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==10)]) 
decimo_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==10)]) 
decimo_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==10)]) 

undicesimo_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==11)]) 
undicesimo_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==11)]) 
undicesimo_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==11)]) 
undicesimo_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==11)]) 

dodicesimo_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==12)]) 
dodicesimo_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==12)]) 
dodicesimo_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==12)]) 
dodicesimo_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==12)]) 

tredi_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==13)]) 
tredi_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==13)]) 
tredi_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==13)]) 
tredi_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==13)]) 

quattordi_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==14)]) 
quattordi_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==14)]) 
quattordi_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==14)]) 
quattordi_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==14)]) 

quindi_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==15)]) 
quindi_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==15)]) 
quindi_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==15)]) 
quindi_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==15)]) 

sedi_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==16)]) 
sedi_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==16)]) 
sedi_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==16)]) 
sedi_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==16)]) 

dicia_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==17)]) 
dicia_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==17)]) 
dicia_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==17)]) 
dicia_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==17)]) 

dicio_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==18)]) 
dicio_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==18)]) 
dicio_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==18)]) 
dicio_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==18)]) 

dician_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==19)]) 
dician_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==19)]) 
dician_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==19)]) 
dician_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==19)]) 

venti_undertrenta_relevance = len(dfr[(dfr['age']<=30) & (dfr['number']==20)]) 
venti_trentaquaranta_relevance = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==20)]) 
venti_quarantacinquanta_relevance = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==20)]) 
venti_overcinquanta_relevance = len(dfr[(dfr['age']>=55) & (dfr['number']==20)])

# %%
primo_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==1)]) 
primo_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==1)])
primo_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==1)]) 
primo_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==1)]) 

secondo_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==2)]) 
secondo_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==2)]) 
secondo_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==2)]) 
secondo_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==2)]) 

terzo_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==3)]) 
terzo_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==3)]) 
terzo_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==3)]) 
terzo_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==3)]) 

quarto_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==4)]) 
quarto_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==4)]) 
quarto_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==4)]) 
quarto_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==4)]) 

quinto_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==5)]) 
quinto_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==5)]) 
quinto_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==5)]) 
quinto_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==5)]) 

sesto_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==6)]) 
sesto_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==6)]) 
sesto_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==6)]) 
sesto_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==6)]) 

settimo_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==7)]) 
settimo_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==7)]) 
settimo_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==7)]) 
settimo_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==7)]) 

ottavo_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==8)]) 
ottavo_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==8)]) 
ottavo_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==8)]) 
ottavo_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==8)]) 

nono_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==9)]) 
nono_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==9)]) 
nono_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==9)]) 
nono_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==9)]) 

decimo_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==10)]) 
decimo_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==10)]) 
decimo_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==10)]) 
decimo_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==10)]) 

undicesimo_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==11)]) 
undicesimo_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==11)]) 
undicesimo_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==11)]) 
undicesimo_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==11)]) 

dodicesimo_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==12)]) 
dodicesimo_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==12)]) 
dodicesimo_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==12)]) 
dodicesimo_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==12)]) 

tredi_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==13)]) 
tredi_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==13)]) 
tredi_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==13)]) 
tredi_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==13)]) 

quattordi_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==14)]) 
quattordi_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==14)]) 
quattordi_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==14)]) 
quattordi_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==14)]) 

quindi_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==15)]) 
quindi_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==15)]) 
quindi_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==15)]) 
quindi_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==15)]) 

sedi_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==16)]) 
sedi_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==16)]) 
sedi_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==16)]) 
sedi_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==16)]) 

dicia_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==17)]) 
dicia_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==17)]) 
dicia_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==17)]) 
dicia_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==17)]) 

dicio_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==18)]) 
dicio_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==18)]) 
dicio_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==18)]) 
dicio_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==18)]) 

dician_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==19)]) 
dician_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==19)]) 
dician_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==19)]) 
dician_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==19)]) 

venti_undertrenta_data = len(dfd[(dfd['age']<=30) & (dfd['number']==20)]) 
venti_trentaquaranta_data = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==20)]) 
venti_quarantacinquanta_data = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==20)]) 
venti_overcinquanta_data = len(dfd[(dfd['age']>=55) & (dfd['number']==20)])

# %%
#================COSTRUISCO GRAFICO RELEVANCE=====================
plt.subplot()
#fig, ax = plt.subplots()

#=======<30=======
plt.scatter(1, 1, s=primo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 2, s = secondo_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 3, s=terzo_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 4, s=quarto_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 5, s = quinto_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 6, s=sesto_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 7, s=settimo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 8, s = ottavo_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 9, s=nono_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 10, s=decimo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 11, s=undicesimo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 12, s = dodicesimo_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 13, s=tredi_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 14, s=quattordi_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 15, s = quindi_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 16, s=sedi_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 17, s=dicia_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 18, s = dicio_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 19, s=dician_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 20, s=venti_undertrenta_relevance*30, color= 'blue' , alpha=0.5)

#====30-40=====
plt.scatter(5, 1, s=primo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 2, s = secondo_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 3, s=terzo_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 4, s=quarto_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 5, s = quinto_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 6, s=sesto_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 7, s=settimo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 8, s = ottavo_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 9, s=nono_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 10, s=decimo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 11, s=undicesimo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 12, s = dodicesimo_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 13, s=tredi_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 14, s=quattordi_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 15, s = quindi_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 16, s=sedi_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 17, s=dicia_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 18, s = dicio_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 19, s=dician_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 20, s=venti_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)



#======40-55=========
plt.scatter(9, 1, s=primo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 2, s = secondo_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 3, s=terzo_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 4, s=quarto_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 5, s = quinto_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 6, s=sesto_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 7, s=settimo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 8, s = ottavo_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 9, s=nono_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 10, s=decimo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 11, s=undicesimo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 12, s = dodicesimo_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 13, s=tredi_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 14, s=quattordi_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 15, s = quindi_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 16, s=sedi_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 17, s=dicia_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 18, s = dicio_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 19, s=dician_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 20, s=venti_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)


#========>55=======
plt.scatter(13, 1, s=primo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 2, s = secondo_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 3, s=terzo_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 4, s=quarto_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 5, s = quinto_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 6, s=sesto_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 7, s=settimo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 8, s = ottavo_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 9, s=nono_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 10, s=decimo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 11, s=undicesimo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 12, s = dodicesimo_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 13, s=tredi_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 14, s=quattordi_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 15, s = quindi_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 16, s=sedi_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 17, s=dicia_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 18, s = dicio_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 19, s=dician_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 20, s=venti_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)

#=======<30=======
plt.scatter(1.5, 1, s=primo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 2, s = secondo_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 3, s=terzo_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 4, s=quarto_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 5, s = quinto_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 6, s=sesto_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 7, s=settimo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 8, s = ottavo_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 9, s=nono_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 10, s=decimo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 11, s=undicesimo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 12, s = dodicesimo_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 13, s=tredi_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 14, s=quattordi_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 15, s = quindi_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 16, s=sedi_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 17, s=dicia_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 18, s = dicio_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 19, s=dician_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 20, s=venti_undertrenta_data*30, color= 'blue' , alpha=0.5)


#====30-40=====
plt.scatter(5.5, 1, s=primo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 2, s = secondo_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 3, s=terzo_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 4, s=quarto_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 5, s = quinto_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 6, s=sesto_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 7, s=settimo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 8, s = ottavo_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 9, s=nono_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 10, s=decimo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 11, s=undicesimo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 12, s = dodicesimo_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 13, s=tredi_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 14, s=quattordi_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 15, s = quindi_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 16, s=sedi_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 17, s=dicia_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 18, s = dicio_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 19, s=dician_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 20, s=venti_trentaquaranta_data*30, color= 'green' , alpha=0.5)


#======40-55=========
plt.scatter(9.5, 1, s=primo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 2, s = secondo_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 3, s=terzo_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 4, s=quarto_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 5, s = quinto_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 6, s=sesto_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 7, s=settimo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 8, s = ottavo_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 9, s=nono_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 10, s=decimo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 11, s=undicesimo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 12, s = dodicesimo_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 13, s=tredi_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 14, s=quattordi_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 15, s = quindi_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 16, s=sedi_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 17, s=dicia_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 18, s = dicio_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 19, s=dician_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 20, s=venti_quarantacinquanta_data*30, color= 'red' , alpha=0.5)


#========>55=======
plt.scatter(13.5, 1, s=primo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 2, s = secondo_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 3, s=terzo_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 4, s=quarto_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 5, s = quinto_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 6, s=sesto_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 7, s=settimo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 8, s = ottavo_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 9, s=nono_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 10, s=decimo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 11, s=undicesimo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 12, s = dodicesimo_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 13, s=tredi_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 14, s=quattordi_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 15, s = quindi_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 16, s=sedi_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 17, s=dicia_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 18, s = dicio_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 19, s=dician_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 20, s=venti_overcinquanta_data*30, color= 'orange' , alpha=0.5)


#=======RIFINITURE========
plt.hlines(y=11, xmin=0.85, xmax=14.15)

plt.title('Distribuzione demografica nelle prime 20 posizioni secondo ordinamento Relevance e data')
plt.ylabel('Posizione in classifica', labelpad = 16)
plt.xlabel('Fascia di età' , labelpad = 16)
#setta ogni quante y ti fa vedere
plt.yticks(np.arange(0, 20, 5.0))
plt.xticks(np.arange(1, 14, 1.0))
plt.xticks([1,1.5,5,5.5,9,9.5,13,13.5],['Relevance','Data','Relevance','Data','Relevance','Data','Relevance','Data','Relevance','Data'],rotation=90)
plt.show()

# %%
#===================RELEVANCE RISTORANTI AMERICANI=======
dfrA = dfr[(dfr['typology']=='American')]
primo_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==1)]) 
primo_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==1)])
primo_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==1)]) 
primo_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==1)]) 

secondo_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==2)]) 
secondo_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==2)]) 
secondo_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==2)]) 
secondo_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==2)]) 

terzo_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==3)]) 
terzo_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==3)]) 
terzo_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==3)]) 
terzo_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==3)]) 

quarto_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==4)]) 
quarto_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==4)]) 
quarto_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==4)]) 
quarto_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==4)]) 

quinto_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==5)]) 
quinto_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==5)]) 
quinto_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==5)]) 
quinto_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==5)]) 

sesto_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==6)]) 
sesto_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==6)]) 
sesto_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==6)]) 
sesto_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==6)]) 

settimo_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==7)]) 
settimo_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==7)]) 
settimo_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==7)]) 
settimo_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==7)]) 

ottavo_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==8)]) 
ottavo_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==8)]) 
ottavo_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==8)]) 
ottavo_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==8)]) 

nono_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==9)]) 
nono_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==9)]) 
nono_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==9)]) 
nono_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==9)]) 

decimo_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==10)]) 
decimo_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==10)]) 
decimo_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==10)]) 
decimo_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==10)]) 

undicesimo_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==11)]) 
undicesimo_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==11)]) 
undicesimo_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==11)]) 
undicesimo_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==11)]) 

dodicesimo_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==12)]) 
dodicesimo_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==12)]) 
dodicesimo_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==12)]) 
dodicesimo_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==12)]) 

tredi_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==13)]) 
tredi_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==13)]) 
tredi_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==13)]) 
tredi_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==13)]) 

quattordi_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==14)]) 
quattordi_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==14)]) 
quattordi_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==14)]) 
quattordi_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==14)]) 

quindi_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==15)]) 
quindi_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==15)]) 
quindi_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==15)]) 
quindi_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==15)]) 

sedi_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==16)]) 
sedi_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==16)]) 
sedi_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==16)]) 
sedi_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==16)]) 

dicia_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==17)]) 
dicia_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==17)]) 
dicia_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==17)]) 
dicia_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==17)]) 

dicio_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==18)]) 
dicio_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==18)]) 
dicio_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==18)]) 
dicio_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==18)]) 

dician_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==19)]) 
dician_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==19)]) 
dician_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==19)]) 
dician_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==19)]) 

venti_undertrenta_relevance = len(dfrA[(dfrA['age']<=30) & (dfrA['number']==20)]) 
venti_trentaquaranta_relevance = len(dfrA[(dfrA['age']>30) & (dfrA['age']<40) & (dfrA['number']==20)]) 
venti_quarantacinquanta_relevance = len(dfrA[(dfrA['age']>=40) & (dfrA['age']<55) & (dfrA['number']==20)]) 
venti_overcinquanta_relevance = len(dfrA[(dfrA['age']>=55) & (dfrA['number']==20)])





#===================DATA RISTORANTI AMERICANI=======
dfdA = dfd[(dfd['typology']=='American')]
primo_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==1)]) 
primo_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==1)])
primo_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==1)]) 
primo_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==1)]) 

secondo_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==2)]) 
secondo_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==2)]) 
secondo_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==2)]) 
secondo_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==2)]) 

terzo_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==3)]) 
terzo_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==3)]) 
terzo_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==3)]) 
terzo_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==3)]) 

quarto_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==4)]) 
quarto_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==4)]) 
quarto_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==4)]) 
quarto_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==4)]) 

quinto_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==5)]) 
quinto_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==5)]) 
quinto_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==5)]) 
quinto_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==5)]) 

sesto_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==6)]) 
sesto_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==6)]) 
sesto_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==6)]) 
sesto_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==6)]) 

settimo_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==7)]) 
settimo_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==7)]) 
settimo_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==7)]) 
settimo_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==7)]) 

ottavo_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==8)]) 
ottavo_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==8)]) 
ottavo_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==8)]) 
ottavo_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==8)]) 

nono_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==9)]) 
nono_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==9)]) 
nono_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==9)]) 
nono_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==9)]) 

decimo_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==10)]) 
decimo_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==10)]) 
decimo_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==10)]) 
decimo_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==10)]) 

undicesimo_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==11)]) 
undicesimo_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==11)]) 
undicesimo_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==11)]) 
undicesimo_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==11)]) 

dodicesimo_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==12)]) 
dodicesimo_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==12)]) 
dodicesimo_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==12)]) 
dodicesimo_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==12)]) 

tredi_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==13)]) 
tredi_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==13)]) 
tredi_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==13)]) 
tredi_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==13)]) 

quattordi_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==14)]) 
quattordi_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==14)]) 
quattordi_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==14)]) 
quattordi_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==14)]) 

quindi_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==15)]) 
quindi_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==15)]) 
quindi_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==15)]) 
quindi_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==15)]) 

sedi_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==16)]) 
sedi_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==16)]) 
sedi_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==16)]) 
sedi_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==16)]) 

dicia_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==17)]) 
dicia_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==17)]) 
dicia_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==17)]) 
dicia_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==17)]) 

dicio_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==18)]) 
dicio_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==18)]) 
dicio_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==18)]) 
dicio_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==18)]) 

dician_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==19)]) 
dician_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==19)]) 
dician_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==19)]) 
dician_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==19)]) 

venti_undertrenta_data = len(dfdA[(dfdA['age']<=30) & (dfdA['number']==20)]) 
venti_trentaquaranta_data = len(dfdA[(dfdA['age']>30) & (dfdA['age']<40) & (dfdA['number']==20)]) 
venti_quarantacinquanta_data = len(dfdA[(dfdA['age']>=40) & (dfdA['age']<55) & (dfdA['number']==20)]) 
venti_overcinquanta_data = len(dfdA[(dfdA['age']>=55) & (dfdA['number']==20)])

# %%
#================COSTRUISCO GRAFICO RELEVANCE=====================
plt.subplot()
#fig, ax = plt.subplots()

#=======<30=======
plt.scatter(1, 1, s=primo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 2, s = secondo_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 3, s=terzo_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 4, s=quarto_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 5, s = quinto_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 6, s=sesto_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 7, s=settimo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 8, s = ottavo_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 9, s=nono_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 10, s=decimo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 11, s=undicesimo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 12, s = dodicesimo_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 13, s=tredi_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 14, s=quattordi_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 15, s = quindi_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 16, s=sedi_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 17, s=dicia_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 18, s = dicio_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 19, s=dician_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 20, s=venti_undertrenta_relevance*30, color= 'blue' , alpha=0.5)

#====30-40=====
plt.scatter(5, 1, s=primo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 2, s = secondo_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 3, s=terzo_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 4, s=quarto_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 5, s = quinto_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 6, s=sesto_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 7, s=settimo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 8, s = ottavo_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 9, s=nono_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 10, s=decimo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 11, s=undicesimo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 12, s = dodicesimo_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 13, s=tredi_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 14, s=quattordi_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 15, s = quindi_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 16, s=sedi_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 17, s=dicia_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 18, s = dicio_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 19, s=dician_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 20, s=venti_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)



#======40-55=========
plt.scatter(9, 1, s=primo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 2, s = secondo_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 3, s=terzo_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 4, s=quarto_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 5, s = quinto_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 6, s=sesto_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 7, s=settimo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 8, s = ottavo_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 9, s=nono_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 10, s=decimo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 11, s=undicesimo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 12, s = dodicesimo_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 13, s=tredi_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 14, s=quattordi_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 15, s = quindi_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 16, s=sedi_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 17, s=dicia_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 18, s = dicio_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 19, s=dician_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 20, s=venti_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)


#========>55=======
plt.scatter(13, 1, s=primo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 2, s = secondo_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 3, s=terzo_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 4, s=quarto_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 5, s = quinto_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 6, s=sesto_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 7, s=settimo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 8, s = ottavo_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 9, s=nono_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 10, s=decimo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 11, s=undicesimo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 12, s = dodicesimo_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 13, s=tredi_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 14, s=quattordi_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 15, s = quindi_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 16, s=sedi_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 17, s=dicia_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 18, s = dicio_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 19, s=dician_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 20, s=venti_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)

#=======<30=======
plt.scatter(1.5, 1, s=primo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 2, s = secondo_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 3, s=terzo_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 4, s=quarto_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 5, s = quinto_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 6, s=sesto_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 7, s=settimo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 8, s = ottavo_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 9, s=nono_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 10, s=decimo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 11, s=undicesimo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 12, s = dodicesimo_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 13, s=tredi_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 14, s=quattordi_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 15, s = quindi_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 16, s=sedi_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 17, s=dicia_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 18, s = dicio_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 19, s=dician_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 20, s=venti_undertrenta_data*30, color= 'blue' , alpha=0.5)


#====30-40=====
plt.scatter(5.5, 1, s=primo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 2, s = secondo_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 3, s=terzo_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 4, s=quarto_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 5, s = quinto_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 6, s=sesto_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 7, s=settimo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 8, s = ottavo_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 9, s=nono_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 10, s=decimo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 11, s=undicesimo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 12, s = dodicesimo_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 13, s=tredi_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 14, s=quattordi_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 15, s = quindi_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 16, s=sedi_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 17, s=dicia_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 18, s = dicio_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 19, s=dician_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 20, s=venti_trentaquaranta_data*30, color= 'green' , alpha=0.5)


#======40-55=========
plt.scatter(9.5, 1, s=primo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 2, s = secondo_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 3, s=terzo_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 4, s=quarto_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 5, s = quinto_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 6, s=sesto_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 7, s=settimo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 8, s = ottavo_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 9, s=nono_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 10, s=decimo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 11, s=undicesimo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 12, s = dodicesimo_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 13, s=tredi_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 14, s=quattordi_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 15, s = quindi_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 16, s=sedi_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 17, s=dicia_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 18, s = dicio_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 19, s=dician_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 20, s=venti_quarantacinquanta_data*30, color= 'red' , alpha=0.5)


#========>55=======
plt.scatter(13.5, 1, s=primo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 2, s = secondo_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 3, s=terzo_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 4, s=quarto_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 5, s = quinto_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 6, s=sesto_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 7, s=settimo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 8, s = ottavo_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 9, s=nono_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 10, s=decimo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 11, s=undicesimo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 12, s = dodicesimo_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 13, s=tredi_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 14, s=quattordi_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 15, s = quindi_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 16, s=sedi_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 17, s=dicia_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 18, s = dicio_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 19, s=dician_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 20, s=venti_overcinquanta_data*30, color= 'orange' , alpha=0.5)


#=======RIFINITURE========
plt.hlines(y=11, xmin=0.85, xmax=14.15)

plt.title('Distribuzione demografica nelle prime 20 posizioni secondo ordinamento Relevance e data in ristoranti americani')
plt.ylabel('Posizione in classifica', labelpad = 16)
plt.xlabel('Fascia di età' , labelpad = 16)
#setta ogni quante y ti fa vedere
plt.yticks(np.arange(0, 20, 5.0))
plt.xticks(np.arange(1, 14, 1.0))
plt.xticks([1,1.5,5,5.5,9,9.5,13,13.5],['Relevance','Data','Relevance','Data','Relevance','Data','Relevance','Data','Relevance','Data'],rotation=90)
plt.show()

# %%
#===================RELEVANCE RISTORANTI GIAPPONESI=======
dfrJ = dfr[(dfr['typology']=='Japanese')]
primo_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==1)]) 
primo_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==1)])
primo_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==1)]) 
primo_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==1)]) 

secondo_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==2)]) 
secondo_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==2)]) 
secondo_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==2)]) 
secondo_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==2)]) 

terzo_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==3)]) 
terzo_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==3)]) 
terzo_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==3)]) 
terzo_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==3)]) 

quarto_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==4)]) 
quarto_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==4)]) 
quarto_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==4)]) 
quarto_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==4)]) 

quinto_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==5)]) 
quinto_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==5)]) 
quinto_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==5)]) 
quinto_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==5)]) 

sesto_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==6)]) 
sesto_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==6)]) 
sesto_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==6)]) 
sesto_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==6)]) 

settimo_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==7)]) 
settimo_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==7)]) 
settimo_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==7)]) 
settimo_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==7)]) 

ottavo_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==8)]) 
ottavo_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==8)]) 
ottavo_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==8)]) 
ottavo_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==8)]) 

nono_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==9)]) 
nono_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==9)]) 
nono_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==9)]) 
nono_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==9)]) 

decimo_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==10)]) 
decimo_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==10)]) 
decimo_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==10)]) 
decimo_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==10)]) 

undicesimo_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==11)]) 
undicesimo_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==11)]) 
undicesimo_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==11)]) 
undicesimo_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==11)]) 

dodicesimo_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==12)]) 
dodicesimo_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==12)]) 
dodicesimo_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==12)]) 
dodicesimo_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==12)]) 

tredi_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==13)]) 
tredi_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==13)]) 
tredi_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==13)]) 
tredi_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==13)]) 

quattordi_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==14)]) 
quattordi_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==14)]) 
quattordi_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==14)]) 
quattordi_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==14)]) 

quindi_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==15)]) 
quindi_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==15)]) 
quindi_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==15)]) 
quindi_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==15)]) 

sedi_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==16)]) 
sedi_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==16)]) 
sedi_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==16)]) 
sedi_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==16)]) 

dicia_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==17)]) 
dicia_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==17)]) 
dicia_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==17)]) 
dicia_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==17)]) 

dicio_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==18)]) 
dicio_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==18)]) 
dicio_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==18)]) 
dicio_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==18)]) 

dician_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==19)]) 
dician_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==19)]) 
dician_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==19)]) 
dician_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==19)]) 

venti_undertrenta_relevance = len(dfrJ[(dfrJ['age']<=30) & (dfrJ['number']==20)]) 
venti_trentaquaranta_relevance = len(dfrJ[(dfrJ['age']>30) & (dfrJ['age']<40) & (dfrJ['number']==20)]) 
venti_quarantacinquanta_relevance = len(dfrJ[(dfrJ['age']>=40) & (dfrJ['age']<55) & (dfrJ['number']==20)]) 
venti_overcinquanta_relevance = len(dfrJ[(dfrJ['age']>=55) & (dfrJ['number']==20)])




#===================DATA RISTORANTI GIAPPONESI=======
dfdJ = dfd[(dfd['typology']=='Japanese')]
primo_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==1)]) 
primo_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==1)])
primo_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==1)]) 
primo_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==1)]) 

secondo_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==2)]) 
secondo_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==2)]) 
secondo_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==2)]) 
secondo_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==2)]) 

terzo_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==3)]) 
terzo_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==3)]) 
terzo_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==3)]) 
terzo_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==3)]) 

quarto_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==4)]) 
quarto_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==4)]) 
quarto_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==4)]) 
quarto_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==4)]) 

quinto_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==5)]) 
quinto_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==5)]) 
quinto_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==5)]) 
quinto_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==5)]) 

sesto_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==6)]) 
sesto_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==6)]) 
sesto_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==6)]) 
sesto_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==6)]) 

settimo_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==7)]) 
settimo_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==7)]) 
settimo_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==7)]) 
settimo_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==7)]) 

ottavo_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==8)]) 
ottavo_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==8)]) 
ottavo_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==8)]) 
ottavo_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==8)]) 

nono_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==9)]) 
nono_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==9)]) 
nono_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==9)]) 
nono_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==9)]) 

decimo_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==10)]) 
decimo_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==10)]) 
decimo_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==10)]) 
decimo_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==10)]) 

undicesimo_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==11)]) 
undicesimo_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==11)]) 
undicesimo_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==11)]) 
undicesimo_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==11)]) 

dodicesimo_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==12)]) 
dodicesimo_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==12)]) 
dodicesimo_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==12)]) 
dodicesimo_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==12)]) 

tredi_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==13)]) 
tredi_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==13)]) 
tredi_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==13)]) 
tredi_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==13)]) 

quattordi_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==14)]) 
quattordi_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==14)]) 
quattordi_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==14)]) 
quattordi_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==14)]) 

quindi_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==15)]) 
quindi_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==15)]) 
quindi_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==15)]) 
quindi_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==15)]) 

sedi_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==16)]) 
sedi_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==16)]) 
sedi_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==16)]) 
sedi_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==16)]) 

dicia_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==17)]) 
dicia_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==17)]) 
dicia_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==17)]) 
dicia_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==17)]) 

dicio_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==18)]) 
dicio_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==18)]) 
dicio_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==18)]) 
dicio_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==18)]) 

dician_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==19)]) 
dician_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==19)]) 
dician_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==19)]) 
dician_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==19)]) 

venti_undertrenta_data = len(dfdJ[(dfdJ['age']<=30) & (dfdJ['number']==20)]) 
venti_trentaquaranta_data = len(dfdJ[(dfdJ['age']>30) & (dfdJ['age']<40) & (dfdJ['number']==20)]) 
venti_quarantacinquanta_data = len(dfdJ[(dfdJ['age']>=40) & (dfdJ['age']<55) & (dfdJ['number']==20)]) 
venti_overcinquanta_data = len(dfdJ[(dfdJ['age']>=55) & (dfdJ['number']==20)])
# Out:
#      restaurant  ... review_sentiment
# 5547   FutoButa  ...         positive
# 5548   FutoButa  ...         negative
# 5554   FutoButa  ...         negative
# 5555   FutoButa  ...         positive
# 5556   FutoButa  ...         positive
# ...         ...  ...              ...
# 9704     Ichiza  ...          neutral
# 9709     Ichiza  ...         positive
# 9711     Ichiza  ...         negative
# 9712     Ichiza  ...         positive
# 9713     Ichiza  ...         positive
#
# [2429 rows x 10 columns]

# %%
#================COSTRUISCO GRAFICO=====================
plt.subplot()
#fig, ax = plt.subplots()

#=======<30=======
plt.scatter(1, 1, s=primo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 2, s = secondo_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 3, s=terzo_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 4, s=quarto_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 5, s = quinto_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 6, s=sesto_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 7, s=settimo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 8, s = ottavo_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 9, s=nono_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 10, s=decimo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 11, s=undicesimo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 12, s = dodicesimo_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 13, s=tredi_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 14, s=quattordi_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 15, s = quindi_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 16, s=sedi_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 17, s=dicia_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 18, s = dicio_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 19, s=dician_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 20, s=venti_undertrenta_relevance*30, color= 'blue' , alpha=0.5)

#====30-40=====
plt.scatter(5, 1, s=primo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 2, s = secondo_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 3, s=terzo_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 4, s=quarto_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 5, s = quinto_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 6, s=sesto_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 7, s=settimo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 8, s = ottavo_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 9, s=nono_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 10, s=decimo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 11, s=undicesimo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 12, s = dodicesimo_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 13, s=tredi_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 14, s=quattordi_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 15, s = quindi_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 16, s=sedi_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 17, s=dicia_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 18, s = dicio_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 19, s=dician_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 20, s=venti_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)



#======40-55=========
plt.scatter(9, 1, s=primo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 2, s = secondo_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 3, s=terzo_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 4, s=quarto_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 5, s = quinto_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 6, s=sesto_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 7, s=settimo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 8, s = ottavo_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 9, s=nono_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 10, s=decimo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 11, s=undicesimo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 12, s = dodicesimo_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 13, s=tredi_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 14, s=quattordi_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 15, s = quindi_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 16, s=sedi_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 17, s=dicia_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 18, s = dicio_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 19, s=dician_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 20, s=venti_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)


#========>55=======
plt.scatter(13, 1, s=primo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 2, s = secondo_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 3, s=terzo_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 4, s=quarto_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 5, s = quinto_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 6, s=sesto_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 7, s=settimo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 8, s = ottavo_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 9, s=nono_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 10, s=decimo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 11, s=undicesimo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 12, s = dodicesimo_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 13, s=tredi_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 14, s=quattordi_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 15, s = quindi_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 16, s=sedi_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 17, s=dicia_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 18, s = dicio_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 19, s=dician_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 20, s=venti_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)

#=======<30=======
plt.scatter(1.5, 1, s=primo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 2, s = secondo_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 3, s=terzo_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 4, s=quarto_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 5, s = quinto_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 6, s=sesto_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 7, s=settimo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 8, s = ottavo_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 9, s=nono_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 10, s=decimo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 11, s=undicesimo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 12, s = dodicesimo_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 13, s=tredi_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 14, s=quattordi_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 15, s = quindi_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 16, s=sedi_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 17, s=dicia_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 18, s = dicio_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 19, s=dician_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 20, s=venti_undertrenta_data*30, color= 'blue' , alpha=0.5)


#====30-40=====
plt.scatter(5.5, 1, s=primo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 2, s = secondo_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 3, s=terzo_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 4, s=quarto_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 5, s = quinto_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 6, s=sesto_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 7, s=settimo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 8, s = ottavo_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 9, s=nono_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 10, s=decimo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 11, s=undicesimo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 12, s = dodicesimo_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 13, s=tredi_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 14, s=quattordi_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 15, s = quindi_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 16, s=sedi_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 17, s=dicia_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 18, s = dicio_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 19, s=dician_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 20, s=venti_trentaquaranta_data*30, color= 'green' , alpha=0.5)


#======40-55=========
plt.scatter(9.5, 1, s=primo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 2, s = secondo_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 3, s=terzo_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 4, s=quarto_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 5, s = quinto_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 6, s=sesto_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 7, s=settimo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 8, s = ottavo_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 9, s=nono_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 10, s=decimo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 11, s=undicesimo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 12, s = dodicesimo_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 13, s=tredi_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 14, s=quattordi_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 15, s = quindi_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 16, s=sedi_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 17, s=dicia_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 18, s = dicio_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 19, s=dician_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 20, s=venti_quarantacinquanta_data*30, color= 'red' , alpha=0.5)


#========>55=======
plt.scatter(13.5, 1, s=primo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 2, s = secondo_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 3, s=terzo_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 4, s=quarto_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 5, s = quinto_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 6, s=sesto_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 7, s=settimo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 8, s = ottavo_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 9, s=nono_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 10, s=decimo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 11, s=undicesimo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 12, s = dodicesimo_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 13, s=tredi_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 14, s=quattordi_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 15, s = quindi_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 16, s=sedi_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 17, s=dicia_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 18, s = dicio_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 19, s=dician_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 20, s=venti_overcinquanta_data*30, color= 'orange' , alpha=0.5)


#=======RIFINITURE========
plt.hlines(y=11, xmin=0.85, xmax=14.15)

plt.title('Distribuzione demografica nelle prime 20 posizioni secondo ordinamento Relevance e data in ristoranti giapponesi')
plt.ylabel('Posizione in classifica', labelpad = 16)
plt.xlabel('Fascia di età' , labelpad = 16)
#setta ogni quante y ti fa vedere
plt.yticks(np.arange(0, 20, 5.0))
plt.xticks(np.arange(1, 14, 1.0))
plt.xticks([1,1.5,5,5.5,9,9.5,13,13.5],['Relevance','Data','Relevance','Data','Relevance','Data','Relevance','Data','Relevance','Data'],rotation=90)
plt.show()

# %%
#===================RELEVANCE RISTORANTI MESSICANI=======
dfrM = dfr[(dfr['typology']=='Mexican')]
primo_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==1)]) 
primo_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==1)])
primo_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==1)]) 
primo_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==1)]) 

secondo_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==2)]) 
secondo_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==2)]) 
secondo_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==2)]) 
secondo_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==2)]) 

terzo_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==3)]) 
terzo_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==3)]) 
terzo_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==3)]) 
terzo_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==3)]) 

quarto_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==4)]) 
quarto_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==4)]) 
quarto_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==4)]) 
quarto_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==4)]) 

quinto_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==5)]) 
quinto_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==5)]) 
quinto_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==5)]) 
quinto_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==5)]) 

sesto_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==6)]) 
sesto_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==6)]) 
sesto_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==6)]) 
sesto_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==6)]) 

settimo_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==7)]) 
settimo_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==7)]) 
settimo_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==7)]) 
settimo_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==7)]) 

ottavo_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==8)]) 
ottavo_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==8)]) 
ottavo_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==8)]) 
ottavo_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==8)]) 

nono_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==9)]) 
nono_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==9)]) 
nono_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==9)]) 
nono_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==9)]) 

decimo_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==10)]) 
decimo_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==10)]) 
decimo_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==10)]) 
decimo_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==10)]) 

undicesimo_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==11)]) 
undicesimo_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==11)]) 
undicesimo_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==11)]) 
undicesimo_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==11)]) 

dodicesimo_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==12)]) 
dodicesimo_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==12)]) 
dodicesimo_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==12)]) 
dodicesimo_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==12)]) 

tredi_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==13)]) 
tredi_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==13)]) 
tredi_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==13)]) 
tredi_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==13)]) 

quattordi_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==14)]) 
quattordi_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==14)]) 
quattordi_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==14)]) 
quattordi_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==14)]) 

quindi_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==15)]) 
quindi_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==15)]) 
quindi_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==15)]) 
quindi_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==15)]) 

sedi_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==16)]) 
sedi_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==16)]) 
sedi_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==16)]) 
sedi_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==16)]) 

dicia_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==17)]) 
dicia_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==17)]) 
dicia_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==17)]) 
dicia_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==17)]) 

dicio_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==18)]) 
dicio_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==18)]) 
dicio_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==18)]) 
dicio_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==18)]) 

dician_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==19)]) 
dician_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==19)]) 
dician_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==19)]) 
dician_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==19)]) 

venti_undertrenta_relevance = len(dfrM[(dfrM['age']<=30) & (dfrM['number']==20)]) 
venti_trentaquaranta_relevance = len(dfrM[(dfrM['age']>30) & (dfrM['age']<40) & (dfrM['number']==20)]) 
venti_quarantacinquanta_relevance = len(dfrM[(dfrM['age']>=40) & (dfrM['age']<55) & (dfrM['number']==20)]) 
venti_overcinquanta_relevance = len(dfrM[(dfrM['age']>=55) & (dfrM['number']==20)])


#===================DATA RISTORANTI Messicani=======
dfdM = dfd[(dfd['typology']=='Mexican')]
primo_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==1)]) 
primo_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==1)])
primo_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==1)]) 
primo_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==1)]) 

secondo_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==2)]) 
secondo_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==2)]) 
secondo_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==2)]) 
secondo_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==2)]) 

terzo_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==3)]) 
terzo_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==3)]) 
terzo_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==3)]) 
terzo_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==3)]) 

quarto_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==4)]) 
quarto_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==4)]) 
quarto_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==4)]) 
quarto_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==4)]) 

quinto_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==5)]) 
quinto_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==5)]) 
quinto_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==5)]) 
quinto_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==5)]) 

sesto_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==6)]) 
sesto_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==6)]) 
sesto_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==6)]) 
sesto_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==6)]) 

settimo_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==7)]) 
settimo_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==7)]) 
settimo_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==7)]) 
settimo_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==7)]) 

ottavo_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==8)]) 
ottavo_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==8)]) 
ottavo_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==8)]) 
ottavo_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==8)]) 

nono_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==9)]) 
nono_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==9)]) 
nono_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==9)]) 
nono_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==9)]) 

decimo_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==10)]) 
decimo_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==10)]) 
decimo_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==10)]) 
decimo_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==10)]) 

undicesimo_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==11)]) 
undicesimo_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==11)]) 
undicesimo_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==11)]) 
undicesimo_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==11)]) 

dodicesimo_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==12)]) 
dodicesimo_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==12)]) 
dodicesimo_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==12)]) 
dodicesimo_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==12)]) 

tredi_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==13)]) 
tredi_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==13)]) 
tredi_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==13)]) 
tredi_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==13)]) 

quattordi_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==14)]) 
quattordi_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==14)]) 
quattordi_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==14)]) 
quattordi_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==14)]) 

quindi_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==15)]) 
quindi_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==15)]) 
quindi_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==15)]) 
quindi_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==15)]) 

sedi_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==16)]) 
sedi_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==16)]) 
sedi_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==16)]) 
sedi_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==16)]) 

dicia_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==17)]) 
dicia_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==17)]) 
dicia_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==17)]) 
dicia_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==17)]) 

dicio_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==18)]) 
dicio_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==18)]) 
dicio_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==18)]) 
dicio_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==18)]) 

dician_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==19)]) 
dician_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==19)]) 
dician_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==19)]) 
dician_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==19)]) 

venti_undertrenta_data = len(dfdM[(dfdM['age']<=30) & (dfdM['number']==20)]) 
venti_trentaquaranta_data = len(dfdM[(dfdM['age']>30) & (dfdM['age']<40) & (dfdM['number']==20)]) 
venti_quarantacinquanta_data = len(dfdM[(dfdM['age']>=40) & (dfdM['age']<55) & (dfdM['number']==20)]) 
venti_overcinquanta_data = len(dfdM[(dfdM['age']>=55) & (dfdM['number']==20)])
# Out:
# Empty DataFrame
# Columns: [restaurant, typology, zone, number, user_id, age, gender, ethnicity, text_review, review_sentiment]
# Index: []

# %%
#================COSTRUISCO GRAFICO=====================
plt.subplot()
#fig, ax = plt.subplots()

#=======<30=======
plt.scatter(1, 1, s=primo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 2, s = secondo_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 3, s=terzo_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 4, s=quarto_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 5, s = quinto_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 6, s=sesto_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 7, s=settimo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 8, s = ottavo_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 9, s=nono_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 10, s=decimo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 11, s=undicesimo_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 12, s = dodicesimo_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 13, s=tredi_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 14, s=quattordi_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 15, s = quindi_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 16, s=sedi_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 17, s=dicia_undertrenta_relevance*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 18, s = dicio_undertrenta_relevance*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 19, s=dician_undertrenta_relevance*30,color= 'blue', alpha=0.5)
plt.scatter(1, 20, s=venti_undertrenta_relevance*30, color= 'blue' , alpha=0.5)

#====30-40=====
plt.scatter(5, 1, s=primo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 2, s = secondo_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 3, s=terzo_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 4, s=quarto_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 5, s = quinto_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 6, s=sesto_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 7, s=settimo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 8, s = ottavo_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 9, s=nono_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 10, s=decimo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 11, s=undicesimo_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 12, s = dodicesimo_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 13, s=tredi_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 14, s=quattordi_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 15, s = quindi_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 16, s=sedi_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 17, s=dicia_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)
plt.scatter(5, 18, s = dicio_trentaquaranta_relevance*30, color= 'green',  alpha=0.5)
plt.scatter(5, 19, s=dician_trentaquaranta_relevance*30,color= 'green', alpha=0.5)
plt.scatter(5, 20, s=venti_trentaquaranta_relevance*30, color= 'green' , alpha=0.5)



#======40-55=========
plt.scatter(9, 1, s=primo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 2, s = secondo_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 3, s=terzo_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 4, s=quarto_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 5, s = quinto_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 6, s=sesto_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 7, s=settimo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 8, s = ottavo_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 9, s=nono_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 10, s=decimo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 11, s=undicesimo_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 12, s = dodicesimo_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 13, s=tredi_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 14, s=quattordi_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 15, s = quindi_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 16, s=sedi_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 17, s=dicia_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)
plt.scatter(9, 18, s = dicio_quarantacinquanta_relevance*30, color= 'red',  alpha=0.5)
plt.scatter(9, 19, s=dician_quarantacinquanta_relevance*30,color= 'red', alpha=0.5)
plt.scatter(9, 20, s=venti_quarantacinquanta_relevance*30, color= 'red' , alpha=0.5)


#========>55=======
plt.scatter(13, 1, s=primo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 2, s = secondo_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 3, s=terzo_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 4, s=quarto_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 5, s = quinto_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 6, s=sesto_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 7, s=settimo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 8, s = ottavo_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 9, s=nono_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 10, s=decimo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 11, s=undicesimo_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 12, s = dodicesimo_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 13, s=tredi_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 14, s=quattordi_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 15, s = quindi_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 16, s=sedi_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 17, s=dicia_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)
plt.scatter(13, 18, s = dicio_overcinquanta_relevance*30, color= 'orange',  alpha=0.5)
plt.scatter(13, 19, s=dician_overcinquanta_relevance*30,color= 'orange', alpha=0.5)
plt.scatter(13, 20, s=venti_overcinquanta_relevance*30, color= 'orange' , alpha=0.5)

#=======<30=======
plt.scatter(1.5, 1, s=primo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 2, s = secondo_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 3, s=terzo_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 4, s=quarto_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 5, s = quinto_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 6, s=sesto_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 7, s=settimo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 8, s = ottavo_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 9, s=nono_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 10, s=decimo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 11, s=undicesimo_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 12, s = dodicesimo_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 13, s=tredi_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 14, s=quattordi_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 15, s = quindi_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 16, s=sedi_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 17, s=dicia_undertrenta_data*30, color= 'blue' , alpha=0.5)
plt.scatter(1.5, 18, s = dicio_undertrenta_data*30, color= 'blue',  alpha=0.5)
plt.scatter(1.5, 19, s=dician_undertrenta_data*30,color= 'blue', alpha=0.5)
plt.scatter(1.5, 20, s=venti_undertrenta_data*30, color= 'blue' , alpha=0.5)


#====30-40=====
plt.scatter(5.5, 1, s=primo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 2, s = secondo_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 3, s=terzo_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 4, s=quarto_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 5, s = quinto_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 6, s=sesto_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 7, s=settimo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 8, s = ottavo_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 9, s=nono_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 10, s=decimo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 11, s=undicesimo_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 12, s = dodicesimo_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 13, s=tredi_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 14, s=quattordi_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 15, s = quindi_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 16, s=sedi_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 17, s=dicia_trentaquaranta_data*30, color= 'green' , alpha=0.5)
plt.scatter(5.5, 18, s = dicio_trentaquaranta_data*30, color= 'green',  alpha=0.5)
plt.scatter(5.5, 19, s=dician_trentaquaranta_data*30,color= 'green', alpha=0.5)
plt.scatter(5.5, 20, s=venti_trentaquaranta_data*30, color= 'green' , alpha=0.5)


#======40-55=========
plt.scatter(9.5, 1, s=primo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 2, s = secondo_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 3, s=terzo_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 4, s=quarto_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 5, s = quinto_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 6, s=sesto_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 7, s=settimo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 8, s = ottavo_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 9, s=nono_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 10, s=decimo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 11, s=undicesimo_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 12, s = dodicesimo_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 13, s=tredi_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 14, s=quattordi_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 15, s = quindi_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 16, s=sedi_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 17, s=dicia_quarantacinquanta_data*30, color= 'red' , alpha=0.5)
plt.scatter(9.5, 18, s = dicio_quarantacinquanta_data*30, color= 'red',  alpha=0.5)
plt.scatter(9.5, 19, s=dician_quarantacinquanta_data*30,color= 'red', alpha=0.5)
plt.scatter(9.5, 20, s=venti_quarantacinquanta_data*30, color= 'red' , alpha=0.5)


#========>55=======
plt.scatter(13.5, 1, s=primo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 2, s = secondo_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 3, s=terzo_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 4, s=quarto_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 5, s = quinto_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 6, s=sesto_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 7, s=settimo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 8, s = ottavo_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 9, s=nono_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 10, s=decimo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 11, s=undicesimo_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 12, s = dodicesimo_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 13, s=tredi_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 14, s=quattordi_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 15, s = quindi_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 16, s=sedi_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 17, s=dicia_overcinquanta_data*30, color= 'orange' , alpha=0.5)
plt.scatter(13.5, 18, s = dicio_overcinquanta_data*30, color= 'orange',  alpha=0.5)
plt.scatter(13.5, 19, s=dician_overcinquanta_data*30,color= 'orange', alpha=0.5)
plt.scatter(13.5, 20, s=venti_overcinquanta_data*30, color= 'orange' , alpha=0.5)


#=======RIFINITURE========
plt.hlines(y=11, xmin=0.85, xmax=14.15)

plt.title('Distribuzione demografica nelle prime 20 posizioni secondo ordinamento Relevance e data in ristoranti giapponesi')
plt.ylabel('Posizione in classifica', labelpad = 16)
plt.xlabel('Fascia di età' , labelpad = 16)
#setta ogni quante y ti fa vedere
plt.yticks(np.arange(0, 20, 5.0))
plt.xticks(np.arange(1, 14, 1.0))
plt.xticks([1,1.5,5,5.5,9,9.5,13,13.5],['Relevance','Data','Relevance','Data','Relevance','Data','Relevance','Data','Relevance','Data'],rotation=90)
plt.show()
