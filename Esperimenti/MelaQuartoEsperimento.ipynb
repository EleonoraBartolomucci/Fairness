# %% [markdown]
# <a href="https://colab.research.google.com/github/EleonoraBartolomucci/Fairness/blob/master/Esperimenti/MelaQuartoEsperimento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
from google.colab import auth
import json
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

sort = 'Relevance'

relevance = '1nwGbyk8q2S-0BkLcyFVqdK6emTooxHJv'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': relevance})
download.GetContentFile('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

dfr = pd.read_csv('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

sort = 'Date'

date = '1Pb2It9WPid9Irjp6bRVgCF7B3Y5ARBjT'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': date})
download.GetContentFile('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

dfd = pd.read_csv('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

# %%
primo_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==1)]) 
primo_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==1)]) 
primo_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==1)]) 


secondo_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==2)]) 
secondo_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==2)]) 
secondo_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==2)]) 


terzo_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==3)]) 
terzo_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==3)]) 
terzo_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==3)]) 


quarto_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==4)]) 
quarto_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==4)]) 
quarto_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==4)]) 

quinto_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==5)]) 
quinto_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==5)]) 
quinto_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==5)]) 

sesto_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==6)]) 
sesto_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==6)]) 
sesto_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==6)]) 

settimo_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==7)]) 
settimo_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==7)]) 
settimo_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==7)]) 

ottavo_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==8)]) 
ottavo_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==8)]) 
ottavo_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==8)]) 

nono_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==9)]) 
nono_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==9)]) 
nono_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==9)]) 

decimo_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==10)]) 
decimo_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==10)]) 
decimo_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==10)]) 

undicesimo_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==11)]) 
undicesimo_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==11)]) 
undicesimo_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==11)]) 

dodicesimo_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==12)]) 
dodicesimo_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==12)]) 
dodicesimo_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==12)]) 

tredi_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==13)]) 
tredi_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==13)]) 
tredi_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==13)]) 

quattordi_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==14)]) 
quattordi_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==14)]) 
quattordi_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==14)]) 

quindi_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==15)]) 
quindi_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==15)]) 
quindi_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==15)]) 

sedi_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==16)]) 
sedi_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==16)]) 
sedi_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==16)]) 

dicia_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==17)]) 
dicia_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==17)]) 
dicia_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==17)]) 

dicio_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==18)]) 
dicio_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==18)]) 
dicio_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==18)]) 

dician_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==19)]) 
dician_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==19)]) 
dician_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==19)]) 

venti_positive = len(dfr[(dfr['review_sentiment']=='positive') & (dfr['number']==20)]) 
venti_neutral = len(dfr[(dfr['review_sentiment']=='neutral') & (dfr['number']==20)]) 
venti_negative = len(dfr[(dfr['review_sentiment']=='negative') & (dfr['number']==20)])

# %%
dfrTorta = dfr[(dfr['number']<=20)]
positive_relevance = len(dfrTorta[(dfrTorta['review_sentiment']=='positive')  & (dfrTorta['number']<=20)]) 
negative_relevance = len(dfrTorta[(dfrTorta['review_sentiment']=='negative')  & (dfrTorta['number']<=20)])
neutral_relevance = len(dfrTorta[(dfrTorta['review_sentiment']=='neutral') & (dfrTorta['number']<=20)])

# %%
#================COSTRUISCO GRAFICO RELEVANCE=====================
plt.subplot()
#fig, ax = plt.subplots()

#=======POSITIVE=======
plt.scatter(1, 1, s=primo_positive*30, color= 'blue' , alpha=0.5, label='positive')
plt.scatter(1, 2, s = secondo_positive*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 3, s=terzo_positive*30,color= 'blue', alpha=0.5)
plt.scatter(1, 4, s=quarto_positive*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 5, s = quinto_positive*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 6, s=sesto_positive*30,color= 'blue', alpha=0.5)
plt.scatter(1, 7, s=settimo_positive*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 8, s = ottavo_positive*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 9, s=nono_positive*30,color= 'blue', alpha=0.5)
plt.scatter(1, 10, s=decimo_positive*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 11, s=undicesimo_positive*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 12, s = dodicesimo_positive*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 13, s=tredi_positive*30,color= 'blue', alpha=0.5)
plt.scatter(1, 14, s=quattordi_positive*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 15, s = quindi_positive*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 16, s=sedi_positive*30,color= 'blue', alpha=0.5)
plt.scatter(1, 17, s=dicia_positive*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 18, s = dicio_positive*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 19, s=dician_positive*30,color= 'blue', alpha=0.5)
plt.scatter(1, 20, s=venti_positive*30, color= 'blue' , alpha=0.5)

#====NEUTRAL=====
plt.scatter(2, 1, s=primo_neutral*30, color= 'green' , alpha=0.5, label='neutral')
plt.scatter(2, 2, s = secondo_neutral*30, color= 'green',  alpha=0.5)
plt.scatter(2, 3, s=terzo_neutral*30,color= 'green', alpha=0.5)
plt.scatter(2, 4, s=quarto_neutral*30, color= 'green' , alpha=0.5)
plt.scatter(2, 5, s = quinto_neutral*30, color= 'green',  alpha=0.5)
plt.scatter(2, 6, s=sesto_neutral*30,color= 'green', alpha=0.5)
plt.scatter(2, 7, s=settimo_neutral*30, color= 'green' , alpha=0.5)
plt.scatter(2, 8, s = ottavo_neutral*30, color= 'green',  alpha=0.5)
plt.scatter(2, 9, s=nono_neutral*30,color= 'green', alpha=0.5)
plt.scatter(2, 10, s=decimo_neutral*30, color= 'green' , alpha=0.5)
plt.scatter(2, 11, s=undicesimo_neutral*30, color= 'green' , alpha=0.5)
plt.scatter(2, 12, s = dodicesimo_neutral*30, color= 'green',  alpha=0.5)
plt.scatter(2, 13, s=tredi_neutral*30,color= 'green', alpha=0.5)
plt.scatter(2, 14, s=quattordi_neutral*30, color= 'green' , alpha=0.5)
plt.scatter(2, 15, s = quindi_neutral*30, color= 'green',  alpha=0.5)
plt.scatter(2, 16, s=sedi_neutral*30,color= 'green', alpha=0.5)
plt.scatter(2, 17, s=dicia_neutral*30, color= 'green' , alpha=0.5)
plt.scatter(2, 18, s = dicio_neutral*30, color= 'green',  alpha=0.5)
plt.scatter(2, 19, s=dician_neutral*30,color= 'green', alpha=0.5)
plt.scatter(2, 20, s=venti_neutral*30, color= 'green' , alpha=0.5)

#====NEGATIVE=====
plt.scatter(3, 1, s=primo_negative*30, color= 'red' , alpha=0.5)
plt.scatter(3, 2, s = secondo_negative*30, color= 'red',  alpha=0.5)
plt.scatter(3, 3, s=terzo_negative*30,color= 'red', alpha=0.5)
plt.scatter(3, 4, s=quarto_negative*30, color= 'red' , alpha=0.5)
plt.scatter(3, 5, s = quinto_negative*30, color= 'red',  alpha=0.5)
plt.scatter(3, 6, s=sesto_negative*30,color= 'red', alpha=0.5)
plt.scatter(3, 7, s=settimo_negative*30, color= 'red' , alpha=0.5)
plt.scatter(3, 8, s = ottavo_negative*30, color= 'red',  alpha=0.5)
plt.scatter(3, 9, s=nono_negative*30,color= 'red', alpha=0.5)
plt.scatter(3, 10, s=decimo_negative*30, color= 'red' , alpha=0.5)
plt.scatter(3, 11, s=undicesimo_negative*30, color= 'red' , alpha=0.5)
plt.scatter(3, 12, s = dodicesimo_negative*30, color= 'red',  alpha=0.5)
plt.scatter(3, 13, s=tredi_negative*30,color= 'red', alpha=0.5)
plt.scatter(3, 14, s=quattordi_negative*30, color= 'red' , alpha=0.5)
plt.scatter(3, 15, s = quindi_negative*30, color= 'red',  alpha=0.5)
plt.scatter(3, 16, s=sedi_negative*30,color= 'red', alpha=0.5)
plt.scatter(3, 17, s=dicia_negative*30, color= 'red' , alpha=0.5)
plt.scatter(3, 18, s = dicio_negative*30, color= 'red',  alpha=0.5)
plt.scatter(3, 19, s=dician_negative*30,color= 'red', alpha=0.5)
plt.scatter(3, 20, s=venti_negative*30, color= 'red' , alpha=0.5)



#=======RIFINITURE========
plt.hlines(y=11, xmin=1, xmax=3)

plt.title('Distribuzione del sentiment analysis nelle prime 20 posizioni secondo ordinamento di Yelp ')
plt.ylabel('Posizione in classifica', labelpad = 16)
plt.xlabel('Sentiment' , labelpad = 16)
#setta ogni quante y ti fa vedere
plt.yticks(np.arange(0, 20, 5.0))
plt.xticks(np.arange(1, 3, 1.0))
plt.xticks([1,2,3],['positive','neutral','negtive'])
plt.show()


labels = ['positive', 'negative', 'neutral']
sizes = [positive_relevance, negative_relevance, neutral_relevance] 
explode = [0.1, 0, 0]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90, colors =['cornflowerblue','tomato','mediumseagreen'])
ax1.set_title("Distribuzione del sentiment secondo ordinamento di Yelp")
fig.tight_layout()

# %%
primo_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==1)]) 
primo_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==1)]) 
primo_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==1)]) 

secondo_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==2)]) 
secondo_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==2)]) 
secondo_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==2)]) 

terzo_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==3)]) 
terzo_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==3)]) 
terzo_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==3)]) 

quarto_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==4)]) 
quarto_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==4)]) 
quarto_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==4)]) 

quinto_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==5)]) 
quinto_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==5)]) 
quinto_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==5)]) 

sesto_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==6)]) 
sesto_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==6)]) 
sesto_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==6)]) 

settimo_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==7)]) 
settimo_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==7)]) 
settimo_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==7)]) 

ottavo_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==8)]) 
ottavo_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==8)]) 
ottavo_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==8)]) 

nono_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==9)]) 
nono_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==9)]) 
nono_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==9)]) 

decimo_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==10)]) 
decimo_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==10)]) 
decimo_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==10)]) 

undicesimo_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==11)]) 
undicesimo_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==11)]) 
undicesimo_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==11)]) 

dodicesimo_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==12)]) 
dodicesimo_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==12)]) 
dodicesimo_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==12)]) 

tredi_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==13)]) 
tredi_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==13)]) 
tredi_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==13)]) 

quattordi_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==14)]) 
quattordi_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==14)]) 
quattordi_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==14)]) 

quindi_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==15)]) 
quindi_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==15)]) 
quindi_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==15)]) 

sedi_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==16)]) 
sedi_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==16)]) 
sedi_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==16)]) 

dicia_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==17)]) 
dicia_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==17)]) 
dicia_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==17)]) 

dicio_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==18)]) 
dicio_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==18)]) 
dicio_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==18)]) 

dician_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==19)]) 
dician_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==19)]) 
dician_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==19)]) 

venti_positive = len(dfd[(dfd['review_sentiment']=='positive') & (dfd['number']==20)]) 
venti_neutral = len(dfd[(dfd['review_sentiment']=='neutral') & (dfd['number']==20)]) 
venti_negative = len(dfd[(dfd['review_sentiment']=='negative') & (dfd['number']==20)])

# %%
dfrTorta = dfd[(dfd['number']<=20)]
positive_date = len(dfrTorta[(dfrTorta['review_sentiment']=='positive')  & (dfrTorta['number']<=20)]) 
negative_date = len(dfrTorta[(dfrTorta['review_sentiment']=='negative')  & (dfrTorta['number']<=20)])
neutral_date = len(dfrTorta[(dfrTorta['review_sentiment']=='neutral') & (dfrTorta['number']<=20)])

# %%
#================COSTRUISCO GRAFICO RELEVANCE=====================
plt.subplot()
#fig, ax = plt.subplots()

#=======POSITIVE=======
plt.scatter(1, 1, s=primo_positive*30, color= 'blue' , alpha=0.5, label='positive')
plt.scatter(1, 2, s = secondo_positive*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 3, s=terzo_positive*30,color= 'blue', alpha=0.5)
plt.scatter(1, 4, s=quarto_positive*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 5, s = quinto_positive*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 6, s=sesto_positive*30,color= 'blue', alpha=0.5)
plt.scatter(1, 7, s=settimo_positive*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 8, s = ottavo_positive*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 9, s=nono_positive*30,color= 'blue', alpha=0.5)
plt.scatter(1, 10, s=decimo_positive*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 11, s=undicesimo_positive*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 12, s = dodicesimo_positive*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 13, s=tredi_positive*30,color= 'blue', alpha=0.5)
plt.scatter(1, 14, s=quattordi_positive*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 15, s = quindi_positive*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 16, s=sedi_positive*30,color= 'blue', alpha=0.5)
plt.scatter(1, 17, s=dicia_positive*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 18, s = dicio_positive*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 19, s=dician_positive*30,color= 'blue', alpha=0.5)
plt.scatter(1, 20, s=venti_positive*30, color= 'blue' , alpha=0.5)

#====NEUTRAL=====
plt.scatter(2, 1, s=primo_neutral*30, color= 'green' , alpha=0.5, label='neutral')
plt.scatter(2, 2, s = secondo_neutral*30, color= 'green',  alpha=0.5)
plt.scatter(2, 3, s=terzo_neutral*30,color= 'green', alpha=0.5)
plt.scatter(2, 4, s=quarto_neutral*30, color= 'green' , alpha=0.5)
plt.scatter(2, 5, s = quinto_neutral*30, color= 'green',  alpha=0.5)
plt.scatter(2, 6, s=sesto_neutral*30,color= 'green', alpha=0.5)
plt.scatter(2, 7, s=settimo_neutral*30, color= 'green' , alpha=0.5)
plt.scatter(2, 8, s = ottavo_neutral*30, color= 'green',  alpha=0.5)
plt.scatter(2, 9, s=nono_neutral*30,color= 'green', alpha=0.5)
plt.scatter(2, 10, s=decimo_neutral*30, color= 'green' , alpha=0.5)
plt.scatter(2, 11, s=undicesimo_neutral*30, color= 'green' , alpha=0.5)
plt.scatter(2, 12, s = dodicesimo_neutral*30, color= 'green',  alpha=0.5)
plt.scatter(2, 13, s=tredi_neutral*30,color= 'green', alpha=0.5)
plt.scatter(2, 14, s=quattordi_neutral*30, color= 'green' , alpha=0.5)
plt.scatter(2, 15, s = quindi_neutral*30, color= 'green',  alpha=0.5)
plt.scatter(2, 16, s=sedi_neutral*30,color= 'green', alpha=0.5)
plt.scatter(2, 17, s=dicia_neutral*30, color= 'green' , alpha=0.5)
plt.scatter(2, 18, s = dicio_neutral*30, color= 'green',  alpha=0.5)
plt.scatter(2, 19, s=dician_neutral*30,color= 'green', alpha=0.5)
plt.scatter(2, 20, s=venti_neutral*30, color= 'green' , alpha=0.5)

#====NEGATIVE=====
plt.scatter(3, 1, s=primo_negative*30, color= 'red' , alpha=0.5)
plt.scatter(3, 2, s = secondo_negative*30, color= 'red',  alpha=0.5)
plt.scatter(3, 3, s=terzo_negative*30,color= 'red', alpha=0.5)
plt.scatter(3, 4, s=quarto_negative*30, color= 'red' , alpha=0.5)
plt.scatter(3, 5, s = quinto_negative*30, color= 'red',  alpha=0.5)
plt.scatter(3, 6, s=sesto_negative*30,color= 'red', alpha=0.5)
plt.scatter(3, 7, s=settimo_negative*30, color= 'red' , alpha=0.5)
plt.scatter(3, 8, s = ottavo_negative*30, color= 'red',  alpha=0.5)
plt.scatter(3, 9, s=nono_negative*30,color= 'red', alpha=0.5)
plt.scatter(3, 10, s=decimo_negative*30, color= 'red' , alpha=0.5)
plt.scatter(3, 11, s=undicesimo_negative*30, color= 'red' , alpha=0.5)
plt.scatter(3, 12, s = dodicesimo_negative*30, color= 'red',  alpha=0.5)
plt.scatter(3, 13, s=tredi_negative*30,color= 'red', alpha=0.5)
plt.scatter(3, 14, s=quattordi_negative*30, color= 'red' , alpha=0.5)
plt.scatter(3, 15, s = quindi_negative*30, color= 'red',  alpha=0.5)
plt.scatter(3, 16, s=sedi_negative*30,color= 'red', alpha=0.5)
plt.scatter(3, 17, s=dicia_negative*30, color= 'red' , alpha=0.5)
plt.scatter(3, 18, s = dicio_negative*30, color= 'red',  alpha=0.5)
plt.scatter(3, 19, s=dician_negative*30,color= 'red', alpha=0.5)
plt.scatter(3, 20, s=venti_negative*30, color= 'red' , alpha=0.5)


#=======RIFINITURE========
plt.hlines(y=11, xmin=1, xmax=3)

plt.title('Distribuzione del sentiment analysis nelle prime 20 posizioni secondo ordinamento per data ')
plt.ylabel('Posizione in classifica', labelpad = 16)
plt.xlabel('Sentiment' , labelpad = 16)
#setta ogni quante y ti fa vedere
plt.yticks(np.arange(0, 20, 5.0))
plt.xticks(np.arange(1, 3, 1.0))
plt.xticks([1,2,3],['positive','neutral','negtive'])
plt.show()


labels = ['positive', 'negative', 'neutral']
sizes = [positive_date, negative_date, neutral_date] 
explode = [0.1, 0, 0]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90, colors =['cornflowerblue','tomato','mediumseagreen'])
ax1.set_title("Distribuzione del sentiment secondo ordinamento per data")
fig.tight_layout()

# %%
tupelo_positive_relevance = dfr[(dfr['restaurant']=='TupeloHoney') & (dfr['review_sentiment']=='positive') & (dfr['number']<=20)]
tupelo_positive_date = dfd[(dfd['restaurant']=='TupeloHoney')  & (dfd['review_sentiment']=='positive') & (dfd['number']<=20)]
tupelo_negative_relevance = dfr[(dfr['restaurant']=='TupeloHoney') & (dfr['review_sentiment']=='negative') & (dfr['number']<=20)]
tupelo_negative_date = dfd[(dfd['restaurant']=='TupeloHoney')  & (dfd['review_sentiment']=='negative') & (dfd['number']<=20)]
tupelo_neutral_relevance = dfr[(dfr['restaurant']=='TupeloHoney') & (dfr['review_sentiment']=='neutral') & (dfr['number']<=20)]
tupelo_neutral_date = dfd[(dfd['restaurant']=='TupeloHoney')  & (dfd['review_sentiment']=='neutral') & (dfd['number']<=20)]


tot_tupelo_positive_relevance = sum(tupelo_positive_relevance['number']) / len(tupelo_positive_relevance)
tot_tupelo_positive_date = sum(tupelo_positive_date['number']) / len(tupelo_positive_date)
tot_tupelo_negative_relevance = sum(tupelo_negative_relevance['number']) / len(tupelo_negative_relevance)
tot_tupelo_negative_date = sum(tupelo_negative_date['number']) / len(tupelo_negative_date)

if(len(tupelo_neutral_relevance) > 0):
  tot_tupelo_neutral_relevance = sum(tupelo_neutral_relevance['number']) / len(tupelo_neutral_relevance)
else: 
  tot_tupelo_neutral_relevance =0

if(len(tupelo_neutral_date) > 0):
  tot_tupelo_neutral_date = sum(tupelo_neutral_date['number']) / len(tupelo_neutral_date)
else:
  tot_tupelo_neutral_date=0

# %%
cravi_positive_relevance = dfr[(dfr['restaurant']=='CravingsBuffet') & (dfr['review_sentiment']=='positive') & (dfr['number']<=20)]
cravi_positive_date = dfd[(dfd['restaurant']=='CravingsBuffet')  & (dfd['review_sentiment']=='positive') & (dfd['number']<=20)]
cravi_negative_relevance = dfr[(dfr['restaurant']=='CravingsBuffet') & (dfr['review_sentiment']=='negative') & (dfr['number']<=20)]
cravi_negative_date = dfd[(dfd['restaurant']=='CravingsBuffet')  & (dfd['review_sentiment']=='negative') & (dfd['number']<=20)]
cravi_neutral_relevance = dfr[(dfr['restaurant']=='CravingsBuffet') & (dfr['review_sentiment']=='neutral') & (dfr['number']<=20)]
cravi_neutral_date = dfd[(dfd['restaurant']=='CravingsBuffet')  & (dfd['review_sentiment']=='neutral') & (dfd['number']<=20)]

tot_cravi_positive_relevance = sum(cravi_positive_relevance['number']) / len(cravi_positive_relevance)
tot_cravi_positive_date = sum(cravi_positive_date['number']) / len(cravi_positive_date)
tot_cravi_negative_relevance = sum(cravi_negative_relevance['number']) / len(cravi_negative_relevance)
tot_cravi_negative_date = sum(cravi_negative_date['number']) / len(cravi_negative_date)
if(len(cravi_neutral_relevance) > 0):
  tot_cravi_neutral_relevance = sum(cravi_neutral_relevance['number']) / len(cravi_neutral_relevance)
else: 
  tot_cravi_neutral_relevance =0

if(len(cravi_neutral_date) > 0):
  tot_cravi_neutral_date = sum(cravi_neutral_date['number']) / len(cravi_neutral_date)
else:
  tot_cravi_neutral_date=0

# %%
culi_positive_relevance = dfr[(dfr['restaurant']=='CulinaryDropout') & (dfr['review_sentiment']=='positive') & (dfr['number']<=20)]
culi_positive_date = dfd[(dfd['restaurant']=='CulinaryDropout')  & (dfd['review_sentiment']=='positive') & (dfd['number']<=20)]
culi_negative_relevance = dfr[(dfr['restaurant']=='CulinaryDropout') & (dfr['review_sentiment']=='negative') & (dfr['number']<=20)]
culi_negative_date = dfd[(dfd['restaurant']=='CulinaryDropout')  & (dfd['review_sentiment']=='negative') & (dfd['number']<=20)]
culi_neutral_relevance = dfr[(dfr['restaurant']=='CulinaryDropout') & (dfr['review_sentiment']=='neutral') & (dfr['number']<=20)]
culi_neutral_date = dfd[(dfd['restaurant']=='CulinaryDropout')  & (dfd['review_sentiment']=='neutral') & (dfd['number']<=20)]

tot_culi_positive_relevance = sum(culi_positive_relevance['number']) / len(culi_positive_relevance)
tot_culi_positive_date = sum(culi_positive_date['number']) / len(culi_positive_date)
tot_culi_negative_relevance = sum(culi_negative_relevance['number']) / len(culi_negative_relevance)
tot_culi_negative_date = sum(culi_negative_date['number']) / len(culi_negative_date)
if(len(culi_neutral_relevance) > 0):
  tot_culi_neutral_relevance = sum(culi_neutral_relevance['number']) / len(culi_neutral_relevance)
else: 
  tot_culi_neutral_relevance =0

if(len(culi_neutral_date) > 0):
  tot_culi_neutral_date = sum(culi_neutral_date['number']) / len(culi_neutral_date)
else:
  tot_culi_neutral_date=0

# %%
futo_positive_relevance = dfr[(dfr['restaurant']=='FutoButa') & (dfr['review_sentiment']=='positive') & (dfr['number']<=20)]
futo_positive_date = dfd[(dfd['restaurant']=='FutoButa')  & (dfd['review_sentiment']=='positive') & (dfd['number']<=20)]
futo_negative_relevance = dfr[(dfr['restaurant']=='FutoButa') & (dfr['review_sentiment']=='negative') & (dfr['number']<=20)]
futo_negative_date = dfd[(dfd['restaurant']=='FutoButa')  & (dfd['review_sentiment']=='negative') & (dfd['number']<=20)]
futo_neutral_relevance = dfr[(dfr['restaurant']=='FutoButa') & (dfr['review_sentiment']=='neutral') & (dfr['number']<=20)]
futo_neutral_date = dfd[(dfd['restaurant']=='FutoButa')  & (dfd['review_sentiment']=='neutral') & (dfd['number']<=20)]

tot_futo_positive_relevance = sum(futo_positive_relevance['number']) / len(futo_positive_relevance)
tot_futo_positive_date = sum(futo_positive_date['number']) / len(futo_positive_date)
tot_futo_negative_relevance = sum(futo_negative_relevance['number']) / len(futo_negative_relevance)
tot_futo_negative_date = sum(futo_negative_date['number']) / len(futo_negative_date)
if(len(futo_neutral_relevance) > 0):
  tot_futo_neutral_relevance = sum(futo_neutral_relevance['number']) / len(futo_neutral_relevance)
else: 
  tot_futo_neutral_relevance =0

if(len(futo_neutral_date) > 0):
  tot_futo_neutral_date = sum(futo_neutral_date['number']) / len(futo_neutral_date)
else:
  tot_futo_neutral_date=0

# %%
haru_positive_relevance = dfr[(dfr['restaurant']=='HarumiSushi') & (dfr['review_sentiment']=='positive') & (dfr['number']<=20)]
haru_positive_date = dfd[(dfd['restaurant']=='HarumiSushi')  & (dfd['review_sentiment']=='positive') & (dfd['number']<=20)]
haru_negative_relevance = dfr[(dfr['restaurant']=='HarumiSushi') & (dfr['review_sentiment']=='negative') & (dfr['number']<=20)]
haru_negative_date = dfd[(dfd['restaurant']=='HarumiSushi')  & (dfd['review_sentiment']=='negative') & (dfd['number']<=20)]
haru_neutral_relevance = dfr[(dfr['restaurant']=='HarumiSushi') & (dfr['review_sentiment']=='neutral') & (dfr['number']<=20)]
haru_neutral_date = dfd[(dfd['restaurant']=='HarumiSushi')  & (dfd['review_sentiment']=='neutral') & (dfd['number']<=20)]

tot_haru_positive_relevance = sum(haru_positive_relevance['number']) / len(haru_positive_relevance)
tot_haru_positive_date = sum(haru_positive_date['number']) / len(haru_positive_date)
tot_haru_negative_relevance = sum(haru_negative_relevance['number']) / len(haru_negative_relevance)
tot_haru_negative_date = sum(haru_negative_date['number']) / len(haru_negative_date)
if(len(haru_neutral_relevance) > 0):
  tot_haru_neutral_relevance = sum(haru_neutral_relevance['number']) / len(haru_neutral_relevance)
else: 
  tot_haru_neutral_relevance =0

if(len(haru_neutral_date) > 0):
  tot_haru_neutral_date = sum(haru_neutral_date['number']) / len(haru_neutral_date)
else:
  tot_haru_neutral_date=0

# %%
ichi_positive_relevance = dfr[(dfr['restaurant']=='Ichiza') & (dfr['review_sentiment']=='positive') & (dfr['number']<=20)]
ichi_positive_date = dfd[(dfd['restaurant']=='Ichiza')  & (dfd['review_sentiment']=='positive') & (dfd['number']<=20)]
ichi_negative_relevance = dfr[(dfr['restaurant']=='Ichiza') & (dfr['review_sentiment']=='negative') & (dfr['number']<=20)]
ichi_negative_date = dfd[(dfd['restaurant']=='Ichiza')  & (dfd['review_sentiment']=='negative') & (dfd['number']<=20)]
ichi_neutral_relevance = dfr[(dfr['restaurant']=='Ichiza') & (dfr['review_sentiment']=='neutral') & (dfr['number']<=20)]
ichi_neutral_date = dfd[(dfd['restaurant']=='Ichiza')  & (dfd['review_sentiment']=='neutral') & (dfd['number']<=20)]

tot_ichi_positive_relevance = sum(ichi_positive_relevance['number']) / len(ichi_positive_relevance)
tot_ichi_positive_date = sum(ichi_positive_date['number']) / len(ichi_positive_date)
tot_ichi_negative_relevance = sum(ichi_negative_relevance['number']) / len(ichi_negative_relevance)
tot_ichi_negative_date = sum(ichi_negative_date['number']) / len(ichi_negative_date)
if(len(ichi_neutral_relevance) > 0):
  tot_ichi_neutral_relevance = sum(ichi_neutral_relevance['number']) / len(ichi_neutral_relevance)
else: 
  tot_ichi_neutral_relevance =0

if(len(ichi_neutral_date) > 0):
  tot_ichi_neutral_date = sum(ichi_neutral_date['number']) / len(ichi_neutral_date)
else:
  tot_ichi_neutral_date=0

# %%
cabo_positive_relevance = dfr[(dfr['restaurant']=='CaboFishTaco') & (dfr['review_sentiment']=='positive') & (dfr['number']<=20)]
cabo_positive_date = dfd[(dfd['restaurant']=='CaboFishTaco')  & (dfd['review_sentiment']=='positive') & (dfd['number']<=20)]
cabo_negative_relevance = dfr[(dfr['restaurant']=='CaboFishTaco') & (dfr['review_sentiment']=='negative') & (dfr['number']<=20)]
cabo_negative_date = dfd[(dfd['restaurant']=='CaboFishTaco')  & (dfd['review_sentiment']=='negative') & (dfd['number']<=20)]
cabo_neutral_relevance = dfr[(dfr['restaurant']=='CaboFishTaco') & (dfr['review_sentiment']=='neutral') & (dfr['number']<=20)]
cabo_neutral_date = dfd[(dfd['restaurant']=='CaboFishTaco')  & (dfd['review_sentiment']=='neutral') & (dfd['number']<=20)]

tot_cabo_positive_relevance = sum(cabo_positive_relevance['number']) / len(cabo_positive_relevance)
tot_cabo_positive_date = sum(cabo_positive_date['number']) / len(cabo_positive_date)
tot_cabo_negative_relevance = sum(cabo_negative_relevance['number']) / len(cabo_negative_relevance)
tot_cabo_negative_date = sum(cabo_negative_date['number']) / len(cabo_negative_date)
if(len(cabo_neutral_relevance) > 0):
  tot_cabo_neutral_relevance = sum(cabo_neutral_relevance['number']) / len(cabo_neutral_relevance)
else: 
  tot_cabo_neutral_relevance =0

if(len(cabo_neutral_date) > 0):
  tot_cabo_neutral_date = sum(cabo_neutral_date['number']) / len(cabo_neutral_date)
else:
  tot_cabo_neutral_date=0

# %%
backy_positive_relevance = dfr[(dfr['restaurant']=='BackyardTaco') & (dfr['review_sentiment']=='positive') & (dfr['number']<=20)]
backy_positive_date = dfd[(dfd['restaurant']=='BackyardTaco')  & (dfd['review_sentiment']=='positive') & (dfd['number']<=20)]
backy_negative_relevance = dfr[(dfr['restaurant']=='BackyardTaco') & (dfr['review_sentiment']=='negative') & (dfr['number']<=20)]
backy_negative_date = dfd[(dfd['restaurant']=='BackyardTaco')  & (dfd['review_sentiment']=='negative') & (dfd['number']<=20)]
backy_neutral_relevance = dfr[(dfr['restaurant']=='BackyardTaco') & (dfr['review_sentiment']=='neutral') & (dfr['number']<=20)]
backy_neutral_date = dfd[(dfd['restaurant']=='BackyardTaco')  & (dfd['review_sentiment']=='neutral') & (dfd['number']<=20)]

tot_backy_positive_relevance = sum(backy_positive_relevance['number']) / len(backy_positive_relevance)
tot_backy_positive_date = sum(backy_positive_date['number']) / len(backy_positive_date)
tot_backy_negative_relevance = sum(backy_negative_relevance['number']) / len(backy_negative_relevance)
tot_backy_negative_date = sum(backy_negative_date['number']) / len(backy_negative_date)
if(len(backy_neutral_relevance) > 0):
  tot_backy_neutral_relevance = sum(backy_neutral_relevance['number']) / len(backy_neutral_relevance)
else: 
  tot_backy_neutral_relevance =0

if(len(backy_neutral_date) > 0):
  tot_backy_neutral_date = sum(backy_neutral_date['number']) / len(backy_neutral_date)
else:
  tot_backy_neutral_date=0

# %%
lindo_positive_relevance = dfr[(dfr['restaurant']=='LindoMichoacan') & (dfr['review_sentiment']=='positive') & (dfr['number']<=20)]
lindo_positive_date = dfd[(dfd['restaurant']=='LindoMichoacan')  & (dfd['review_sentiment']=='positive') & (dfd['number']<=20)]
lindo_negative_relevance = dfr[(dfr['restaurant']=='LindoMichoacan') & (dfr['review_sentiment']=='negative') & (dfr['number']<=20)]
lindo_negative_date = dfd[(dfd['restaurant']=='LindoMichoacan')  & (dfd['review_sentiment']=='negative') & (dfd['number']<=20)]
lindo_neutral_relevance = dfr[(dfr['restaurant']=='LindoMichoacan') & (dfr['review_sentiment']=='neutral') & (dfr['number']<=20)]
lindo_neutral_date = dfd[(dfd['restaurant']=='LindoMichoacan')  & (dfd['review_sentiment']=='neutral') & (dfd['number']<=20)]

tot_lindo_positive_relevance = sum(lindo_positive_relevance['number']) / len(lindo_positive_relevance)
tot_lindo_positive_date = sum(lindo_positive_date['number']) / len(lindo_positive_date)
tot_lindo_negative_relevance = sum(lindo_negative_relevance['number']) / len(lindo_negative_relevance)
tot_lindo_negative_date = sum(lindo_negative_date['number']) / len(lindo_negative_date)
if(len(lindo_neutral_relevance) > 0):
  tot_lindo_neutral_relevance = sum(lindo_neutral_relevance['number']) / len(lindo_neutral_relevance)
else: 
  tot_lindo_neutral_relevance =0

if(len(lindo_neutral_date) > 0):
  tot_lindo_neutral_date = sum(lindo_neutral_date['number']) / len(lindo_neutral_date)
else:
  tot_lindo_neutral_date=0

# %%
tot_american_positive_relevance = (tot_tupelo_positive_relevance + tot_cravi_positive_relevance + tot_culi_positive_relevance)/3
tot_american_positive_date = (tot_tupelo_positive_date + tot_cravi_positive_date + tot_culi_positive_date)/3

tot_asian_positive_relevance = (tot_futo_positive_relevance + tot_haru_positive_relevance + tot_ichi_positive_relevance)/3
tot_asian_positive_date = (tot_futo_positive_date + tot_haru_positive_date + tot_ichi_positive_date)/3

tot_mexican_positive_relevance = (tot_cabo_positive_relevance + tot_backy_positive_relevance + tot_lindo_positive_relevance)/3
tot_mexican_positive_date = (tot_cabo_positive_date + tot_backy_positive_date + tot_lindo_positive_date)/3

tot_american_negative_relevance = (tot_tupelo_negative_relevance + tot_cravi_negative_relevance + tot_culi_negative_relevance)/3
tot_american_negative_date = (tot_tupelo_negative_date + tot_cravi_negative_date + tot_culi_negative_date)/3

tot_asian_negative_relevance = (tot_futo_negative_relevance + tot_haru_negative_relevance + tot_ichi_negative_relevance)/3
tot_asian_negative_date = (tot_futo_negative_date + tot_haru_negative_date + tot_ichi_negative_date)/3

tot_mexican_negative_relevance = (tot_cabo_negative_relevance + tot_backy_negative_relevance + tot_lindo_negative_relevance)/3
tot_mexican_negative_date = (tot_cabo_negative_date + tot_backy_negative_date + tot_lindo_negative_date)/3

tot_american_neutral_relevance = (tot_tupelo_neutral_relevance + tot_cravi_neutral_relevance + tot_culi_neutral_relevance)/3
tot_american_neutral_date = (tot_tupelo_neutral_date + tot_cravi_neutral_date + tot_culi_neutral_date)/3

tot_asian_neutral_relevance = (tot_futo_neutral_relevance + tot_haru_neutral_relevance + tot_ichi_neutral_relevance)/3
tot_asian_neutral_date = (tot_futo_neutral_date + tot_haru_neutral_date + tot_ichi_neutral_date)/3

tot_mexican_neutral_relevance = (tot_cabo_neutral_relevance + tot_backy_neutral_relevance + tot_lindo_neutral_relevance)/3
tot_mexican_neutral_date = (tot_cabo_neutral_date + tot_backy_neutral_date + tot_lindo_neutral_date)/3

# %%
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.1f}'.format(height),
                    xy=(rect.get_x() + rect.get_width(), height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')




labels = ['Americano', 'Giapponese','Messicano']

positive = [tot_american_positive_date,tot_asian_positive_date,tot_mexican_positive_date]
negative = [tot_american_negative_date,tot_asian_negative_date,tot_mexican_negative_date]
neutral = [tot_american_neutral_date,tot_asian_neutral_date,tot_mexican_neutral_date]


x = np.arange(len(labels))  # the label locations
width = 0.15 # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, positive, width, label='positive',color='limegreen')
rects2 = ax.bar(x, neutral, width,label ='neutral',color='gold')
rects3 = ax.bar(x + width, negative, width,label ='negative',color='tomato')
ax.set_ylabel('Posizione media in classifica')
ax.set_title('Posizione media in classifica secondo ordinamento per data')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylim([1,18])
ax.legend()
plt.xlabel('Tipologia ristorante' , labelpad = 16)
autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
fig.tight_layout()



labels = ['Americano', 'Giapponese','Messicano']
positive = [tot_american_positive_relevance,tot_asian_positive_relevance,tot_mexican_positive_relevance]
negative = [tot_american_negative_relevance,tot_asian_negative_relevance,tot_mexican_negative_relevance]
neutral = [tot_american_neutral_relevance,tot_asian_neutral_relevance,tot_mexican_neutral_relevance]

fig, ax = plt.subplots()
x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars
rects1 = ax.bar(x - width, positive, width, label='positive',color='limegreen')
rects2 = ax.bar(x, neutral, width,label ='neutral',color='gold')
rects3 = ax.bar(x + width, negative, width,label ='negative',color='tomato')

ax.set_ylabel('Posizione media in classifica')
ax.set_title('Posizione media in classifica secondo ordinamento di Yelp')
ax.set_xticks(x)
ax.set_xticklabels(labels)
plt.xlabel('Tipologia ristorante' , labelpad = 16)
ax.set_ylim([1,18])
ax.legend()
autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
fig.tight_layout()
