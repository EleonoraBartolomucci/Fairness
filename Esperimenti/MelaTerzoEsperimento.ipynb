# %% [markdown]
# <a href="https://colab.research.google.com/github/EleonoraBartolomucci/Fairness/blob/master/Esperimenti/MelaTerzoEsperimento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
from google.colab import auth
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

sort = 'Relevance'

relevance = '1nwGbyk8q2S-0BkLcyFVqdK6emTooxHJv'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': relevance})
download.GetContentFile('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

dfr = pd.read_csv('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

sort = 'Date'

date = '1Pb2It9WPid9Irjp6bRVgCF7B3Y5ARBjT'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': date})
download.GetContentFile('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

dfd = pd.read_csv('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

# %%
#converto l'eta in numero
dfr['age'] = pd.to_numeric(dfr['age'], errors='coerce').fillna(0).astype(np.int64)

#converto l'età in nuemro
dfd['age'] = pd.to_numeric(dfd['age'], errors='coerce').fillna(0).astype(np.int64)

# %%
primo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==1)]) 
primo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==1)])
primo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==1)]) 
primo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==1)]) 
primo_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==1)])


secondo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==2)]) 
secondo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==2)]) 
secondo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==2)]) 
secondo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==2)]) 
secondo_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==2)])


terzo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==3)]) 
terzo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==3)]) 
terzo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==3)]) 
terzo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==3)]) 
terzo_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==3)])


quarto_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==4)]) 
quarto_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==4)]) 
quarto_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==4)]) 
quarto_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==4)]) 
quarto_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==4)])


quinto_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==5)]) 
quinto_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==5)]) 
quinto_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==5)]) 
quinto_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==5)]) 
quinto_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==5)])


sesto_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==6)]) 
sesto_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==6)]) 
sesto_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==6)]) 
sesto_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==6)]) 
sesto_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==6)])


settimo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==7)]) 
settimo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==7)]) 
settimo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==7)]) 
settimo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==7)])
settimo_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==7)])


ottavo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==8)]) 
ottavo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==8)]) 
ottavo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==8)]) 
ottavo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==8)]) 
ottavo_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==8)])


nono_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==9)]) 
nono_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==9)]) 
nono_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==9)]) 
nono_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==9)])
nono_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==9)])


decimo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==10)]) 
decimo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==10)]) 
decimo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==10)]) 
decimo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==10)]) 
decimo_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==10)])


undicesimo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==11)]) 
undicesimo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==11)]) 
undicesimo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==11)]) 
undicesimo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==11)]) 
undicesimo_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==11)])

dodicesimo_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==12)]) 
dodicesimo_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==12)]) 
dodicesimo_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==12)]) 
dodicesimo_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==12)]) 
dodicesimo_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==12)])

tredi_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==13)]) 
tredi_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==13)]) 
tredi_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==13)]) 
tredi_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==13)]) 
tredi_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==13)])

quattordi_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==14)]) 
quattordi_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==14)]) 
quattordi_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==14)]) 
quattordi_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==14)]) 
quattordi_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==14)])

quindi_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==15)]) 
quindi_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==15)]) 
quindi_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==15)]) 
quindi_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==15)]) 
quindi_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==15)])

sedi_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==16)]) 
sedi_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==16)]) 
sedi_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==16)]) 
sedi_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==16)]) 
sedi_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==16)])

dicia_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==17)]) 
dicia_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==17)]) 
dicia_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==17)]) 
dicia_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==17)])
dicia_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==17)]) 

dicio_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==18)]) 
dicio_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==18)]) 
dicio_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==18)]) 
dicio_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==18)]) 
dicio_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==18)])

dician_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==19)]) 
dician_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==19)]) 
dician_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==19)]) 
dician_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==19)]) 
dician_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==19)])

venti_undertrenta = len(dfr[(dfr['age']<=30) & (dfr['age']>=1) & (dfr['number']==20)]) 
venti_trentaquaranta = len(dfr[(dfr['age']>30) & (dfr['age']<40) & (dfr['number']==20)]) 
venti_quarantacinquanta = len(dfr[(dfr['age']>=40) & (dfr['age']<55) & (dfr['number']==20)]) 
venti_overcinquanta = len(dfr[(dfr['age']>=55) & (dfr['number']==20)])
venti_unknow = len(dfr[(dfr['age']== 0) & (dfr['number']==20)])

# %%
dfrTorta = dfr[(dfr['number']<=20)]
undertrenta_relevance = len(dfrTorta[(dfrTorta['age']<=30) & (dfr['age']>=1) & (dfrTorta['number']<=20)]) 
trentaquaranta_relevance = len(dfrTorta[(dfrTorta['age']>30) & (dfrTorta['age']<40) & (dfrTorta['number']<=20)])
quarantacinquanta_relevance = len(dfrTorta[(dfrTorta['age']>=40) & (dfrTorta['age']<55) & (dfrTorta['number']<=20)]) 
overcinquanta_relevance = len(dfrTorta[(dfrTorta['age']>=55) & (dfrTorta['number']<=20)])
unknow_relevance = len(dfrTorta[(dfrTorta['age']==0) & (dfrTorta['number']<=20)])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
#================COSTRUISCO GRAFICO RELEVANCE=====================
plt.subplot()

#=======<30=======
plt.scatter(1, 1, s=primo_undertrenta*30, color= 'blue' , alpha=0.5, label='undertrenta')
plt.scatter(1, 2, s = secondo_undertrenta*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 3, s=terzo_undertrenta*30,color= 'blue', alpha=0.5)
plt.scatter(1, 4, s=quarto_undertrenta*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 5, s = quinto_undertrenta*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 6, s=sesto_undertrenta*30,color= 'blue', alpha=0.5)
plt.scatter(1, 7, s=settimo_undertrenta*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 8, s = ottavo_undertrenta*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 9, s=nono_undertrenta*30,color= 'blue', alpha=0.5)
plt.scatter(1, 10, s=decimo_undertrenta*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 11, s=undicesimo_undertrenta*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 12, s = dodicesimo_undertrenta*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 13, s=tredi_undertrenta*30,color= 'blue', alpha=0.5)
plt.scatter(1, 14, s=quattordi_undertrenta*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 15, s = quindi_undertrenta*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 16, s=sedi_undertrenta*30,color= 'blue', alpha=0.5)
plt.scatter(1, 17, s=dicia_undertrenta*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 18, s = dicio_undertrenta*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 19, s=dician_undertrenta*30,color= 'blue', alpha=0.5)
plt.scatter(1, 20, s=venti_undertrenta*30, color= 'blue' , alpha=0.5)

#====30-40=====
plt.scatter(2, 1, s=primo_trentaquaranta*30, color= 'green' , alpha=0.5, label='trentaquaranta')
plt.scatter(2, 2, s = secondo_trentaquaranta*30, color= 'green',  alpha=0.5)
plt.scatter(2, 3, s=terzo_trentaquaranta*30,color= 'green', alpha=0.5)
plt.scatter(2, 4, s=quarto_trentaquaranta*30, color= 'green' , alpha=0.5)
plt.scatter(2, 5, s = quinto_trentaquaranta*30, color= 'green',  alpha=0.5)
plt.scatter(2, 6, s=sesto_trentaquaranta*30,color= 'green', alpha=0.5)
plt.scatter(2, 7, s=settimo_trentaquaranta*30, color= 'green' , alpha=0.5)
plt.scatter(2, 8, s = ottavo_trentaquaranta*30, color= 'green',  alpha=0.5)
plt.scatter(2, 9, s=nono_trentaquaranta*30,color= 'green', alpha=0.5)
plt.scatter(2, 10, s=decimo_trentaquaranta*30, color= 'green' , alpha=0.5)
plt.scatter(2, 11, s=undicesimo_trentaquaranta*30, color= 'green' , alpha=0.5)
plt.scatter(2, 12, s = dodicesimo_trentaquaranta*30, color= 'green',  alpha=0.5)
plt.scatter(2, 13, s=tredi_trentaquaranta*30,color= 'green', alpha=0.5)
plt.scatter(2, 14, s=quattordi_trentaquaranta*30, color= 'green' , alpha=0.5)
plt.scatter(2, 15, s = quindi_trentaquaranta*30, color= 'green',  alpha=0.5)
plt.scatter(2, 16, s=sedi_trentaquaranta*30,color= 'green', alpha=0.5)
plt.scatter(2, 17, s=dicia_trentaquaranta*30, color= 'green' , alpha=0.5)
plt.scatter(2, 18, s = dicio_trentaquaranta*30, color= 'green',  alpha=0.5)
plt.scatter(2, 19, s=dician_trentaquaranta*30,color= 'green', alpha=0.5)
plt.scatter(2, 20, s=venti_trentaquaranta*30, color= 'green' , alpha=0.5)

#======40-55=========
plt.scatter(3, 1, s=primo_quarantacinquanta*30, color= 'red' , alpha=0.5)
plt.scatter(3, 2, s = secondo_quarantacinquanta*30, color= 'red',  alpha=0.5)
plt.scatter(3, 3, s=terzo_quarantacinquanta*30,color= 'red', alpha=0.5)
plt.scatter(3, 4, s=quarto_quarantacinquanta*30, color= 'red' , alpha=0.5)
plt.scatter(3, 5, s = quinto_quarantacinquanta*30, color= 'red',  alpha=0.5)
plt.scatter(3, 6, s=sesto_quarantacinquanta*30,color= 'red', alpha=0.5)
plt.scatter(3, 7, s=settimo_quarantacinquanta*30, color= 'red' , alpha=0.5)
plt.scatter(3, 8, s = ottavo_quarantacinquanta*30, color= 'red',  alpha=0.5)
plt.scatter(3, 9, s=nono_quarantacinquanta*30,color= 'red', alpha=0.5)
plt.scatter(3, 10, s=decimo_quarantacinquanta*30, color= 'red' , alpha=0.5)
plt.scatter(3, 11, s=undicesimo_quarantacinquanta*30, color= 'red' , alpha=0.5)
plt.scatter(3, 12, s = dodicesimo_quarantacinquanta*30, color= 'red',  alpha=0.5)
plt.scatter(3, 13, s=tredi_quarantacinquanta*30,color= 'red', alpha=0.5)
plt.scatter(3, 14, s=quattordi_quarantacinquanta*30, color= 'red' , alpha=0.5)
plt.scatter(3, 15, s = quindi_quarantacinquanta*30, color= 'red',  alpha=0.5)
plt.scatter(3, 16, s=sedi_quarantacinquanta*30,color= 'red', alpha=0.5)
plt.scatter(3, 17, s=dicia_quarantacinquanta*30, color= 'red' , alpha=0.5)
plt.scatter(3, 18, s = dicio_quarantacinquanta*30, color= 'red',  alpha=0.5)
plt.scatter(3, 19, s=dician_quarantacinquanta*30,color= 'red', alpha=0.5)
plt.scatter(3, 20, s=venti_quarantacinquanta*30, color= 'red' , alpha=0.5)


#========>55=======
plt.scatter(4, 1, s=primo_overcinquanta*30, color= 'orange' , alpha=0.5)
plt.scatter(4, 2, s = secondo_overcinquanta*30, color= 'orange',  alpha=0.5)
plt.scatter(4, 3, s=terzo_overcinquanta*30,color= 'orange', alpha=0.5)
plt.scatter(4, 4, s=quarto_overcinquanta*30, color= 'orange' , alpha=0.5)
plt.scatter(4, 5, s = quinto_overcinquanta*30, color= 'orange',  alpha=0.5)
plt.scatter(4, 6, s=sesto_overcinquanta*30,color= 'orange', alpha=0.5)
plt.scatter(4, 7, s=settimo_overcinquanta*30, color= 'orange' , alpha=0.5)
plt.scatter(4, 8, s = ottavo_overcinquanta*30, color= 'orange',  alpha=0.5)
plt.scatter(4, 9, s=nono_overcinquanta*30,color= 'orange', alpha=0.5)
plt.scatter(4, 10, s=decimo_overcinquanta*30, color= 'orange' , alpha=0.5)
plt.scatter(4, 11, s=undicesimo_overcinquanta*30, color= 'orange' , alpha=0.5)
plt.scatter(4, 12, s = dodicesimo_overcinquanta*30, color= 'orange',  alpha=0.5)
plt.scatter(4, 13, s=tredi_overcinquanta*30,color= 'orange', alpha=0.5)
plt.scatter(4, 14, s=quattordi_overcinquanta*30, color= 'orange' , alpha=0.5)
plt.scatter(4, 15, s = quindi_overcinquanta*30, color= 'orange',  alpha=0.5)
plt.scatter(4, 16, s=sedi_overcinquanta*30,color= 'orange', alpha=0.5)
plt.scatter(4, 17, s=dicia_overcinquanta*30, color= 'orange' , alpha=0.5)
plt.scatter(4, 18, s = dicio_overcinquanta*30, color= 'orange',  alpha=0.5)
plt.scatter(4, 19, s=dician_overcinquanta*30,color= 'orange', alpha=0.5)
plt.scatter(4, 20, s=venti_overcinquanta*30, color= 'orange' , alpha=0.5)

#==========unknow
plt.scatter(5, 1, s=primo_unknow*30, color= 'grey' , alpha=0.5)
plt.scatter(5, 2, s = secondo_unknow*30, color= 'grey',  alpha=0.5)
plt.scatter(5, 3, s=terzo_unknow*30,color= 'grey', alpha=0.5)
plt.scatter(5, 4, s=quarto_unknow*30, color= 'grey' , alpha=0.5)
plt.scatter(5, 5, s = quinto_unknow*30, color= 'grey',  alpha=0.5)
plt.scatter(5, 6, s=sesto_unknow*30,color= 'grey', alpha=0.5)
plt.scatter(5, 7, s=settimo_unknow*30, color= 'grey' , alpha=0.5)
plt.scatter(5, 8, s = ottavo_unknow*30, color= 'grey',  alpha=0.5)
plt.scatter(5, 9, s=nono_unknow*30,color= 'grey', alpha=0.5)
plt.scatter(5, 10, s=decimo_unknow*30, color= 'grey' , alpha=0.5)
plt.scatter(5, 11, s=undicesimo_unknow*30, color= 'grey' , alpha=0.5)
plt.scatter(5, 12, s = dodicesimo_unknow*30, color= 'grey',  alpha=0.5)
plt.scatter(5, 13, s=tredi_unknow*30,color= 'grey', alpha=0.5)
plt.scatter(5, 14, s=quattordi_unknow*30, color= 'grey' , alpha=0.5)
plt.scatter(5, 15, s = quindi_unknow*30, color= 'grey',  alpha=0.5)
plt.scatter(5, 16, s=sedi_unknow*30,color= 'grey', alpha=0.5)
plt.scatter(5, 17, s=dicia_unknow*30, color= 'grey' , alpha=0.5)
plt.scatter(5, 18, s = dicio_unknow*30, color= 'grey',  alpha=0.5)
plt.scatter(5, 19, s=dician_unknow*30,color= 'grey', alpha=0.5)
plt.scatter(5, 20, s=venti_unknow*30, color= 'grey' , alpha=0.5)


#=======RIFINITURE========
plt.hlines(y=11, xmin=0.85, xmax=5.15)

plt.title("Distribuzione dell'età nelle prime 20 posizioni secondo ordinamento di Yelp")
plt.ylabel('Posizione in classifica', labelpad = 16)
plt.xlabel("Fascia di età" , labelpad = 16)
#setta ogni quante y ti fa vedere
plt.yticks(np.arange(0, 20, 5.0))
plt.xticks(np.arange(1, 4, 1.0))
plt.xticks([1,2,3,4,5],['under 30','30-40','40-55','over 55','non riconosciuti'])
plt.show()


labels = ['<30', '30-40', '40-55', '>55','non riconosciuti']
sizes = [undertrenta_relevance, trentaquaranta_relevance, quarantacinquanta_relevance, overcinquanta_relevance, unknow_relevance] 
explode = [0, 0, 0, 0, 0.1]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90, colors =['cornflowerblue','mediumseagreen','tomato','gold','silver'])
ax1.set_title("Distribuzione dell'età secondo ordinamento di Yelp")
fig.tight_layout()

# %%
primo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==1)]) 
primo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==1)])
primo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==1)]) 
primo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==1)]) 
primo_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==1)])

secondo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==2)]) 
secondo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==2)]) 
secondo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==2)]) 
secondo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==2)]) 
secondo_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==2)])

terzo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==3)]) 
terzo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==3)]) 
terzo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==3)]) 
terzo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==3)]) 
terzo_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==3)])

quarto_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==4)]) 
quarto_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==4)]) 
quarto_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==4)]) 
quarto_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==4)]) 
quarto_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==4)])

quinto_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==5)]) 
quinto_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==5)]) 
quinto_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==5)]) 
quinto_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==5)]) 
quinto_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==5)])

sesto_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==6)]) 
sesto_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==6)]) 
sesto_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==6)]) 
sesto_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==6)]) 
sesto_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==6)])

settimo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==7)]) 
settimo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==7)]) 
settimo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==7)]) 
settimo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==7)])
settimo_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==7)])

ottavo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==8)]) 
ottavo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==8)]) 
ottavo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==8)]) 
ottavo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==8)]) 
ottavo_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==8)])

nono_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==9)]) 
nono_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==9)]) 
nono_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==9)]) 
nono_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==9)])
nono_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==9)])

decimo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==10)]) 
decimo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==10)]) 
decimo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==10)]) 
decimo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==10)]) 
decimo_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==10)])

undicesimo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==11)]) 
undicesimo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==11)]) 
undicesimo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==11)]) 
undicesimo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==11)]) 
undicesimo_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==11)])

dodicesimo_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==12)]) 
dodicesimo_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==12)]) 
dodicesimo_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==12)]) 
dodicesimo_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==12)]) 
dodicesimo_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==12)])

tredi_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==13)]) 
tredi_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==13)]) 
tredi_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==13)]) 
tredi_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==13)]) 
tredi_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==13)])

quattordi_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==14)]) 
quattordi_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==14)]) 
quattordi_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==14)]) 
quattordi_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==14)]) 
quattordi_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==14)])

quindi_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==15)]) 
quindi_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==15)]) 
quindi_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==15)]) 
quindi_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==15)]) 
quindi_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==15)])

sedi_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==16)]) 
sedi_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==16)]) 
sedi_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==16)]) 
sedi_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==16)]) 
sedi_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==16)])

dicia_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==17)]) 
dicia_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==17)]) 
dicia_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==17)]) 
dicia_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==17)])
dicia_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==17)]) 

dicio_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==18)]) 
dicio_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==18)]) 
dicio_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==18)]) 
dicio_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==18)]) 
dicio_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==18)])

dician_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==19)]) 
dician_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==19)]) 
dician_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==19)]) 
dician_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==19)]) 
dician_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==19)])

venti_undertrenta = len(dfd[(dfd['age']<=30) & (dfd['age']>=1) & (dfd['number']==20)]) 
venti_trentaquaranta = len(dfd[(dfd['age']>30) & (dfd['age']<40) & (dfd['number']==20)]) 
venti_quarantacinquanta = len(dfd[(dfd['age']>=40) & (dfd['age']<55) & (dfd['number']==20)]) 
venti_overcinquanta = len(dfd[(dfd['age']>=55) & (dfd['number']==20)])
venti_unknow = len(dfd[(dfd['age']== 0) & (dfd['number']==20)])

# %%
dfdTorta = dfd[(dfd['number']<=20)]
dfdTorta = dfd[(dfd['number']<=20)]
undertrenta_data = len(dfdTorta[(dfdTorta['age']<=30) & (dfd['age']>=1) & (dfdTorta['number']<=20)]) 
trentaquaranta_data = len(dfdTorta[(dfdTorta['age']>30) & (dfdTorta['age']<40) & (dfdTorta['number']<=20)])
quarantacinquanta_data = len(dfdTorta[(dfdTorta['age']>=40) & (dfdTorta['age']<55) & (dfdTorta['number']<=20)]) 
overcinquanta_data = len(dfdTorta[(dfdTorta['age']>=55) & (dfdTorta['number']<=20)])
unknow_data = len(dfdTorta[(dfdTorta['age']==0) & (dfdTorta['number']<=20)])

# %%
#================COSTRUISCO GRAFICO RELEVANCE=====================
plt.subplot()
#fig, ax = plt.subplots()

#=======<30=======
plt.scatter(1, 1, s=primo_undertrenta*30, color= 'blue' , alpha=0.5, label='undertrenta')
plt.scatter(1, 2, s = secondo_undertrenta*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 3, s=terzo_undertrenta*30,color= 'blue', alpha=0.5)
plt.scatter(1, 4, s=quarto_undertrenta*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 5, s = quinto_undertrenta*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 6, s=sesto_undertrenta*30,color= 'blue', alpha=0.5)
plt.scatter(1, 7, s=settimo_undertrenta*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 8, s = ottavo_undertrenta*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 9, s=nono_undertrenta*30,color= 'blue', alpha=0.5)
plt.scatter(1, 10, s=decimo_undertrenta*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 11, s=undicesimo_undertrenta*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 12, s = dodicesimo_undertrenta*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 13, s=tredi_undertrenta*30,color= 'blue', alpha=0.5)
plt.scatter(1, 14, s=quattordi_undertrenta*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 15, s = quindi_undertrenta*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 16, s=sedi_undertrenta*30,color= 'blue', alpha=0.5)
plt.scatter(1, 17, s=dicia_undertrenta*30, color= 'blue' , alpha=0.5)
plt.scatter(1, 18, s = dicio_undertrenta*30, color= 'blue',  alpha=0.5)
plt.scatter(1, 19, s=dician_undertrenta*30,color= 'blue', alpha=0.5)
plt.scatter(1, 20, s=venti_undertrenta*30, color= 'blue' , alpha=0.5)

#====30-40=====
plt.scatter(2, 1, s=primo_trentaquaranta*30, color= 'green' , alpha=0.5, label='trentaquaranta')
plt.scatter(2, 2, s = secondo_trentaquaranta*30, color= 'green',  alpha=0.5)
plt.scatter(2, 3, s=terzo_trentaquaranta*30,color= 'green', alpha=0.5)
plt.scatter(2, 4, s=quarto_trentaquaranta*30, color= 'green' , alpha=0.5)
plt.scatter(2, 5, s = quinto_trentaquaranta*30, color= 'green',  alpha=0.5)
plt.scatter(2, 6, s=sesto_trentaquaranta*30,color= 'green', alpha=0.5)
plt.scatter(2, 7, s=settimo_trentaquaranta*30, color= 'green' , alpha=0.5)
plt.scatter(2, 8, s = ottavo_trentaquaranta*30, color= 'green',  alpha=0.5)
plt.scatter(2, 9, s=nono_trentaquaranta*30,color= 'green', alpha=0.5)
plt.scatter(2, 10, s=decimo_trentaquaranta*30, color= 'green' , alpha=0.5)
plt.scatter(2, 11, s=undicesimo_trentaquaranta*30, color= 'green' , alpha=0.5)
plt.scatter(2, 12, s = dodicesimo_trentaquaranta*30, color= 'green',  alpha=0.5)
plt.scatter(2, 13, s=tredi_trentaquaranta*30,color= 'green', alpha=0.5)
plt.scatter(2, 14, s=quattordi_trentaquaranta*30, color= 'green' , alpha=0.5)
plt.scatter(2, 15, s = quindi_trentaquaranta*30, color= 'green',  alpha=0.5)
plt.scatter(2, 16, s=sedi_trentaquaranta*30,color= 'green', alpha=0.5)
plt.scatter(2, 17, s=dicia_trentaquaranta*30, color= 'green' , alpha=0.5)
plt.scatter(2, 18, s = dicio_trentaquaranta*30, color= 'green',  alpha=0.5)
plt.scatter(2, 19, s=dician_trentaquaranta*30,color= 'green', alpha=0.5)
plt.scatter(2, 20, s=venti_trentaquaranta*30, color= 'green' , alpha=0.5)

#======40-55=========
plt.scatter(3, 1, s=primo_quarantacinquanta*30, color= 'red' , alpha=0.5)
plt.scatter(3, 2, s = secondo_quarantacinquanta*30, color= 'red',  alpha=0.5)
plt.scatter(3, 3, s=terzo_quarantacinquanta*30,color= 'red', alpha=0.5)
plt.scatter(3, 4, s=quarto_quarantacinquanta*30, color= 'red' , alpha=0.5)
plt.scatter(3, 5, s = quinto_quarantacinquanta*30, color= 'red',  alpha=0.5)
plt.scatter(3, 6, s=sesto_quarantacinquanta*30,color= 'red', alpha=0.5)
plt.scatter(3, 7, s=settimo_quarantacinquanta*30, color= 'red' , alpha=0.5)
plt.scatter(3, 8, s = ottavo_quarantacinquanta*30, color= 'red',  alpha=0.5)
plt.scatter(3, 9, s=nono_quarantacinquanta*30,color= 'red', alpha=0.5)
plt.scatter(3, 10, s=decimo_quarantacinquanta*30, color= 'red' , alpha=0.5)
plt.scatter(3, 11, s=undicesimo_quarantacinquanta*30, color= 'red' , alpha=0.5)
plt.scatter(3, 12, s = dodicesimo_quarantacinquanta*30, color= 'red',  alpha=0.5)
plt.scatter(3, 13, s=tredi_quarantacinquanta*30,color= 'red', alpha=0.5)
plt.scatter(3, 14, s=quattordi_quarantacinquanta*30, color= 'red' , alpha=0.5)
plt.scatter(3, 15, s = quindi_quarantacinquanta*30, color= 'red',  alpha=0.5)
plt.scatter(3, 16, s=sedi_quarantacinquanta*30,color= 'red', alpha=0.5)
plt.scatter(3, 17, s=dicia_quarantacinquanta*30, color= 'red' , alpha=0.5)
plt.scatter(3, 18, s = dicio_quarantacinquanta*30, color= 'red',  alpha=0.5)
plt.scatter(3, 19, s=dician_quarantacinquanta*30,color= 'red', alpha=0.5)
plt.scatter(3, 20, s=venti_quarantacinquanta*30, color= 'red' , alpha=0.5)


#========>55=======
plt.scatter(4, 1, s=primo_overcinquanta*30, color= 'orange' , alpha=0.5)
plt.scatter(4, 2, s = secondo_overcinquanta*30, color= 'orange',  alpha=0.5)
plt.scatter(4, 3, s=terzo_overcinquanta*30,color= 'orange', alpha=0.5)
plt.scatter(4, 4, s=quarto_overcinquanta*30, color= 'orange' , alpha=0.5)
plt.scatter(4, 5, s = quinto_overcinquanta*30, color= 'orange',  alpha=0.5)
plt.scatter(4, 6, s=sesto_overcinquanta*30,color= 'orange', alpha=0.5)
plt.scatter(4, 7, s=settimo_overcinquanta*30, color= 'orange' , alpha=0.5)
plt.scatter(4, 8, s = ottavo_overcinquanta*30, color= 'orange',  alpha=0.5)
plt.scatter(4, 9, s=nono_overcinquanta*30,color= 'orange', alpha=0.5)
plt.scatter(4, 10, s=decimo_overcinquanta*30, color= 'orange' , alpha=0.5)
plt.scatter(4, 11, s=undicesimo_overcinquanta*30, color= 'orange' , alpha=0.5)
plt.scatter(4, 12, s = dodicesimo_overcinquanta*30, color= 'orange',  alpha=0.5)
plt.scatter(4, 13, s=tredi_overcinquanta*30,color= 'orange', alpha=0.5)
plt.scatter(4, 14, s=quattordi_overcinquanta*30, color= 'orange' , alpha=0.5)
plt.scatter(4, 15, s = quindi_overcinquanta*30, color= 'orange',  alpha=0.5)
plt.scatter(4, 16, s=sedi_overcinquanta*30,color= 'orange', alpha=0.5)
plt.scatter(4, 17, s=dicia_overcinquanta*30, color= 'orange' , alpha=0.5)
plt.scatter(4, 18, s = dicio_overcinquanta*30, color= 'orange',  alpha=0.5)
plt.scatter(4, 19, s=dician_overcinquanta*30,color= 'orange', alpha=0.5)
plt.scatter(4, 20, s=venti_overcinquanta*30, color= 'orange' , alpha=0.5)


#==========unknow
plt.scatter(5, 1, s=primo_unknow*30, color= 'grey' , alpha=0.5)
plt.scatter(5, 2, s = secondo_unknow*30, color= 'grey',  alpha=0.5)
plt.scatter(5, 3, s=terzo_unknow*30,color= 'grey', alpha=0.5)
plt.scatter(5, 4, s=quarto_unknow*30, color= 'grey' , alpha=0.5)
plt.scatter(5, 5, s = quinto_unknow*30, color= 'grey',  alpha=0.5)
plt.scatter(5, 6, s=sesto_unknow*30,color= 'grey', alpha=0.5)
plt.scatter(5, 7, s=settimo_unknow*30, color= 'grey' , alpha=0.5)
plt.scatter(5, 8, s = ottavo_unknow*30, color= 'grey',  alpha=0.5)
plt.scatter(5, 9, s=nono_unknow*30,color= 'grey', alpha=0.5)
plt.scatter(5, 10, s=decimo_unknow*30, color= 'grey' , alpha=0.5)
plt.scatter(5, 11, s=undicesimo_unknow*30, color= 'grey' , alpha=0.5)
plt.scatter(5, 12, s = dodicesimo_unknow*30, color= 'grey',  alpha=0.5)
plt.scatter(5, 13, s=tredi_unknow*30,color= 'grey', alpha=0.5)
plt.scatter(5, 14, s=quattordi_unknow*30, color= 'grey' , alpha=0.5)
plt.scatter(5, 15, s = quindi_unknow*30, color= 'grey',  alpha=0.5)
plt.scatter(5, 16, s=sedi_unknow*30,color= 'grey', alpha=0.5)
plt.scatter(5, 17, s=dicia_unknow*30, color= 'grey' , alpha=0.5)
plt.scatter(5, 18, s = dicio_unknow*30, color= 'grey',  alpha=0.5)
plt.scatter(5, 19, s=dician_unknow*30,color= 'grey', alpha=0.5)
plt.scatter(5, 20, s=venti_unknow*30, color= 'grey' , alpha=0.5)

#=======RIFINITURE========
plt.hlines(y=11, xmin=0.85, xmax=5.15)

plt.title("Distribuzione dell'età nelle prime 20 posizioni secondo ordinamento per data")
plt.ylabel('Posizione in classifica', labelpad = 16)
plt.xlabel('Fascia di età' , labelpad = 16)
#setta ogni quante y ti fa vedere
plt.yticks(np.arange(0, 20, 5.0))
plt.xticks(np.arange(1, 4, 1.0))
plt.xticks([1,2,3,4,5],['under 30','30-40','40-55','over 55','non riconosciuti'])
plt.show()

labels = ['<30', '30-40', '40-55', '>55','non riconosciuti']
sizes = [undertrenta_data, trentaquaranta_data, quarantacinquanta_data, overcinquanta_data,unknow_data] 
explode = [0, 0, 0, 0,0.1]
fig, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90,colors =['cornflowerblue','mediumseagreen','tomato','gold','silver'])
ax1.set_title("Distribuzione dell'età secondo ordinamento per data")
fig.tight_layout()
