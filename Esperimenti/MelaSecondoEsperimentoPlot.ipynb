# %% [markdown]
# <a href="https://colab.research.google.com/github/EleonoraBartolomucci/Fairness/blob/master/Esperimenti/MelaSecondoEsperimentoPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
from google.colab import auth
import json
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

sort = 'Relevance'

relevance = '1nwGbyk8q2S-0BkLcyFVqdK6emTooxHJv'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': relevance})
download.GetContentFile('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

dfr = pd.read_csv('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

sort = 'Date'

date = '1Pb2It9WPid9Irjp6bRVgCF7B3Y5ARBjT'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': date})
download.GetContentFile('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

dfd = pd.read_csv('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

# %%
#filtro il df prendendo solo le righe che mi interessano
df1 = dfr[(dfr['restaurant']=='TupeloHoney') & (dfr['gender']=='masculine')]
df2 = dfd[(dfd['restaurant']=='TupeloHoney')  & (dfd['gender']=='masculine')]

df1['sort'] = 'yelp1'
df2['sort'] ='date1'

df = pd.concat([df1, df2])
df = df[(df['number']<40)]

df = df.sort_values('number')
y1 = df['number'].tolist()
x1 = df['sort'].tolist()

#filtro il df prendendo solo le righe che mi interessano
df1 = dfr[(dfr['restaurant']=='TupeloHoney') & (dfr['gender']=='feminine')]
df2 = dfd[(dfd['restaurant']=='TupeloHoney')  & (dfd['gender']=='feminine')]

df1['sort'] = 'yelp1'
df2['sort'] ='date1'

df = pd.concat([df1, df2])
df = df[(df['number']<40)]

df = df.sort_values('number')
y2 = df['number'].tolist()
x2 = df['sort'].tolist()


plt.scatter(x1,y1, s=10, color='blue')
plt.scatter(x2,y2, s=10, color='pink')


#=============================================================================================================================

#filtro il df prendendo solo le righe che mi interessano
df1 = dfr[(dfr['restaurant']=='CulinaryDropout') & (dfr['gender']=='masculine')]
df2 = dfd[(dfd['restaurant']=='CulinaryDropout')  & (dfd['gender']=='masculine')]

df1['sort'] = 'yelp2'
df2['sort'] ='date2'

df = pd.concat([df1, df2])
df = df[(df['number']<40)]

df = df.sort_values('number')
y1 = df['number'].tolist()
x1 = df['sort'].tolist()

#filtro il df prendendo solo le righe che mi interessano
df1 = dfr[(dfr['restaurant']=='CulinaryDropout') & (dfr['gender']=='feminine')]
df2 = dfd[(dfd['restaurant']=='CulinaryDropout')  & (dfd['gender']=='feminine')]

df1['sort'] = 'yelp2'
df2['sort'] ='date2'

df = pd.concat([df1, df2])
df = df[(df['number']<40)]

df = df.sort_values('number')
y2 = df['number'].tolist()
x2 = df['sort'].tolist()


plt.scatter(x1,y1, s=10, color='blue')
plt.scatter(x2,y2, s=10, color='pink')

#=============================================================================================================================
#filtro il df prendendo solo le righe che mi interessano
df1 = dfr[(dfr['restaurant']=='CravingsBuffet') & (dfr['gender']=='masculine')]
df2 = dfd[(dfd['restaurant']=='CravingsBuffet')  & (dfd['gender']=='masculine')]

df1['sort'] = 'yelp3'
df2['sort'] ='date3'

df = pd.concat([df1, df2])
df = df[(df['number']<40)]

df = df.sort_values('number')
y1 = df['number'].tolist()
x1 = df['sort'].tolist()

#filtro il df prendendo solo le righe che mi interessano
df1 = dfr[(dfr['restaurant']=='CravingsBuffet') & (dfr['gender']=='feminine')]
df2 = dfd[(dfd['restaurant']=='CravingsBuffet')  & (dfd['gender']=='feminine')]

df1['sort'] = 'yelp3'
df2['sort'] ='date3'

df = pd.concat([df1, df2])
df = df[(df['number']<40)]

df = df.sort_values('number')
y2 = df['number'].tolist()
x2 = df['sort'].tolist()

plt.scatter(x1,y1, s=10, color='blue')
plt.scatter(x2,y2, s=10, color='pink')
#=================================================================================================

#servono per mettere la griglia
axes = plt.gca()
axes.yaxis.grid()
#mi definisce i limiti della y
axes.set_ylim([1,40])
#axes.set_xticklabels(labels)

#scegliere dove mettere le etichette
plt.yticks(np.arange(0, 40, 10.0))

#plt.scatter(x1,y1)

#plt.legend(loc="upper center")
plt.xlabel('Ordinamento')
plt.ylabel('Posizione in classifica')


# disable ticks in the x axis
#plt.xticks([])


#plt.legend(reversed_handles,correct_labels)

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
