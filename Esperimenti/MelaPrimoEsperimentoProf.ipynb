# %% [markdown]
# <a href="https://colab.research.google.com/github/EleonoraBartolomucci/Fairness/blob/master/Esperimenti/MelaPrimoEsperimentoProf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
from google.colab import auth
import json
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

sort = 'Relevance'

relevance = '1nwGbyk8q2S-0BkLcyFVqdK6emTooxHJv'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': relevance})
download.GetContentFile('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

dfr = pd.read_csv('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

sort = 'Date'

date = '1Pb2It9WPid9Irjp6bRVgCF7B3Y5ARBjT'  # FILE ID, got on google drive with condivision link
download = drive.CreateFile({'id': date})
download.GetContentFile('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

dfd = pd.read_csv('AllRestaurant_' + '%s' % sort + '_Analysis.csv')

# %%
#============================================
#========RISTORANTI AMERICANI================
#============================================

# %%
#============TUPELO HONEY====================
tupelo_white_relevance = dfr[(dfr['restaurant']=='TupeloHoney') & (dfr['ethnicity']=='white') & (dfr['number']<=20)]
tupelo_white_data = dfd[(dfd['restaurant']=='TupeloHoney')  & (dfd['ethnicity']=='white') & (dfd['number']<=20)]

tupelo_asian_relevance = dfr[(dfr['restaurant']=='TupeloHoney') & (dfr['ethnicity']=='asian') & (dfr['number']<=20)]
tupelo_asian_data = dfd[(dfd['restaurant']=='TupeloHoney')  & (dfd['ethnicity']=='asian') & (dfd['number']<=20)]

tupelo_black_relevance = dfr[(dfr['restaurant']=='TupeloHoney') & (dfr['ethnicity']=='black or african american') & (dfr['number']<=20)]
tupelo_black_data = dfd[(dfd['restaurant']=='TupeloHoney')  & (dfd['ethnicity']=='black or african american') & (dfd['number']<=20)]

tupelo_spanish_relevance = dfr[(dfr['restaurant']=='TupeloHoney') & (dfr['ethnicity']=='hispanic, latino, or spanish origin') & (dfr['number']<=20)]
tupelo_spanish_data = dfd[(dfd['restaurant']=='TupeloHoney')  & (dfd['ethnicity']=='hispanic, latino, or spanish origin') & (dfd['number']<=20)]

tupelo_unknow_relevance = dfr[(dfr['restaurant']=='TupeloHoney') & (dfr['ethnicity']=='Not recognized') & (dfr['number']<=20)]
tupelo_unknow_data = dfd[(dfd['restaurant']=='TupeloHoney')  & (dfd['ethnicity']=='Not recognized') & (dfd['number']<=20)]




tupelo_y_white_relevance = tupelo_white_relevance['number'].tolist()
tupelo_y_white_data = tupelo_white_data['number'].tolist()

tupelo_y_asian_relevance = tupelo_asian_relevance['number'].tolist()
tupelo_y_asian_data = tupelo_asian_data['number'].tolist()

tupelo_y_black_relevance = tupelo_black_relevance['number'].tolist()
tupelo_y_black_data = tupelo_black_data['number'].tolist()

tupelo_y_spanish_relevance = tupelo_spanish_relevance['number'].tolist()
tupelo_y_spanish_data = tupelo_spanish_data['number'].tolist()

tupelo_y_unknow_relevance = tupelo_unknow_relevance['number'].tolist()
tupelo_y_unknow_data = tupelo_unknow_data['number'].tolist()

def tupelo_x_data(dim):
  lista =[]
  for i in range(dim):
    lista.append(1)
  return lista

def tupelo_x_relevance(dim):
  lista =[]
  for i in range(dim):
    lista.append(1.5)
  return lista

# %%
#============CULINARY DROPOUT====================
culinary_white_relevance = dfr[(dfr['restaurant']=='CulinaryDropout') & (dfr['ethnicity']=='white') & (dfr['number']<=20)]
culinary_white_data = dfd[(dfd['restaurant']=='CulinaryDropout')  & (dfd['ethnicity']=='white') & (dfd['number']<=20)]

culinary_asian_relevance = dfr[(dfr['restaurant']=='CulinaryDropout') & (dfr['ethnicity']=='asian') & (dfr['number']<=20)]
culinary_asian_data = dfd[(dfd['restaurant']=='CulinaryDropout')  & (dfd['ethnicity']=='asian') & (dfd['number']<=20)]

culinary_black_relevance = dfr[(dfr['restaurant']=='CulinaryDropout') & (dfr['ethnicity']=='black or african american') & (dfr['number']<=20)]
culinary_black_data = dfd[(dfd['restaurant']=='CulinaryDropout')  & (dfd['ethnicity']=='black or african american') & (dfd['number']<=20)]

culinary_spanish_relevance = dfr[(dfr['restaurant']=='CulinaryDropout') & (dfr['ethnicity']=='hispanic, latino, or spanish origin') & (dfr['number']<=20)]
culinary_spanish_data = dfd[(dfd['restaurant']=='CulinaryDropout')  & (dfd['ethnicity']=='hispanic, latino, or spanish origin') & (dfd['number']<=20)]

culinary_unknow_relevance = dfr[(dfr['restaurant']=='CulinaryDropout') & (dfr['ethnicity']=='Not recognized') & (dfr['number']<=20)]
culinary_unknow_data = dfd[(dfd['restaurant']=='CulinaryDropout')  & (dfd['ethnicity']=='Not recognized') & (dfd['number']<=20)]




culinary_y_white_relevance = culinary_white_relevance['number'].tolist()
culinary_y_white_data = culinary_white_data['number'].tolist()

culinary_y_asian_relevance = culinary_asian_relevance['number'].tolist()
culinary_y_asian_data = culinary_asian_data['number'].tolist()

culinary_y_black_relevance = culinary_black_relevance['number'].tolist()
culinary_y_black_data = culinary_black_data['number'].tolist()

culinary_y_spanish_relevance = culinary_spanish_relevance['number'].tolist()
culinary_y_spanish_data = culinary_spanish_data['number'].tolist()

culinary_y_unknow_relevance = culinary_unknow_relevance['number'].tolist()
culinary_y_unknow_data = culinary_unknow_data['number'].tolist()

def culinary_x_data(dim):
  lista =[]
  for i in range(dim):
    lista.append(4)
  return lista

def culinary_x_relevance(dim):
  lista =[]
  for i in range(dim):
    lista.append(4.5)
  return lista

# %%
#============CRAVINGS BUFFET====================
cravings_white_relevance = dfr[(dfr['restaurant']=='CravingsBuffet') & (dfr['ethnicity']=='white') & (dfr['number']<=20)]
cravings_white_data = dfd[(dfd['restaurant']=='CravingsBuffet')  & (dfd['ethnicity']=='white') & (dfd['number']<=20)]

cravings_asian_relevance = dfr[(dfr['restaurant']=='CravingsBuffet') & (dfr['ethnicity']=='asian') & (dfr['number']<=20)]
cravings_asian_data = dfd[(dfd['restaurant']=='CravingsBuffet')  & (dfd['ethnicity']=='asian') & (dfd['number']<=20)]

cravings_black_relevance = dfr[(dfr['restaurant']=='CravingsBuffet') & (dfr['ethnicity']=='black or african american') & (dfr['number']<=20)]
cravings_black_data = dfd[(dfd['restaurant']=='CravingsBuffet')  & (dfd['ethnicity']=='black or african american') & (dfd['number']<=20)]

cravings_spanish_relevance = dfr[(dfr['restaurant']=='CravingsBuffet') & (dfr['ethnicity']=='hispanic, latino, or spanish origin') & (dfr['number']<=20)]
cravings_spanish_data = dfd[(dfd['restaurant']=='CravingsBuffet')  & (dfd['ethnicity']=='hispanic, latino, or spanish origin') & (dfd['number']<=20)]

cravings_unknow_relevance = dfr[(dfr['restaurant']=='CravingsBuffet') & (dfr['ethnicity']=='Not recognized') & (dfr['number']<=20)]
cravings_unknow_data = dfd[(dfd['restaurant']=='CravingsBuffet')  & (dfd['ethnicity']=='Not recognized') & (dfd['number']<=20)]



cravings_y_white_relevance = cravings_white_relevance['number'].tolist()
cravings_y_white_data = cravings_white_data['number'].tolist()

cravings_y_asian_relevance = cravings_asian_relevance['number'].tolist()
cravings_y_asian_data = cravings_asian_data['number'].tolist()

cravings_y_black_relevance = cravings_black_relevance['number'].tolist()
cravings_y_black_data = cravings_black_data['number'].tolist()

cravings_y_spanish_relevance = cravings_spanish_relevance['number'].tolist()
cravings_y_spanish_data = cravings_spanish_data['number'].tolist()

cravings_y_unknow_relevance = cravings_unknow_relevance['number'].tolist()
cravings_y_unknow_data = cravings_unknow_data['number'].tolist()

def cravings_x_data(dim):
  lista =[]
  for i in range(dim):
    lista.append(8)
  return lista

def cravings_x_relevance(dim):
  lista =[]
  for i in range(dim):
    lista.append(8.5)
  return lista

# %%
#============================================
#========RISTORANTI GIAPPONESI================
#============================================

# %%
#============FUTO BUTA====================
futo_white_relevance = dfr[(dfr['restaurant']=='FutoButa') & (dfr['ethnicity']=='white') & (dfr['number']<=20)]
futo_white_data = dfd[(dfd['restaurant']=='FutoButa')  & (dfd['ethnicity']=='white') & (dfd['number']<=20)]

futo_asian_relevance = dfr[(dfr['restaurant']=='FutoButa') & (dfr['ethnicity']=='asian') & (dfr['number']<=20)]
futo_asian_data = dfd[(dfd['restaurant']=='FutoButa')  & (dfd['ethnicity']=='asian') & (dfd['number']<=20)]

futo_black_relevance = dfr[(dfr['restaurant']=='FutoButa') & (dfr['ethnicity']=='black or african american') & (dfr['number']<=20)]
futo_black_data = dfd[(dfd['restaurant']=='FutoButa')  & (dfd['ethnicity']=='black or african american') & (dfd['number']<=20)]

futo_spanish_relevance = dfr[(dfr['restaurant']=='FutoButa') & (dfr['ethnicity']=='hispanic, latino, or spanish origin') & (dfr['number']<=20)]
futo_spanish_data = dfd[(dfd['restaurant']=='FutoButa')  & (dfd['ethnicity']=='hispanic, latino, or spanish origin') & (dfd['number']<=20)]

futo_unknow_relevance = dfr[(dfr['restaurant']=='FutoButa') & (dfr['ethnicity']=='Not recognized') & (dfr['number']<=20)]
futo_unknow_data = dfd[(dfd['restaurant']=='FutoButa')  & (dfd['ethnicity']=='Not recognized') & (dfd['number']<=20)]


futo_y_white_relevance = futo_white_relevance['number'].tolist()
futo_y_white_data = futo_white_data['number'].tolist()

futo_y_asian_relevance = futo_asian_relevance['number'].tolist()
futo_y_asian_data = futo_asian_data['number'].tolist()

futo_y_black_relevance = futo_black_relevance['number'].tolist()
futo_y_black_data = futo_black_data['number'].tolist()

futo_y_spanish_relevance = futo_spanish_relevance['number'].tolist()
futo_y_spanish_data = futo_spanish_data['number'].tolist()

futo_y_unknow_relevance = futo_unknow_relevance['number'].tolist()
futo_y_unknow_data = futo_unknow_data['number'].tolist()

def futo_x_data(dim):
  lista =[]
  for i in range(dim):
    lista.append(12)
  return lista

def futo_x_relevance(dim):
  lista =[]
  for i in range(dim):
    lista.append(12.5)
  return lista

# %%
#============HARUMI SUSHI====================
harumi_white_relevance = dfr[(dfr['restaurant']=='HarumiSushi') & (dfr['ethnicity']=='white') & (dfr['number']<=20)]
harumi_white_data = dfd[(dfd['restaurant']=='HarumiSushi')  & (dfd['ethnicity']=='white') & (dfd['number']<=20)]

harumi_asian_relevance = dfr[(dfr['restaurant']=='HarumiSushi') & (dfr['ethnicity']=='asian') & (dfr['number']<=20)]
harumi_asian_data = dfd[(dfd['restaurant']=='HarumiSushi')  & (dfd['ethnicity']=='asian') & (dfd['number']<=20)]

harumi_black_relevance = dfr[(dfr['restaurant']=='HarumiSushi') & (dfr['ethnicity']=='black or african american') & (dfr['number']<=20)]
harumi_black_data = dfd[(dfd['restaurant']=='HarumiSushi')  & (dfd['ethnicity']=='black or african american') & (dfd['number']<=20)]

harumi_spanish_relevance = dfr[(dfr['restaurant']=='HarumiSushi') & (dfr['ethnicity']=='hispanic, latino, or spanish origin') & (dfr['number']<=20)]
harumi_spanish_data = dfd[(dfd['restaurant']=='HarumiSushi')  & (dfd['ethnicity']=='hispanic, latino, or spanish origin') & (dfd['number']<=20)]

harumi_unknow_relevance = dfr[(dfr['restaurant']=='HarumiSushi') & (dfr['ethnicity']=='Not recognized') & (dfr['number']<=20)]
harumi_unknow_data = dfd[(dfd['restaurant']=='HarumiSushi')  & (dfd['ethnicity']=='Not recognized') & (dfd['number']<=20)]

harumi_y_white_relevance = harumi_white_relevance['number'].tolist()
harumi_y_white_data = harumi_white_data['number'].tolist()

harumi_y_asian_relevance = harumi_asian_relevance['number'].tolist()
harumi_y_asian_data = harumi_asian_data['number'].tolist()

harumi_y_black_relevance = harumi_black_relevance['number'].tolist()
harumi_y_black_data = harumi_black_data['number'].tolist()

harumi_y_spanish_relevance = harumi_spanish_relevance['number'].tolist()
harumi_y_spanish_data = harumi_spanish_data['number'].tolist()

harumi_y_unknow_relevance = harumi_unknow_relevance['number'].tolist()
harumi_y_unknow_data = harumi_unknow_data['number'].tolist()

def harumi_x_data(dim):
  lista =[]
  for i in range(dim):
    lista.append(16)
  return lista

def harumi_x_relevance(dim):
  lista =[]
  for i in range(dim):
    lista.append(16.5)
  return lista

# %%
#============ICHIZA====================
ichiza_white_relevance = dfr[(dfr['restaurant']=='Ichiza') & (dfr['ethnicity']=='white') & (dfr['number']<=20)]
ichiza_white_data = dfd[(dfd['restaurant']=='Ichiza')  & (dfd['ethnicity']=='white') & (dfd['number']<=20)]

ichiza_asian_relevance = dfr[(dfr['restaurant']=='Ichiza') & (dfr['ethnicity']=='asian') & (dfr['number']<=20)]
ichiza_asian_data = dfd[(dfd['restaurant']=='Ichiza')  & (dfd['ethnicity']=='asian') & (dfd['number']<=20)]

ichiza_black_relevance = dfr[(dfr['restaurant']=='Ichiza') & (dfr['ethnicity']=='black or african american') & (dfr['number']<=20)]
ichiza_black_data = dfd[(dfd['restaurant']=='Ichiza')  & (dfd['ethnicity']=='black or african american') & (dfd['number']<=20)]

ichiza_spanish_relevance = dfr[(dfr['restaurant']=='Ichiza') & (dfr['ethnicity']=='hispanic, latino, or spanish origin') & (dfr['number']<=20)]
ichiza_spanish_data = dfd[(dfd['restaurant']=='Ichiza')  & (dfd['ethnicity']=='hispanic, latino, or spanish origin') & (dfd['number']<=20)]

ichiza_unknow_relevance = dfr[(dfr['restaurant']=='Ichiza') & (dfr['ethnicity']=='Not recognized') & (dfr['number']<=20)]
ichiza_unknow_data = dfd[(dfd['restaurant']=='Ichiza')  & (dfd['ethnicity']=='Not recognized') & (dfd['number']<=20)]

ichiza_y_white_relevance = ichiza_white_relevance['number'].tolist()
ichiza_y_white_data = ichiza_white_data['number'].tolist()

ichiza_y_asian_relevance = ichiza_asian_relevance['number'].tolist()
ichiza_y_asian_data = ichiza_asian_data['number'].tolist()

ichiza_y_black_relevance = ichiza_black_relevance['number'].tolist()
ichiza_y_black_data = ichiza_black_data['number'].tolist()

ichiza_y_spanish_relevance = ichiza_spanish_relevance['number'].tolist()
ichiza_y_spanish_data = ichiza_spanish_data['number'].tolist()

ichiza_y_unknow_relevance = ichiza_unknow_relevance['number'].tolist()
ichiza_y_unknow_data = ichiza_unknow_data['number'].tolist()

def ichiza_x_data(dim):
  lista =[]
  for i in range(dim):
    lista.append(20)
  return lista

def ichiza_x_relevance(dim):
  lista =[]
  for i in range(dim):
    lista.append(20.5)
  return lista

# %%
#============================================
#========RISTORANTI MESSICANI================
#============================================

# %%
#============CABOFISH TACO====================
cabo_white_relevance = dfr[(dfr['restaurant']=='CaboFishTaco') & (dfr['ethnicity']=='white') & (dfr['number']<=20)]
cabo_white_data = dfd[(dfd['restaurant']=='CaboFishTaco')  & (dfd['ethnicity']=='white') & (dfd['number']<=20)]

cabo_asian_relevance = dfr[(dfr['restaurant']=='CaboFishTaco') & (dfr['ethnicity']=='asian') & (dfr['number']<=20)]
cabo_asian_data = dfd[(dfd['restaurant']=='CaboFishTaco')  & (dfd['ethnicity']=='asian') & (dfd['number']<=20)]

cabo_black_relevance = dfr[(dfr['restaurant']=='CaboFishTaco') & (dfr['ethnicity']=='black or african american') & (dfr['number']<=20)]
cabo_black_data = dfd[(dfd['restaurant']=='CaboFishTaco')  & (dfd['ethnicity']=='black or african american') & (dfd['number']<=20)]

cabo_spanish_relevance = dfr[(dfr['restaurant']=='CaboFishTaco') & (dfr['ethnicity']=='hispanic, latino, or spanish origin') & (dfr['number']<=20)]
cabo_spanish_data = dfd[(dfd['restaurant']=='CaboFishTaco')  & (dfd['ethnicity']=='hispanic, latino, or spanish origin') & (dfd['number']<=20)]

cabo_unknow_relevance = dfr[(dfr['restaurant']=='CaboFishTaco') & (dfr['ethnicity']=='Not recognized') & (dfr['number']<=20)]
cabo_unknow_data = dfd[(dfd['restaurant']=='CaboFishTaco')  & (dfd['ethnicity']=='Not recognized') & (dfd['number']<=20)]

cabo_y_white_relevance = cabo_white_relevance['number'].tolist()
cabo_y_white_data = cabo_white_data['number'].tolist()

cabo_y_asian_relevance = cabo_asian_relevance['number'].tolist()
cabo_y_asian_data = cabo_asian_data['number'].tolist()

cabo_y_black_relevance = cabo_black_relevance['number'].tolist()
cabo_y_black_data = cabo_black_data['number'].tolist()

cabo_y_spanish_relevance = cabo_spanish_relevance['number'].tolist()
cabo_y_spanish_data = cabo_spanish_data['number'].tolist()

cabo_y_unknow_relevance = cabo_unknow_relevance['number'].tolist()
cabo_y_unknow_data = cabo_unknow_data['number'].tolist()

def cabo_x_data(dim):
  lista =[]
  for i in range(dim):
    lista.append(24)
  return lista

def cabo_x_relevance(dim):
  lista =[]
  for i in range(dim):
    lista.append(24.5)
  return lista

# %%
#============BACKYARD TACO====================
backy_white_relevance = dfr[(dfr['restaurant']=='BackyardTaco') & (dfr['ethnicity']=='white') & (dfr['number']<=20)]
backy_white_data = dfd[(dfd['restaurant']=='BackyardTaco')  & (dfd['ethnicity']=='white') & (dfd['number']<=20)]

backy_asian_relevance = dfr[(dfr['restaurant']=='BackyardTaco') & (dfr['ethnicity']=='asian') & (dfr['number']<=20)]
backy_asian_data = dfd[(dfd['restaurant']=='BackyardTaco')  & (dfd['ethnicity']=='asian') & (dfd['number']<=20)]

backy_black_relevance = dfr[(dfr['restaurant']=='BackyardTaco') & (dfr['ethnicity']=='black or african american') & (dfr['number']<=20)]
backy_black_data = dfd[(dfd['restaurant']=='BackyardTaco')  & (dfd['ethnicity']=='black or african american') & (dfd['number']<=20)]

backy_spanish_relevance = dfr[(dfr['restaurant']=='BackyardTaco') & (dfr['ethnicity']=='hispanic, latino, or spanish origin') & (dfr['number']<=20)]
backy_spanish_data = dfd[(dfd['restaurant']=='BackyardTaco')  & (dfd['ethnicity']=='hispanic, latino, or spanish origin') & (dfd['number']<=20)]

backy_unknow_relevance = dfr[(dfr['restaurant']=='BackyardTaco') & (dfr['ethnicity']=='Not recognized') & (dfr['number']<=20)]
backy_unknow_data = dfd[(dfd['restaurant']=='BackyardTaco')  & (dfd['ethnicity']=='Not recognized') & (dfd['number']<=20)]

backy_y_white_relevance = backy_white_relevance['number'].tolist()
backy_y_white_data = backy_white_data['number'].tolist()

backy_y_asian_relevance = backy_asian_relevance['number'].tolist()
backy_y_asian_data = backy_asian_data['number'].tolist()

backy_y_black_relevance = backy_black_relevance['number'].tolist()
backy_y_black_data = backy_black_data['number'].tolist()

backy_y_spanish_relevance = backy_spanish_relevance['number'].tolist()
backy_y_spanish_data = backy_spanish_data['number'].tolist()

backy_y_unknow_relevance = backy_unknow_relevance['number'].tolist()
backy_y_unknow_data = backy_unknow_data['number'].tolist()

def backy_x_data(dim):
  lista =[]
  for i in range(dim):
    lista.append(28)
  return lista

def backy_x_relevance(dim):
  lista =[]
  for i in range(dim):
    lista.append(28.5)
  return lista

# %%
#============LINDO MICHOACAN====================
lindo_white_relevance = dfr[(dfr['restaurant']=='LindoMichoacan') & (dfr['ethnicity']=='white') & (dfr['number']<=20)]
lindo_white_data = dfd[(dfd['restaurant']=='LindoMichoacan')  & (dfd['ethnicity']=='white') & (dfd['number']<=20)]

lindo_asian_relevance = dfr[(dfr['restaurant']=='LindoMichoacan') & (dfr['ethnicity']=='asian') & (dfr['number']<=20)]
lindo_asian_data = dfd[(dfd['restaurant']=='LindoMichoacan')  & (dfd['ethnicity']=='asian') & (dfd['number']<=20)]

lindo_black_relevance = dfr[(dfr['restaurant']=='LindoMichoacan') & (dfr['ethnicity']=='black or african american') & (dfr['number']<=20)]
lindo_black_data = dfd[(dfd['restaurant']=='LindoMichoacan')  & (dfd['ethnicity']=='black or african american') & (dfd['number']<=20)]

lindo_spanish_relevance = dfr[(dfr['restaurant']=='LindoMichoacan') & (dfr['ethnicity']=='hispanic, latino, or spanish origin') & (dfr['number']<=20)]
lindo_spanish_data = dfd[(dfd['restaurant']=='LindoMichoacan')  & (dfd['ethnicity']=='hispanic, latino, or spanish origin') & (dfd['number']<=20)]

lindo_unknow_relevance = dfr[(dfr['restaurant']=='LindoMichoacan') & (dfr['ethnicity']=='Not recognized') & (dfr['number']<=20)]
lindo_unknow_data = dfd[(dfd['restaurant']=='LindoMichoacan')  & (dfd['ethnicity']=='Not recognized') & (dfd['number']<=20)]

lindo_y_white_relevance = lindo_white_relevance['number'].tolist()
lindo_y_white_data = lindo_white_data['number'].tolist()

lindo_y_asian_relevance = lindo_asian_relevance['number'].tolist()
lindo_y_asian_data = lindo_asian_data['number'].tolist()

lindo_y_black_relevance = lindo_black_relevance['number'].tolist()
lindo_y_black_data = lindo_black_data['number'].tolist()

lindo_y_spanish_relevance = lindo_spanish_relevance['number'].tolist()
lindo_y_spanish_data = lindo_spanish_data['number'].tolist()

lindo_y_unknow_relevance = lindo_unknow_relevance['number'].tolist()
lindo_y_unknow_data = lindo_unknow_data['number'].tolist()

def lindo_x_data(dim):
  lista =[]
  for i in range(dim):
    lista.append(32)
  return lista

def lindo_x_relevance(dim):
  lista =[]
  for i in range(dim):
    lista.append(32.5)
  return lista

# %%
#=========COSTRUISCO IL GRAFICO============
fig, ax = plt.subplots()

#=========VALORI TUPELO HONEY==============
ax.scatter(tupelo_x_data(len(tupelo_y_white_data)),tupelo_y_white_data, color = 'blue', label ='white')
ax.scatter(tupelo_x_data(len(tupelo_y_asian_data)),tupelo_y_asian_data, color = 'green', label ='asian')
ax.scatter(tupelo_x_data(len(tupelo_y_black_data)),tupelo_y_black_data,  color = 'black' , label ='black or african american')
ax.scatter(tupelo_x_data(len(tupelo_y_spanish_data)),tupelo_y_spanish_data,  color = 'red',label ='hispanic, latino, or spanish origin')
ax.scatter(tupelo_x_data(len(tupelo_y_unknow_data)),tupelo_y_unknow_data, color = 'grey', label ='unknow')


ax.scatter(tupelo_x_relevance(len(tupelo_y_white_relevance)),tupelo_y_white_relevance, color = 'blue')
ax.scatter(tupelo_x_relevance(len(tupelo_y_asian_relevance)),tupelo_y_asian_relevance, color = 'green')
ax.scatter(tupelo_x_relevance(len(tupelo_y_black_relevance)),tupelo_y_black_relevance, color = 'black')
ax.scatter(tupelo_x_relevance(len(tupelo_y_spanish_relevance)),tupelo_y_spanish_relevance, color = 'red')
ax.scatter(tupelo_x_relevance(len(tupelo_y_unknow_relevance)),tupelo_y_unknow_relevance, color = 'grey')

#=========VALORI CULINARY DROPOUT==============
ax.scatter(culinary_x_data(len(culinary_y_white_data)),culinary_y_white_data, color = 'blue')
ax.scatter(culinary_x_data(len(culinary_y_asian_data)),culinary_y_asian_data, color = 'green')
ax.scatter(culinary_x_data(len(culinary_y_black_data)),culinary_y_black_data,  color = 'black')
ax.scatter(culinary_x_data(len(culinary_y_spanish_data)),culinary_y_spanish_data, color = 'red')
ax.scatter(culinary_x_data(len(culinary_y_unknow_data)),culinary_y_unknow_data, color = 'grey')

ax.scatter(culinary_x_relevance(len(culinary_y_white_relevance)),culinary_y_white_relevance, color = 'blue')
ax.scatter(culinary_x_relevance(len(culinary_y_asian_relevance)),culinary_y_asian_relevance, color = 'green')
ax.scatter(culinary_x_relevance(len(culinary_y_black_relevance)),culinary_y_black_relevance, color = 'black')
ax.scatter(culinary_x_relevance(len(culinary_y_spanish_relevance)),culinary_y_spanish_relevance, color = 'red')
ax.scatter(culinary_x_relevance(len(culinary_y_unknow_relevance)),culinary_y_unknow_relevance, color = 'grey')

#=========VALORI CRAVINGS BUFFET==============
ax.scatter(cravings_x_data(len(cravings_y_white_data)),cravings_y_white_data, color = 'blue')
ax.scatter(cravings_x_data(len(cravings_y_asian_data)),cravings_y_asian_data, color = 'green')
ax.scatter(cravings_x_data(len(cravings_y_black_data)),cravings_y_black_data, color = 'black')
ax.scatter(cravings_x_data(len(cravings_y_spanish_data)),cravings_y_spanish_data, color = 'red')
ax.scatter(cravings_x_data(len(cravings_y_unknow_data)),cravings_y_unknow_data, color = 'grey')

ax.scatter(cravings_x_relevance(len(cravings_y_white_relevance)),cravings_y_white_relevance, color = 'blue')
ax.scatter(cravings_x_relevance(len(cravings_y_asian_relevance)),cravings_y_asian_relevance, color = 'green')
ax.scatter(cravings_x_relevance(len(cravings_y_black_relevance)),cravings_y_black_relevance, color = 'black')
ax.scatter(cravings_x_relevance(len(cravings_y_spanish_relevance)),cravings_y_spanish_relevance, color = 'red')
ax.scatter(cravings_x_relevance(len(cravings_y_unknow_relevance)),cravings_y_unknow_relevance, color = 'grey')

#=========VALORI FUTO BUTA==============
ax.scatter(futo_x_data(len(futo_y_white_data)),futo_y_white_data, color = 'blue')
ax.scatter(futo_x_data(len(futo_y_asian_data)),futo_y_asian_data, color = 'green')
ax.scatter(futo_x_data(len(futo_y_black_data)),futo_y_black_data, color = 'black')
ax.scatter(futo_x_data(len(futo_y_spanish_data)),futo_y_spanish_data, color = 'red')
ax.scatter(futo_x_data(len(futo_y_unknow_data)),futo_y_unknow_data, color = 'grey')

ax.scatter(futo_x_relevance(len(futo_y_white_relevance)),futo_y_white_relevance, color = 'blue')
ax.scatter(futo_x_relevance(len(futo_y_asian_relevance)),futo_y_asian_relevance, color = 'green')
ax.scatter(futo_x_relevance(len(futo_y_black_relevance)),futo_y_black_relevance, color = 'black')
ax.scatter(futo_x_relevance(len(futo_y_spanish_relevance)),futo_y_spanish_relevance, color = 'red')
ax.scatter(futo_x_relevance(len(futo_y_unknow_relevance)),futo_y_unknow_relevance, color = 'grey')

#=========VALORI HARUMI SUSHI==============
ax.scatter(harumi_x_data(len(harumi_y_white_data)),harumi_y_white_data, color = 'blue')
ax.scatter(harumi_x_data(len(harumi_y_asian_data)),harumi_y_asian_data, color = 'green')
ax.scatter(harumi_x_data(len(harumi_y_black_data)),harumi_y_black_data, color = 'black')
ax.scatter(harumi_x_data(len(harumi_y_spanish_data)),harumi_y_spanish_data, color = 'red')
ax.scatter(harumi_x_data(len(harumi_y_unknow_data)),harumi_y_unknow_data, color = 'grey')

ax.scatter(harumi_x_relevance(len(harumi_y_white_relevance)),harumi_y_white_relevance, color = 'blue')
ax.scatter(harumi_x_relevance(len(harumi_y_asian_relevance)),harumi_y_asian_relevance, color = 'green')
ax.scatter(harumi_x_relevance(len(harumi_y_black_relevance)),harumi_y_black_relevance, color = 'black')
ax.scatter(harumi_x_relevance(len(harumi_y_spanish_relevance)),harumi_y_spanish_relevance, color = 'red')
ax.scatter(harumi_x_relevance(len(harumi_y_unknow_relevance)),harumi_y_unknow_relevance, color = 'grey')

#=========VALORI ICHIZA==============
ax.scatter(ichiza_x_data(len(ichiza_y_white_data)),ichiza_y_white_data, color = 'blue')
ax.scatter(ichiza_x_data(len(ichiza_y_asian_data)),ichiza_y_asian_data, color = 'green')
ax.scatter(ichiza_x_data(len(ichiza_y_black_data)),ichiza_y_black_data, color = 'black')
ax.scatter(ichiza_x_data(len(ichiza_y_spanish_data)),ichiza_y_spanish_data,  color = 'red')
ax.scatter(ichiza_x_data(len(ichiza_y_unknow_data)),ichiza_y_unknow_data, color = 'grey')

ax.scatter(ichiza_x_relevance(len(ichiza_y_white_relevance)),ichiza_y_white_relevance, color = 'blue')
ax.scatter(ichiza_x_relevance(len(ichiza_y_asian_relevance)),ichiza_y_asian_relevance, color = 'green')
ax.scatter(ichiza_x_relevance(len(ichiza_y_black_relevance)),ichiza_y_black_relevance, color = 'black')
ax.scatter(ichiza_x_relevance(len(ichiza_y_spanish_relevance)),ichiza_y_spanish_relevance, color = 'red')
ax.scatter(ichiza_x_relevance(len(ichiza_y_unknow_relevance)),ichiza_y_unknow_relevance, color = 'grey')

#=========VALORI CABOFISH TACO==============
ax.scatter(cabo_x_data(len(cabo_y_white_data)),cabo_y_white_data, color = 'blue')
ax.scatter(cabo_x_data(len(cabo_y_asian_data)),cabo_y_asian_data,  color = 'green')
ax.scatter(cabo_x_data(len(cabo_y_black_data)),cabo_y_black_data,  color = 'black')
ax.scatter(cabo_x_data(len(cabo_y_spanish_data)),cabo_y_spanish_data, color = 'red')
ax.scatter(cabo_x_data(len(cabo_y_unknow_data)),cabo_y_unknow_data, color = 'grey')

ax.scatter(cabo_x_relevance(len(cabo_y_white_relevance)),cabo_y_white_relevance, color = 'blue')
ax.scatter(cabo_x_relevance(len(cabo_y_asian_relevance)),cabo_y_asian_relevance, color = 'green')
ax.scatter(cabo_x_relevance(len(cabo_y_black_relevance)),cabo_y_black_relevance, color = 'black')
ax.scatter(cabo_x_relevance(len(cabo_y_spanish_relevance)),cabo_y_spanish_relevance, color = 'red')
ax.scatter(cabo_x_relevance(len(cabo_y_unknow_relevance)),cabo_y_unknow_relevance, color = 'grey')

#=========VALORI BACKYARD TACO==============
ax.scatter(backy_x_data(len(backy_y_white_data)),backy_y_white_data, color = 'blue')
ax.scatter(backy_x_data(len(backy_y_asian_data)),backy_y_asian_data, color = 'green')
ax.scatter(backy_x_data(len(backy_y_black_data)),backy_y_black_data, color = 'black')
ax.scatter(backy_x_data(len(backy_y_spanish_data)),backy_y_spanish_data, color = 'red')
ax.scatter(backy_x_data(len(backy_y_unknow_data)),backy_y_unknow_data, color = 'grey')

ax.scatter(backy_x_relevance(len(backy_y_white_relevance)),backy_y_white_relevance, color = 'blue')
ax.scatter(backy_x_relevance(len(backy_y_asian_relevance)),backy_y_asian_relevance, color = 'green')
ax.scatter(backy_x_relevance(len(backy_y_black_relevance)),backy_y_black_relevance, color = 'black')
ax.scatter(backy_x_relevance(len(backy_y_spanish_relevance)),backy_y_spanish_relevance, color = 'red')
ax.scatter(backy_x_relevance(len(backy_y_unknow_relevance)),backy_y_unknow_relevance, color = 'grey')

#=========VALORI LINDO MICHOACAN========================================================
ax.scatter(lindo_x_data(len(lindo_y_white_data)),lindo_y_white_data, color = 'blue')
ax.scatter(lindo_x_data(len(lindo_y_asian_data)),lindo_y_asian_data, color = 'green')
ax.scatter(lindo_x_data(len(lindo_y_black_data)),lindo_y_black_data, color = 'black')
ax.scatter(lindo_x_data(len(lindo_y_spanish_data)),lindo_y_spanish_data, color = 'red')
ax.scatter(lindo_x_data(len(lindo_y_unknow_data)),lindo_y_unknow_data, color = 'grey')

ax.scatter(lindo_x_relevance(len(lindo_y_white_relevance)),lindo_y_white_relevance, color = 'blue')
ax.scatter(lindo_x_relevance(len(lindo_y_asian_relevance)),lindo_y_asian_relevance, color = 'green')
ax.scatter(lindo_x_relevance(len(lindo_y_black_relevance)),lindo_y_black_relevance, color = 'black')
ax.scatter(lindo_x_relevance(len(lindo_y_spanish_relevance)),lindo_y_spanish_relevance, color = 'red')
ax.scatter(lindo_x_relevance(len(lindo_y_unknow_relevance)),lindo_y_unknow_relevance, color = 'grey')
#===========================================================================================
labels = ['Data1', 'Yelp1','Data2','Yelp2','Data3','Yelp3','Data4','Yelp4','Data5', 'Yelp5','Data6','Yelp6','Data7','Yelp7','Data8','Yelp8','Data9','Yelp9']
ax.set_title('Posizione in classifica di 9 ristoranti secondo ordinamento Relevance e Data ')
ax.set_ylabel('Posizione in classifica', labelpad = 16)
ax.set_xlabel('Ordinamento' , labelpad = 16)
ax.set_yticks(np.arange(0, 20, 5.0))
#ax.set_xticks(labels)
#ax.set_xticklabels(labels)
ax.legend(loc = 'upper center')
plt.xticks([1,1.5,4,4.5,8,8.5,12,12.5,16,16.5,20,20.5,24,24.5,28,28.5,32,32.5],labels,rotation=90)
plt.tight_layout()
ax.hlines(y=11.5, xmin=0, xmax=17)

# %%
labels = ['Data1', 'Yelp1','Data2','Yelp2','Data3','Yelp3','Data4','Yelp4','Data5', 'Yelp5','Data6','Yelp6','Data7','Yelp7','Data8','Yelp8','Data9','Yelp9']
fig, ax = plt.subplots()
ax.set_ylabel('Posizione in classifica')
ax.set_xlabel('Ordinamento')
ax.set_title('Posizione in classifica di 9 ristoranti')
#ax.set_xticks(labels)
ax.set_xticklabels(labels)
x = np.linspace(11,11)  
y = x
ax.plot(x,y)

# %%
#filtro il df prendendo solo le righe che mi interessano
df1 = dfr[(dfr['restaurant']=='TupeloHoney') & (dfr['ethnicity']=='white')]
df2 = dfd[(dfd['restaurant']=='TupeloHoney')  & (dfd['ethnicity']=='white')]
df1['sort1'] = 'yelp1'
df2['sort1'] ='date1'
df = pd.concat([df1, df2])
df = df[(df['number']<40)]

df = df.sort_values('number')
y1 = df['number'].tolist()
x1 = df['sort1'].tolist()

#filtro il df prendendo solo le righe che mi interessano
df1 = dfr[(dfr['restaurant']=='TupeloHoney') & (dfr['ethnicity']=='asian')]
df2 = dfd[(dfd['restaurant']=='TupeloHoney')  & (dfd['ethnicity']=='asian')]
df1['sort1'] = 'yelp1'
df2['sort1'] ='date1'
df = pd.concat([df1, df2])
df = df[(df['number']<40)]

df = df.sort_values('number')
y2 = df['number'].tolist()
x2 = df['sort1'].tolist()

#filtro il df prendendo solo le righe che mi interessano
df1 = dfr[(dfr['restaurant']=='TupeloHoney') & (dfr['ethnicity']=='hispanic, latino, or spanish origin')]
df2 = dfd[(dfd['restaurant']=='TupeloHoney')  & (dfd['ethnicity']=='hispanic, latino, or spanish origin')]
df1['sort1'] = 'yelp1'
df2['sort1'] ='date1'
df = pd.concat([df1, df2])
df = df[(df['number']<40)]

df = df.sort_values('number')
y3 = df['number'].tolist()
x3 = df['sort1'].tolist()

plt.scatter(x1,y1, s=10, color='red')
plt.scatter(x2,y2, s=10, color='green')
plt.scatter(x3,y3, s=10, color='blue')

#=============================================================================================================================

#filtro il df prendendo solo le righe che mi interessano
df1 = dfr[(dfr['restaurant']=='CulinaryDropout') & (dfr['ethnicity']=='white')]
df2 = dfd[(dfd['restaurant']=='CulinaryDropout')  & (dfd['ethnicity']=='white')]
df1['sort2'] = 'yelp2'
df2['sort2'] ='date2'
df = pd.concat([df1, df2])
df = df[(df['number']<40)]

df = df.sort_values('number')
y1 = df['number'].tolist()
x1 = df['sort2'].tolist()

#filtro il df prendendo solo le righe che mi interessano
df1 = dfr[(dfr['restaurant']=='CulinaryDropout') & (dfr['ethnicity']=='asian')]
df2 = dfd[(dfd['restaurant']=='CulinaryDropout')  & (dfd['ethnicity']=='asian')]
df1['sort2'] = 'yelp2'
df2['sort2'] ='date2'
df = pd.concat([df1, df2])
df = df[(df['number']<40)]

df = df.sort_values('number')
y2 = df['number'].tolist()
x2 = df['sort2'].tolist()

#filtro il df prendendo solo le righe che mi interessano
df1 = dfr[(dfr['restaurant']=='CulinaryDropout') & (dfr['ethnicity']=='hispanic, latino, or spanish origin')]
df2 = dfd[(dfd['restaurant']=='CulinaryDropout')  & (dfd['ethnicity']=='hispanic, latino, or spanish origin')]
df1['sort2'] = 'yelp2'
df2['sort2'] ='date2'
df = pd.concat([df1, df2])
df = df[(df['number']<40)]

df = df.sort_values('number')
y3 = df['number'].tolist()
x3 = df['sort2'].tolist()

plt.scatter(x1,y1, s=10, color='red')
plt.scatter(x2,y2, s=10, color='green')
plt.scatter(x3,y3, s=10, color='blue')
#=============================================================================================================================
#filtro il df prendendo solo le righe che mi interessano
df1 = dfr[(dfr['restaurant']=='CravingsBuffet') & (dfr['ethnicity']=='white')]
df2 = dfd[(dfd['restaurant']=='CravingsBuffet')  & (dfd['ethnicity']=='white')]
df1['sort3'] = 'yelp3'
df2['sort3'] ='date3'
df = pd.concat([df1, df2])
df = df[(df['number']<40)]

df = df.sort_values('number')
y1 = df['number'].tolist()
x1 = df['sort3'].tolist()

#filtro il df prendendo solo le righe che mi interessano
df1 = dfr[(dfr['restaurant']=='CravingsBuffet') & (dfr['ethnicity']=='asian')]
df2 = dfd[(dfd['restaurant']=='CravingsBuffet')  & (dfd['ethnicity']=='asian')]
df1['sort3'] = 'yelp3'
df2['sort3'] ='date3'
df = pd.concat([df1, df2])
df = df[(df['number']<40)]

df = df.sort_values('number')
y2 = df['number'].tolist()
x2 = df['sort3'].tolist()

#filtro il df prendendo solo le righe che mi interessano
df1 = dfr[(dfr['restaurant']=='CravingsBuffet') & (dfr['ethnicity']=='hispanic, latino, or spanish origin')]
df2 = dfd[(dfd['restaurant']=='CravingsBuffet')  & (dfd['ethnicity']=='hispanic, latino, or spanish origin')]
df1['sort3'] = 'yelp3'
df2['sort3'] ='date3'
df = pd.concat([df1, df2])
df = df[(df['number']<40)]

df = df.sort_values('number')
y3 = df['number'].tolist()
x3 = df['sort3'].tolist()

#=================================================================================================

#servono per mettere la griglia
axes = plt.gca()
axes.yaxis.grid()
#mi definisce i limiti della y
axes.set_ylim([1,40])

#scegliere dove mettere le etichette
plt.yticks(np.arange(0, 40, 10.0))

#plt.scatter(x1,y1)
plt.scatter(x1,y1, s=10, color='red')
plt.scatter(x2,y2, s=10, color='green')
plt.scatter(x3,y3, s=10, color='blue')
#plt.legend(loc="upper center")
plt.xlabel('Ordinamento')
plt.ylabel('Posizione in classifica')
#plt.xlabel('etnia')

# disable ticks in the x axis
#plt.xticks([])

# fix the legend or it'll include the dummy variable
#current_handles, _ = plt.gca().get_legend_handles_labels()
#reversed_handles = reversed(current_handles)
#correct_labels = reversed(restaurant['restaurant'].unique())

#plt.legend(reversed_handles,correct_labels)

#plt.show()
