# %% [markdown]
# <a href="https://colab.research.google.com/github/EleonoraBartolomucci/Fairness/blob/master/FacePlusPlus/ElaboraFoto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install clarifai
# Out:
# Collecting clarifai
#   Downloading https://files.pythonhosted.org/packages/7a/1b/b7718c29f54ba7545551724461a8c2891304b7e68e5f415c30b49499f5e1/clarifai-2.6.2.tar.gz (125kB)
#      |████████████████████████████████| 133kB 2.9MB/s
# Requirement already satisfied: future<2,>=0.15 in /usr/local/lib/python3.6/dist-packages (from clarifai) (0.16.0)
# Requirement already satisfied: requests<3,>=2.13 in /usr/local/lib/python3.6/dist-packages (from clarifai) (2.21.0)
# Collecting configparser<4,>=3.5
#   Downloading https://files.pythonhosted.org/packages/ab/1a/ec151e5e703ac80041eaccef923611bbcec2b667c20383655a06962732e9/configparser-3.8.1-py2.py3-none-any.whl
# Requirement already satisfied: jsonschema<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from clarifai) (2.6.0)
# Requirement already satisfied: grpcio<2,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from clarifai) (1.24.3)
# Requirement already satisfied: protobuf<4,>=3.6 in /usr/local/lib/python3.6/dist-packages (from clarifai) (3.10.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from clarifai) (1.51.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.13->clarifai) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.13->clarifai) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.13->clarifai) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.13->clarifai) (2.8)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from grpcio<2,>=1.13.0->clarifai) (1.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf<4,>=3.6->clarifai) (45.2.0)
# Building wheels for collected packages: clarifai
#   Building wheel for clarifai (setup.py) ... done
#   Created wheel for clarifai: filename=clarifai-2.6.2-cp36-none-any.whl size=188403 sha256=271feac96c5771eb221ff5b0fa8852803db83139e942ae702f2272ee485843dc
#   Stored in directory: /root/.cache/pip/wheels/17/2c/3b/d89ffd4572633f70872165cedf61813ac8047461ed5e1e3768
# Successfully built clarifai
# Installing collected packages: configparser, clarifai
# Successfully installed clarifai-2.6.2 configparser-3.8.1

# %%
from clarifai.rest import ClarifaiApp
import time

def detect_clarifai(id, url_photo):
  app = ClarifaiApp(api_key='6651c2b2e8d64d3291238ef15277c18c')
  model = app.models.get(model_id="c0c0ac362b03416da06ab3fa36fb58e3")
  response = model.predict_by_url(url = url_photo)
  print(response) #file json completo

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
from google.colab import auth
from clarifai.rest import ApiError

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

#Auto-iterate through all files that matches this query
file_list = drive.ListFile({'q': "'18gjR0tXLt6ET54X-EcUZFBkS2u8Sn1R1' in parents and trashed=false"}).GetList()

for file1 in file_list: 
  url = file1['thumbnailLink']
  url2 = '%s' % url
  detect_clarifai(file1['id'], url2)
# Out:
# {'status': {'code': 10000, 'description': 'Ok', 'req_id': 'e8b9bfd2108243f4b4babb81a7dcb40f'}, 'outputs': [{'id': '921c39e2670541bd94c85163f9a8728d', 'status': {'code': 10000, 'description': 'Ok'}, 'created_at': '2020-03-19T12:08:05.615690383Z', 'model': {'id': 'c0c0ac362b03416da06ab3fa36fb58e3', 'name': 'demographics', 'created_at': '2016-12-23T06:08:44.271674Z', 'app_id': 'main', 'output_info': {'message': 'Show output_info with: GET /models/{model_id}/output_info', 'type': 'detect-concept', 'type_ext': 'detect-concept'}, 'model_version': {'id': 'f783f0807c52474c8c6ad20c8cf45fc0', 'created_at': '2016-12-23T06:08:44.271674Z', 'status': {'code': 21100, 'description': 'Model is trained and ready'}}, 'display_name': 'Demographics'}, 'input': {'id': '4225efbb7ef4411dbdabaad4d43149ed', 'data': {'image': {'url': 'https://lh3.googleusercontent.com/pJtm_5lqEqfl6ei17mlU8TmGZdLBqtYDAleRspsWM15ePjMG8mVD0mpHM9WxqYfo7fGiX5FTIH4=s220'}}}, 'data': {'regions': [{'id': 'cfwfdpop6v87', 'region_info': {'bounding_box': {'top_row': 0.508522629737854, 'left_col': 0.5141555070877075, 'bottom_row': 0.6523330211639404, 'right_col': 0.6578395962715149}}, 'data': {'concepts': [{'id': 'ai_XCS0ZXlc', 'name': '39', 'value': 0.38369232416152954, 'app_id': 'main'}, {'id': 'ai_Jn5sPpjV', 'name': '38', 'value': 0.3747594654560089, 'app_id': 'main'}, {'id': 'ai_pm9dFGXp', 'name': '37', 'value': 0.3702083230018616, 'app_id': 'main'}, {'id': 'ai_KFWpWmRk', 'name': '36', 'value': 0.3642053008079529, 'app_id': 'main'}, {'id': 'ai_wpbCDvCQ', 'name': '40', 'value': 0.32969963550567627, 'app_id': 'main'}, {'id': 'ai_fFJR7TwD', 'name': '24', 'value': 0.3295004367828369, 'app_id': 'main'}, {'id': 'ai_1XrRmbf5', 'name': '23', 'value': 0.3191823661327362, 'app_id': 'main'}, {'id': 'ai_1qNCjBCW', 'name': '27', 'value': 0.31681695580482483, 'app_id': 'main'}, {'id': 'ai_3QlM0LQG', 'name': '35', 'value': 0.3084671199321747, 'app_id': 'main'}, {'id': 'ai_J5NgRLQ1', 'name': '28', 'value': 0.30525678396224976, 'app_id': 'main'}, {'id': 'ai_prhRGPd1', 'name': '34', 'value': 0.2996094226837158, 'app_id': 'main'}, {'id': 'ai_t7C4Hfmm', 'name': '29', 'value': 0.28782978653907776, 'app_id': 'main'}, {'id': 'ai_9SgNdvCZ', 'name': '33', 'value': 0.28319722414016724, 'app_id': 'main'}, {'id': 'ai_Lq29DpjP', 'name': '41', 'value': 0.2811180353164673, 'app_id': 'main'}, {'id': 'ai_hCkCX508', 'name': '26', 'value': 0.275882363319397, 'app_id': 'main'}, {'id': 'ai_f55t4M4T', 'name': '22', 'value': 0.27461904287338257, 'app_id': 'main'}, {'id': 'ai_81J6NJF3', 'name': '25', 'value': 0.26796427369117737, 'app_id': 'main'}, {'id': 'ai_tzZdX8VP', 'name': '30', 'value': 0.26666826009750366, 'app_id': 'main'}, {'id': 'ai_z2K094hx', 'name': '31', 'value': 0.24059277772903442, 'app_id': 'main'}, {'id': 'ai_VtPhMhJv', 'name': '42', 'value': 0.2384161353111267, 'app_id': 'main'}, {'id': 'ai_zgR2BBt0', 'name': 'masculine', 'value': 0.5187313556671143, 'app_id': 'main'}, {'id': 'ai_cVWr8NK5', 'name': 'feminine', 'value': 0.48126867413520813, 'app_id': 'main'}, {'id': 'ai_659b6V0v', 'name': 'asian', 'value': 0.2868039608001709, 'app_id': 'main'}, {'id': 'ai_l9ngrR28', 'name': 'hispanic, latino, or spanish origin', 'value': 0.24402844905853271, 'app_id': 'main'}, {'id': 'ai_r5F00Gqn', 'name': 'white', 'value': 0.19787390530109406, 'app_id': 'main'}, {'id': 'ai_wScNwk9Z', 'name': 'black or african american', 'value': 0.05047362297773361, 'app_id': 'main'}, {'id': 'ai_1qp01psl', 'name': 'native hawaiian or pacific islander', 'value': 0.0478670634329319, 'app_id': 'main'}, {'id': 'ai_WWxnB3mw', 'name': 'american indian or alaska native', 'value': 0.021987002342939377, 'app_id': 'main'}, {'id': 'ai_bZft5m0H', 'name': 'middle eastern or north african', 'value': 0.011930450797080994, 'app_id': 'main'}], 'face': {'age_appearance': {'concepts': [{'id': 'ai_XCS0ZXlc', 'name': '39', 'value': 0.38369232416152954, 'app_id': 'main'}, {'id': 'ai_Jn5sPpjV', 'name': '38', 'value': 0.3747594654560089, 'app_id': 'main'}, ...
# {'status': {'code': 10000, 'description': 'Ok', 'req_id': '90e01ea02e0e43099cface2449b56600'}, 'outputs': [{'id': 'acc82e1f87064ddc829c05382b944847', 'status': {'code': 10000, 'description': 'Ok'}, 'created_at': '2020-03-19T12:08:06.765204106Z', 'model': {'id': 'c0c0ac362b03416da06ab3fa36fb58e3', 'name': 'demographics', 'created_at': '2016-12-23T06:08:44.271674Z', 'app_id': 'main', 'output_info': {'message': 'Show output_info with: GET /models/{model_id}/output_info', 'type': 'detect-concept', 'type_ext': 'detect-concept'}, 'model_version': {'id': 'f783f0807c52474c8c6ad20c8cf45fc0', 'created_at': '2016-12-23T06:08:44.271674Z', 'status': {'code': 21100, 'description': 'Model is trained and ready'}}, 'display_name': 'Demographics'}, 'input': {'id': '466f2cd23c6544c0a3d0a47403972688', 'data': {'image': {'url': 'https://lh3.googleusercontent.com/_aXApraMHuOyr-B_sRJNFTqFeQYouuXdTwuZJ4gaz-bTdyCFt3gJJ1JbEeGFgYQHWknFLccahmc=s220'}}}, 'data': {}}]}
# {'status': {'code': 10000, 'description': 'Ok', 'req_id': 'b06d0dbc07654dae8dda8f2af714b360'}, 'outputs': [{'id': 'ef829597bbe74f25bd4664e964c1aaa6', 'status': {'code': 10000, 'description': 'Ok'}, 'created_at': '2020-03-19T12:08:07.428971411Z', 'model': {'id': 'c0c0ac362b03416da06ab3fa36fb58e3', 'name': 'demographics', 'created_at': '2016-12-23T06:08:44.271674Z', 'app_id': 'main', 'output_info': {'message': 'Show output_info with: GET /models/{model_id}/output_info', 'type': 'detect-concept', 'type_ext': 'detect-concept'}, 'model_version': {'id': 'f783f0807c52474c8c6ad20c8cf45fc0', 'created_at': '2016-12-23T06:08:44.271674Z', 'status': {'code': 21100, 'description': 'Model is trained and ready'}}, 'display_name': 'Demographics'}, 'input': {'id': '99086fe4a2534168a57f8908fcd0e469', 'data': {'image': {'url': 'https://lh3.googleusercontent.com/_gvdi2t1_BSQm85P1-gbW_guVl5rnIilzaa4irh2Fc6W2j5l9wR-ze9LANUjkzZPWb49QKj9Ipk=s220'}}}, 'data': {'regions': [{'id': '1614wef5o2oz', 'region_info': {'bounding_box': {'top_row': 0.1373956948518753, 'left_col': 0.3448105454444885, 'bottom_row': 0.31540319323539734, 'right_col': 0.5228105187416077}}, 'data': {'concepts': [{'id': 'ai_wpbCDvCQ', 'name': '40', 'value': 0.5113344192504883, 'app_id': 'main'}, {'id': 'ai_Lq29DpjP', 'name': '41', 'value': 0.5085911750793457, 'app_id': 'main'}, {'id': 'ai_4w8KM6Rd', 'name': '45', 'value': 0.5037546753883362, 'app_id': 'main'}, {'id': 'ai_DK5PKzTt', 'name': '44', 'value': 0.5031818151473999, 'app_id': 'main'}, {'id': 'ai_XCS0ZXlc', 'name': '39', 'value': 0.5007739067077637, 'app_id': 'main'}, {'id': 'ai_VtPhMhJv', 'name': '42', 'value': 0.4919308125972748, 'app_id': 'main'}, {'id': 'ai_9f5g2Wgg', 'name': '43', 'value': 0.4642745852470398, 'app_id': 'main'}, {'id': 'ai_fbRxTRbd', 'name': '46', 'value': 0.45804762840270996, 'app_id': 'main'}, {'id': 'ai_Jn5sPpjV', 'name': '38', 'value': 0.45426619052886963, 'app_id': 'main'}, {'id': 'ai_9stlV794', 'name': '47', 'value': 0.40568339824676514, 'app_id': 'main'}, {'id': 'ai_pm9dFGXp', 'name': '37', 'value': 0.40150943398475647, 'app_id': 'main'}, {'id': 'ai_4124wHvG', 'name': '48', 'value': 0.3643389940261841, 'app_id': 'main'}, {'id': 'ai_KFWpWmRk', 'name': '36', 'value': 0.3497945964336395, 'app_id': 'main'}, {'id': 'ai_B42sCp6t', 'name': '49', 'value': 0.32094597816467285, 'app_id': 'main'}, {'id': 'ai_wDDRSlqF', 'name': '50', 'value': 0.27443927526474, 'app_id': 'main'}, {'id': 'ai_9DCQKqhJ', 'name': '51', 'value': 0.2417048215866089, 'app_id': 'main'}, {'id': 'ai_3QlM0LQG', 'name': '35', 'value': 0.23821720480918884, 'app_id': 'main'}, {'id': 'ai_cPX160mW', 'name': '52', 'value': 0.2010156810283661, 'app_id': 'main'}, {'id': 'ai_prhRGPd1', 'name': '34', 'value': 0.19027376174926758, 'app_id': 'main'}, {'id': 'ai_0MwHlcbx', 'name': '53', 'value': 0.16738039255142212, 'app_id': 'main'}, {'id': 'ai_zgR2BBt0', 'name': 'masculine', 'value': 0.8237221240997314, 'app_id': 'main'}, {'id': 'ai_cVWr8NK5', 'name': 'feminine', 'value': 0.17627793550491333, 'app_id': 'main'}, {'id': 'ai_659b6V0v', 'name': 'asian', 'value': 0.6446958780288696, 'app_id': 'main'}, {'id': 'ai_l9ngrR28', 'name': 'hispanic, latino, or spanish origin', 'value': 0.10204117000102997, 'app_id': 'main'}, {'id': 'ai_1qp01psl', 'name': 'native hawaiian or pacific islander', 'value': 0.07856577634811401, 'app_id': 'main'}, {'id': 'ai_r5F00Gqn', 'name': 'white', 'value': 0.04014727473258972, 'app_id': 'main'}, {'id': 'ai_WWxnB3mw', 'name': 'american indian or alaska native', 'value': 0.005764706525951624, 'app_id': 'main'}, {'id': 'ai_bZft5m0H', 'name': 'middle eastern or north african', 'value': 0.0049294945783913136, 'app_id': 'main'}, {'id': 'ai_wScNwk9Z', 'name': 'black or african american', 'value': 0.0015123933553695679, 'app_id': 'main'}], 'face': {'age_appearance': {'concepts': [{'id': 'ai_wpbCDvCQ', 'name': '40', 'value': 0.5113344192504883, 'app_id': 'main'}, {'id': 'ai_Lq29DpjP', 'name': '41', 'value': 0.5085911750793457, 'app_id': 'main' ...
# {'status': {'code': 10000, 'description': 'Ok', 'req_id': '3d871741c0014db9b57ef362956770c3'}, 'outputs': [{'id': 'd040cdc775a5474f8855f998f15fe8ce', 'status': {'code': 10000, 'description': 'Ok'}, 'created_at': '2020-03-19T12:08:08.156011396Z', 'model': {'id': 'c0c0ac362b03416da06ab3fa36fb58e3', 'name': 'demographics', 'created_at': '2016-12-23T06:08:44.271674Z', 'app_id': 'main', 'output_info': {'message': 'Show output_info with: GET /models/{model_id}/output_info', 'type': 'detect-concept', 'type_ext': 'detect-concept'}, 'model_version': {'id': 'f783f0807c52474c8c6ad20c8cf45fc0', 'created_at': '2016-12-23T06:08:44.271674Z', 'status': {'code': 21100, 'description': 'Model is trained and ready'}}, 'display_name': 'Demographics'}, 'input': {'id': '12639bf9a91f46ed8e156f638fc36f10', 'data': {'image': {'url': 'https://lh3.googleusercontent.com/H2tBoNfjBfTCK9qttF0MFbqHwnI78lDRwtfOUxP0JsyVo_W3Ufk6U1EJLqgtM5CkEkDBB_v-q0U=s220'}}}, 'data': {'regions': [{'id': 'hf5906znjbgy', 'region_info': {'bounding_box': {'top_row': 0.2910037338733673, 'left_col': 0.04649365320801735, 'bottom_row': 0.7428159713745117, 'right_col': 0.4984855651855469}}, 'data': {'concepts': [{'id': 'ai_1qNCjBCW', 'name': '27', 'value': 0.5181939601898193, 'app_id': 'main'}, {'id': 'ai_J5NgRLQ1', 'name': '28', 'value': 0.5088571310043335, 'app_id': 'main'}, {'id': 'ai_t7C4Hfmm', 'name': '29', 'value': 0.4853507876396179, 'app_id': 'main'}, {'id': 'ai_fFJR7TwD', 'name': '24', 'value': 0.4694451689720154, 'app_id': 'main'}, {'id': 'ai_1XrRmbf5', 'name': '23', 'value': 0.4525022506713867, 'app_id': 'main'}, {'id': 'ai_hCkCX508', 'name': '26', 'value': 0.442001074552536, 'app_id': 'main'}, {'id': 'ai_tzZdX8VP', 'name': '30', 'value': 0.4390352964401245, 'app_id': 'main'}, {'id': 'ai_81J6NJF3', 'name': '25', 'value': 0.41625767946243286, 'app_id': 'main'}, {'id': 'ai_f55t4M4T', 'name': '22', 'value': 0.39543676376342773, 'app_id': 'main'}, {'id': 'ai_z2K094hx', 'name': '31', 'value': 0.39055266976356506, 'app_id': 'main'}, {'id': 'ai_9SgNdvCZ', 'name': '33', 'value': 0.38384902477264404, 'app_id': 'main'}, {'id': 'ai_prhRGPd1', 'name': '34', 'value': 0.3343240022659302, 'app_id': 'main'}, {'id': 'ai_7pxCXq0L', 'name': '21', 'value': 0.33175522089004517, 'app_id': 'main'}, {'id': 'ai_KG4tcMLc', 'name': '32', 'value': 0.32543912529945374, 'app_id': 'main'}, {'id': 'ai_J9NW4DbQ', 'name': '20', 'value': 0.2862192988395691, 'app_id': 'main'}, {'id': 'ai_3QlM0LQG', 'name': '35', 'value': 0.28244006633758545, 'app_id': 'main'}, {'id': 'ai_KFWpWmRk', 'name': '36', 'value': 0.21522149443626404, 'app_id': 'main'}, {'id': 'ai_pm9dFGXp', 'name': '37', 'value': 0.17211049795150757, 'app_id': 'main'}, {'id': 'ai_Jn5sPpjV', 'name': '38', 'value': 0.14211778342723846, 'app_id': 'main'}, {'id': 'ai_XCS0ZXlc', 'name': '39', 'value': 0.12325090914964676, 'app_id': 'main'}, {'id': 'ai_cVWr8NK5', 'name': 'feminine', 'value': 0.6432695388793945, 'app_id': 'main'}, {'id': 'ai_zgR2BBt0', 'name': 'masculine', 'value': 0.35673046112060547, 'app_id': 'main'}, {'id': 'ai_659b6V0v', 'name': 'asian', 'value': 0.9999265074729919, 'app_id': 'main'}, {'id': 'ai_WWxnB3mw', 'name': 'american indian or alaska native', 'value': 0.002653206465765834, 'app_id': 'main'}, {'id': 'ai_1qp01psl', 'name': 'native hawaiian or pacific islander', 'value': 0.0003469983930699527, 'app_id': 'main'}, {'id': 'ai_r5F00Gqn', 'name': 'white', 'value': 0.0003095087013207376, 'app_id': 'main'}, {'id': 'ai_wScNwk9Z', 'name': 'black or african american', 'value': 8.898145460989326e-05, 'app_id': 'main'}, {'id': 'ai_l9ngrR28', 'name': 'hispanic, latino, or spanish origin', 'value': 3.289514279458672e-05, 'app_id': 'main'}, {'id': 'ai_bZft5m0H', 'name': 'middle eastern or north african', 'value': 1.1316604286548682e-05, 'app_id': 'main'}], 'face': {'age_appearance': {'concepts': [{'id': 'ai_1qNCjBCW', 'name': '27', 'value': 0.5181939601898193, 'app_id': 'main'}, {'id': 'ai_J5NgRLQ1', 'name': '28', 'value': 0.5088571310043335, 'app_ ...
# {'status': {'code': 10000, 'description': 'Ok', 'req_id': '5a610df7d7084da9bb2e0d9d9309e436'}, 'outputs': [{'id': '851fe4e6bd7b4a81bdb6a9f115c05ff7', 'status': {'code': 10000, 'description': 'Ok'}, 'created_at': '2020-03-19T12:08:08.923875245Z', 'model': {'id': 'c0c0ac362b03416da06ab3fa36fb58e3', 'name': 'demographics', 'created_at': '2016-12-23T06:08:44.271674Z', 'app_id': 'main', 'output_info': {'message': 'Show output_info with: GET /models/{model_id}/output_info', 'type': 'detect-concept', 'type_ext': 'detect-concept'}, 'model_version': {'id': 'f783f0807c52474c8c6ad20c8cf45fc0', 'created_at': '2016-12-23T06:08:44.271674Z', 'status': {'code': 21100, 'description': 'Model is trained and ready'}}, 'display_name': 'Demographics'}, 'input': {'id': '5bfd5f11919749d2845964caed1713d2', 'data': {'image': {'url': 'https://lh3.googleusercontent.com/MH8qPOaGYxBJQJU6yKn0mbxbTrrXZQlYDC2S6pNppC21PStJlPmtICJ_wXndMQQvMcMaA-xbhU0=s220'}}}, 'data': {'regions': [{'id': 'antojpm1qa2r', 'region_info': {'bounding_box': {'top_row': 0.09098559617996216, 'left_col': 0.4352045953273773, 'bottom_row': 0.2969651222229004, 'right_col': 0.6409457325935364}}, 'data': {'concepts': [{'id': 'ai_KFWpWmRk', 'name': '36', 'value': 0.4729803204536438, 'app_id': 'main'}, {'id': 'ai_pm9dFGXp', 'name': '37', 'value': 0.4690937399864197, 'app_id': 'main'}, {'id': 'ai_Jn5sPpjV', 'name': '38', 'value': 0.4586222767829895, 'app_id': 'main'}, {'id': 'ai_XCS0ZXlc', 'name': '39', 'value': 0.4455488324165344, 'app_id': 'main'}, {'id': 'ai_3QlM0LQG', 'name': '35', 'value': 0.4243510961532593, 'app_id': 'main'}, {'id': 'ai_prhRGPd1', 'name': '34', 'value': 0.4096463918685913, 'app_id': 'main'}, {'id': 'ai_9SgNdvCZ', 'name': '33', 'value': 0.3950093984603882, 'app_id': 'main'}, {'id': 'ai_t7C4Hfmm', 'name': '29', 'value': 0.353339821100235, 'app_id': 'main'}, {'id': 'ai_wpbCDvCQ', 'name': '40', 'value': 0.352664053440094, 'app_id': 'main'}, {'id': 'ai_J5NgRLQ1', 'name': '28', 'value': 0.3432379961013794, 'app_id': 'main'}, {'id': 'ai_tzZdX8VP', 'name': '30', 'value': 0.34226667881011963, 'app_id': 'main'}, {'id': 'ai_1qNCjBCW', 'name': '27', 'value': 0.3209880590438843, 'app_id': 'main'}, {'id': 'ai_z2K094hx', 'name': '31', 'value': 0.3193399906158447, 'app_id': 'main'}, {'id': 'ai_KG4tcMLc', 'name': '32', 'value': 0.29481831192970276, 'app_id': 'main'}, {'id': 'ai_Lq29DpjP', 'name': '41', 'value': 0.28426989912986755, 'app_id': 'main'}, {'id': 'ai_hCkCX508', 'name': '26', 'value': 0.227997288107872, 'app_id': 'main'}, {'id': 'ai_VtPhMhJv', 'name': '42', 'value': 0.22609063982963562, 'app_id': 'main'}, {'id': 'ai_DK5PKzTt', 'name': '44', 'value': 0.19001495838165283, 'app_id': 'main'}, {'id': 'ai_9f5g2Wgg', 'name': '43', 'value': 0.18126821517944336, 'app_id': 'main'}, {'id': 'ai_81J6NJF3', 'name': '25', 'value': 0.18117035925388336, 'app_id': 'main'}, {'id': 'ai_cVWr8NK5', 'name': 'feminine', 'value': 0.910309910774231, 'app_id': 'main'}, {'id': 'ai_zgR2BBt0', 'name': 'masculine', 'value': 0.08969004452228546, 'app_id': 'main'}, {'id': 'ai_l9ngrR28', 'name': 'hispanic, latino, or spanish origin', 'value': 0.7386831045150757, 'app_id': 'main'}, {'id': 'ai_659b6V0v', 'name': 'asian', 'value': 0.2008865922689438, 'app_id': 'main'}, {'id': 'ai_1qp01psl', 'name': 'native hawaiian or pacific islander', 'value': 0.024656929075717926, 'app_id': 'main'}, {'id': 'ai_r5F00Gqn', 'name': 'white', 'value': 0.023006554692983627, 'app_id': 'main'}, {'id': 'ai_bZft5m0H', 'name': 'middle eastern or north african', 'value': 0.00965373869985342, 'app_id': 'main'}, {'id': 'ai_WWxnB3mw', 'name': 'american indian or alaska native', 'value': 0.0009162757196463645, 'app_id': 'main'}, {'id': 'ai_wScNwk9Z', 'name': 'black or african american', 'value': 0.0008779250783845782, 'app_id': 'main'}], 'face': {'age_appearance': {'concepts': [{'id': 'ai_KFWpWmRk', 'name': '36', 'value': 0.4729803204536438, 'app_id': 'main'}, {'id': 'ai_pm9dFGXp', 'name': '37', 'value': 0.4690937399864197, 'app_id': 'main'},  ...
# {'status': {'code': 10000, 'description': 'Ok', 'req_id': 'bbee83448f2e498d86240b6bbf825813'}, 'outputs': [{'id': '4a096f92e489414a9952deb6936fefff', 'status': {'code': 10000, 'description': 'Ok'}, 'created_at': '2020-03-19T12:08:09.703386696Z', 'model': {'id': 'c0c0ac362b03416da06ab3fa36fb58e3', 'name': 'demographics', 'created_at': '2016-12-23T06:08:44.271674Z', 'app_id': 'main', 'output_info': {'message': 'Show output_info with: GET /models/{model_id}/output_info', 'type': 'detect-concept', 'type_ext': 'detect-concept'}, 'model_version': {'id': 'f783f0807c52474c8c6ad20c8cf45fc0', 'created_at': '2016-12-23T06:08:44.271674Z', 'status': {'code': 21100, 'description': 'Model is trained and ready'}}, 'display_name': 'Demographics'}, 'input': {'id': '78116583faa04a2992e7b7620b6d9130', 'data': {'image': {'url': 'https://lh3.googleusercontent.com/_s9YEQ1-uvMrIXDjb2tyDxJf-BAeTXHdVWOm7AiegSm1rVJ54cDYeozBRsb4TkI_uh4SOsBn8aw=s220'}}}, 'data': {'regions': [{'id': '7v429hcnmiqt', 'region_info': {'bounding_box': {'top_row': 0.1648244857788086, 'left_col': 0.27250009775161743, 'bottom_row': 0.6791169047355652, 'right_col': 0.7869154214859009}}, 'data': {'concepts': [{'id': 'ai_J5NgRLQ1', 'name': '28', 'value': 0.4865087866783142, 'app_id': 'main'}, {'id': 'ai_1qNCjBCW', 'name': '27', 'value': 0.48511803150177, 'app_id': 'main'}, {'id': 'ai_t7C4Hfmm', 'name': '29', 'value': 0.4700319468975067, 'app_id': 'main'}, {'id': 'ai_tzZdX8VP', 'name': '30', 'value': 0.42737531661987305, 'app_id': 'main'}, {'id': 'ai_hCkCX508', 'name': '26', 'value': 0.3922734260559082, 'app_id': 'main'}, {'id': 'ai_z2K094hx', 'name': '31', 'value': 0.37010619044303894, 'app_id': 'main'}, {'id': 'ai_fFJR7TwD', 'name': '24', 'value': 0.3487010598182678, 'app_id': 'main'}, {'id': 'ai_9SgNdvCZ', 'name': '33', 'value': 0.3469246029853821, 'app_id': 'main'}, {'id': 'ai_81J6NJF3', 'name': '25', 'value': 0.3403092324733734, 'app_id': 'main'}, {'id': 'ai_KG4tcMLc', 'name': '32', 'value': 0.31649690866470337, 'app_id': 'main'}, {'id': 'ai_1XrRmbf5', 'name': '23', 'value': 0.313448429107666, 'app_id': 'main'}, {'id': 'ai_prhRGPd1', 'name': '34', 'value': 0.30592483282089233, 'app_id': 'main'}, {'id': 'ai_3QlM0LQG', 'name': '35', 'value': 0.2745818793773651, 'app_id': 'main'}, {'id': 'ai_f55t4M4T', 'name': '22', 'value': 0.259235680103302, 'app_id': 'main'}, {'id': 'ai_KFWpWmRk', 'name': '36', 'value': 0.2550659477710724, 'app_id': 'main'}, {'id': 'ai_pm9dFGXp', 'name': '37', 'value': 0.22795677185058594, 'app_id': 'main'}, {'id': 'ai_Jn5sPpjV', 'name': '38', 'value': 0.2140500247478485, 'app_id': 'main'}, {'id': 'ai_XCS0ZXlc', 'name': '39', 'value': 0.20123399794101715, 'app_id': 'main'}, {'id': 'ai_7pxCXq0L', 'name': '21', 'value': 0.20119230449199677, 'app_id': 'main'}, {'id': 'ai_wpbCDvCQ', 'name': '40', 'value': 0.16344258189201355, 'app_id': 'main'}, {'id': 'ai_cVWr8NK5', 'name': 'feminine', 'value': 0.6053655743598938, 'app_id': 'main'}, {'id': 'ai_zgR2BBt0', 'name': 'masculine', 'value': 0.3946344554424286, 'app_id': 'main'}, {'id': 'ai_r5F00Gqn', 'name': 'white', 'value': 0.49660632014274597, 'app_id': 'main'}, {'id': 'ai_l9ngrR28', 'name': 'hispanic, latino, or spanish origin', 'value': 0.1445748209953308, 'app_id': 'main'}, {'id': 'ai_bZft5m0H', 'name': 'middle eastern or north african', 'value': 0.06161489337682724, 'app_id': 'main'}, {'id': 'ai_659b6V0v', 'name': 'asian', 'value': 0.041624873876571655, 'app_id': 'main'}, {'id': 'ai_WWxnB3mw', 'name': 'american indian or alaska native', 'value': 0.011795541271567345, 'app_id': 'main'}, {'id': 'ai_wScNwk9Z', 'name': 'black or african american', 'value': 0.007680603303015232, 'app_id': 'main'}, {'id': 'ai_1qp01psl', 'name': 'native hawaiian or pacific islander', 'value': 0.0003174791927449405, 'app_id': 'main'}], 'face': {'age_appearance': {'concepts': [{'id': 'ai_J5NgRLQ1', 'name': '28', 'value': 0.4865087866783142, 'app_id': 'main'}, {'id': 'ai_1qNCjBCW', 'name': '27', 'value': 0.48511803150177, 'app_id': 'main'}, {' ...
# {'status': {'code': 10000, 'description': 'Ok', 'req_id': 'a4d0636d6a5044a5818962f94c849e4e'}, 'outputs': [{'id': 'b65d6501a2b84c38b588299cfdaf7a0c', 'status': {'code': 10000, 'description': 'Ok'}, 'created_at': '2020-03-19T12:08:10.417671845Z', 'model': {'id': 'c0c0ac362b03416da06ab3fa36fb58e3', 'name': 'demographics', 'created_at': '2016-12-23T06:08:44.271674Z', 'app_id': 'main', 'output_info': {'message': 'Show output_info with: GET /models/{model_id}/output_info', 'type': 'detect-concept', 'type_ext': 'detect-concept'}, 'model_version': {'id': 'f783f0807c52474c8c6ad20c8cf45fc0', 'created_at': '2016-12-23T06:08:44.271674Z', 'status': {'code': 21100, 'description': 'Model is trained and ready'}}, 'display_name': 'Demographics'}, 'input': {'id': 'f512d33d1dd4461391649d0aab207ba3', 'data': {'image': {'url': 'https://lh3.googleusercontent.com/qIC66hrvBqJkzYM6SqtZ1j8h3ZuMQZT0x-PSJGa0ndghA6_pIQfShDYvXPC98HevJwbO8pdYzV8=s220'}}}, 'data': {'regions': [{'id': 'oun2pyk0pdgj', 'region_info': {'bounding_box': {'top_row': 0.33662810921669006, 'left_col': 0.742421567440033, 'bottom_row': 0.5291052460670471, 'right_col': 0.9347492456436157}}, 'data': {'concepts': [{'id': 'ai_KFWpWmRk', 'name': '36', 'value': 0.4059242308139801, 'app_id': 'main'}, {'id': 'ai_3QlM0LQG', 'name': '35', 'value': 0.39444732666015625, 'app_id': 'main'}, {'id': 'ai_prhRGPd1', 'name': '34', 'value': 0.37418243288993835, 'app_id': 'main'}, {'id': 'ai_pm9dFGXp', 'name': '37', 'value': 0.3732607364654541, 'app_id': 'main'}, {'id': 'ai_Jn5sPpjV', 'name': '38', 'value': 0.35228949785232544, 'app_id': 'main'}, {'id': 'ai_XCS0ZXlc', 'name': '39', 'value': 0.3359963297843933, 'app_id': 'main'}, {'id': 'ai_cPX160mW', 'name': '52', 'value': 0.31892627477645874, 'app_id': 'main'}, {'id': 'ai_9DCQKqhJ', 'name': '51', 'value': 0.3155497908592224, 'app_id': 'main'}, {'id': 'ai_9SgNdvCZ', 'name': '33', 'value': 0.31538212299346924, 'app_id': 'main'}, {'id': 'ai_0MwHlcbx', 'name': '53', 'value': 0.29362401366233826, 'app_id': 'main'}, {'id': 'ai_wDDRSlqF', 'name': '50', 'value': 0.28894057869911194, 'app_id': 'main'}, {'id': 'ai_38qJ9qlS', 'name': '55', 'value': 0.26660633087158203, 'app_id': 'main'}, {'id': 'ai_B42sCp6t', 'name': '49', 'value': 0.2623336911201477, 'app_id': 'main'}, {'id': 'ai_Mp3n0xln', 'name': '54', 'value': 0.25854235887527466, 'app_id': 'main'}, {'id': 'ai_wpbCDvCQ', 'name': '40', 'value': 0.245225191116333, 'app_id': 'main'}, {'id': 'ai_8Q4lxPgg', 'name': '56', 'value': 0.23630645871162415, 'app_id': 'main'}, {'id': 'ai_4124wHvG', 'name': '48', 'value': 0.22641205787658691, 'app_id': 'main'}, {'id': 'ai_tzZdX8VP', 'name': '30', 'value': 0.219944030046463, 'app_id': 'main'}, {'id': 'ai_t7C4Hfmm', 'name': '29', 'value': 0.21746812760829926, 'app_id': 'main'}, {'id': 'ai_z2K094hx', 'name': '31', 'value': 0.21736493706703186, 'app_id': 'main'}, {'id': 'ai_cVWr8NK5', 'name': 'feminine', 'value': 0.8089433312416077, 'app_id': 'main'}, {'id': 'ai_zgR2BBt0', 'name': 'masculine', 'value': 0.19105663895606995, 'app_id': 'main'}, {'id': 'ai_r5F00Gqn', 'name': 'white', 'value': 0.5399892330169678, 'app_id': 'main'}, {'id': 'ai_l9ngrR28', 'name': 'hispanic, latino, or spanish origin', 'value': 0.2428147792816162, 'app_id': 'main'}, {'id': 'ai_bZft5m0H', 'name': 'middle eastern or north african', 'value': 0.019993416965007782, 'app_id': 'main'}, {'id': 'ai_wScNwk9Z', 'name': 'black or african american', 'value': 0.010396378114819527, 'app_id': 'main'}, {'id': 'ai_1qp01psl', 'name': 'native hawaiian or pacific islander', 'value': 0.00787937268614769, 'app_id': 'main'}, {'id': 'ai_659b6V0v', 'name': 'asian', 'value': 0.003928591962903738, 'app_id': 'main'}, {'id': 'ai_WWxnB3mw', 'name': 'american indian or alaska native', 'value': 0.0020035605411976576, 'app_id': 'main'}], 'face': {'age_appearance': {'concepts': [{'id': 'ai_KFWpWmRk', 'name': '36', 'value': 0.4059242308139801, 'app_id': 'main'}, {'id': 'ai_3QlM0LQG', 'name': '35', 'value': 0.39444732666015625, 'app_id': 'm ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-4753e283a5bc> in <module>()
#      16   url = file1['thumbnailLink']
#      17   url2 = '%s' % url
# ---> 18   detect_clarifai(file1['id'], url2)
#      19
#
# <ipython-input-47-977e68e0ca50> in detect_clarifai(id, url_photo)
#       3
#       4 def detect_clarifai(id, url_photo):
# ----> 5   app = ClarifaiApp(api_key='6651c2b2e8d64d3291238ef15277c18c')
#       6   model = app.models.get(model_id="c0c0ac362b03416da06ab3fa36fb58e3")
#       7   response = model.predict_by_url(url = url_photo)
#
# /usr/local/lib/python3.6/dist-packages/clarifai/rest/client.py in __init__(self, app_id, app_secret, base_url, api_key, quiet, log_level)
#     122     self.concepts = Concepts(self.api)  # type: Concepts
#     123     self.inputs = Inputs(self.api)  # type: Inputs
# --> 124     self.models = Models(self.api, self.solutions)  # type: Models
#     125     self.workflows = Workflows(self.api)  # type: Workflows
#     126
#
# /usr/local/lib/python3.6/dist-packages/clarifai/rest/client.py in __init__(self, api, solutions)
#    1066     # the cache of the model name -> model id mapping
#    1067     # to avoid an extra model query on every prediction by model name
# -> 1068     self.model_id_cache = self.init_model_cache()
#    1069
#    1070   def init_model_cache(self):
#
# /usr/local/lib/python3.6/dist-packages/clarifai/rest/client.py in init_model_cache(self)
#    1084
#    1085     try:
# -> 1086       for m in models:
#    1087         model_name = m.model_name
#    1088         model_type = m.output_info['type']
#
# /usr/local/lib/python3.6/dist-packages/clarifai/rest/client.py in get_all(self, public_only, private_only)
#    1191
#    1192     while True:
# -> 1193       res = self.api.get_models(page, per_page)
#    1194
#    1195       if not res['models']:
#
# /usr/local/lib/python3.6/dist-packages/clarifai/rest/client.py in get_models(self, page, per_page)
#    3941
#    3942     response = self._grpc_request(self._grpc_stub().ListModels,
# -> 3943                                   ListModelsRequest(page=page, per_page=per_page))
#    3944     return response
#    3945
#
# /usr/local/lib/python3.6/dist-packages/clarifai/rest/client.py in _grpc_request(self, method, argument)
#    3645     for attempt_num in range(1, max_attempts + 1):
#    3646       try:
# -> 3647         res = method(argument)
#    3648
#    3649         dict_res = protobuf_to_dict(res)
#
# /usr/local/lib/python3.6/dist-packages/clarifai/rest/grpc/grpc_json_channel.py in __call__(self, request, metadata)
#     165       del params[url_field]
#     166
# --> 167     response_json = self.http_client.execute_request(method, params, url)
#     168
#     169     # Get the actual message object to construct
#
# /usr/local/lib/python3.6/dist-packages/clarifai/rest/http_client.py in execute_request(self, method, params, url)
#      33     try:
#      34       if method == 'GET':
# ---> 35         res = self._session.get(url, params=params, headers=headers)
#      36       elif method == "POST":
#      37         res = self._session.post(url, data=json.dumps(params), headers=headers)
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.6/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1344         try:
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#    1348                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import csv

# apro e parso il file .json
def convert(response, id):

    #creo e apro un file .csv per scrivere
    file_parsed = open('File_Parsered.csv', 'w')
    
    #creo il writer
    writer = csv.writer(file_parsed)

    #ciclo per tradurre il file .json in quello .csv
    header = ['user', 'age', 'gender', 'ethnicity']

    #creo il writer
    writer.writerow(header)

    #estrarre dal file json i valori di età, genere ed etnia
    age = response['outputs'][0]['data']['regions'][0]['data']['face']['age_appearance']['concepts'][0]['name']
    gender = response['outputs'][0]['data']['regions'][0]['data']['face']['gender_appearance']['concepts'][0]['name']
    ethnicity = response['outputs'][0]['data']['regions'][0]['data']['face']['multicultural_appearance']['concepts'][0]['name']
    writer.writerow([id, age, gender, ethnicity])

    #salvo e chiudo il file .csv
    file_parsed.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-1badc8a29408> in <module>()
#      17
#      18     #estrarre dal file json i valori di età, genere ed etnia
# ---> 19 age = response['outputs'][0]['data']['regions'][0]['data']['face']['age_appearance']['concepts'][0]['name']
#      20 gender = response['outputs'][0]['data']['regions'][0]['data']['face']['gender_appearance']['concepts'][0]['name']
#      21 ethnicity = response['outputs'][0]['data']['regions'][0]['data']['face']['multicultural_appearance']['concepts'][0]['name']
#
# NameError: name 'response' is not defined
