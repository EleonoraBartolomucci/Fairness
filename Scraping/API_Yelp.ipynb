# %% [markdown]
# <a href="https://colab.research.google.com/github/EleonoraBartolomucci/Fairness/blob/master/Scraping/API_Yelp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

api_key='8lQKTmzi_bpJLR2Btn_oLrCw4dGnQDtixACUfkt4jvSZHdxdlF5l0_F0UpsWhcTYM1HE0kWIoMlCDnyo7gOBMljy5SNbvSAj5RHYCs956KYzOcKiLczzIphyBJ0BX3Yx'
headers = {'Authorization': 'Bearer %s' % api_key}

url='https://api.yelp.com/v3/businesses/search'
params={'term':'restaurant','location':'NV'}

req = requests.get(url, params=params, headers=headers)

parsed = json.loads(req.text)

print(json.dumps(parsed, indent=4))

# %%
import requests
import json

api_key = '8lQKTmzi_bpJLR2Btn_oLrCw4dGnQDtixACUfkt4jvSZHdxdlF5l0_F0UpsWhcTYM1HE0kWIoMlCDnyo7gOBMljy5SNbvSAj5RHYCs956KYzOcKiLczzIphyBJ0BX3Yx'
headers = {'Authorization': 'Bearer %s' % api_key}

url = 'https://api.yelp.com/v3/businesses/search'
params = {'term':'restaurant','location':'NC'}

req = requests.get(url, params=params, headers=headers)

parsed = json.loads(req.text)

businesses = parsed["businesses"]

for business in businesses:
    print("Name:", business["name"])
    print("Rating:", business["rating"])
    print("Address:", " ".join(business["location"]["display_address"]))
    print("Phone:", business["phone"])
    print("\n")

    id = business["id"]

    url="https://api.yelp.com/v3/businesses/" + id + "/reviews"

    req = requests.get(url, headers=headers)

    parsed = json.loads(req.text)

    reviews = parsed["reviews"]

    print("--- Reviews ---")

    for review in reviews:
        print("User:", review["user"]["name"], "Rating:", review["rating"], "Review:", review["text"], "\n")
# Out:
# Name: Ilios Crafted Greek
# Rating: 5.0
# Address: 1514 S Church St Charlotte, NC 28203
# Phone: +19802371949
#
#
# --- Reviews ---
# User: Jes T. Rating: 5 Review: Full disclosure: I'm a Greek food fanatic.
#
# Y'all, sitting here writing this review after taking  3 bites of food because it's that good. I went to Greece...
#
# User: Emily M. Rating: 5 Review: Wow, I honestly picked this place when we couldn't decide on anything else to eat, I mean it's another Greek place, right? Wrong.
# Service: super nice people...
#
# User: Lauren F. Rating: 5 Review: I just ordered takeout from here for lunch and Wow is all I have to say!! Some of the freshest gyro I've ever had!! Will definitely be back,This is my new...
#
# Name: RH Rooftop Restaurant Charlotte
# Rating: 4.0
# Address: 6903 Phillips Place Ct Charlotte, NC 28210
# Phone: +17047904970
#
#
# --- Reviews ---
# ...
